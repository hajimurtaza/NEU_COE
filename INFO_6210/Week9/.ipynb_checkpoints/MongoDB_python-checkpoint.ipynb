# %% [markdown]
# # MongoDB with python

# %%
# %matplotlib inline
import pymongo
from pymongo import MongoClient
from pymongo.errors import ConnectionFailure
from bson import json_util, ObjectId
import pandas as pd
from pandas import DataFrame
from pandas.io.json import json_normalize
import numpy as np
import requests
import json, os
import configparser
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import seaborn as sns
import warnings
import random
import pprint
from datetime import datetime
random.seed(datetime.now())
warnings.filterwarnings('ignore')

# Make plots larger
plt.rcParams['figure.figsize'] = (10, 6)

# %% [markdown]
# ###  Install PyMongo¶
#
# Linux/OS X
# You can use pip to install:
#
# ```bash
# pip install pymongo
# ```
#
# ###  Create a Connection
#
#
# Use MongoClient to create a connection:
#
# ```python
# client = MongoClient()
# ```
# If you do not specify any arguments to MongoClient, then MongoClient defaults to the MongoDB instance that runs on the localhost interface on port 27017.
#
# You can also specify a complete MongoDB URI to define the connection, including explicitly specifying the host and port number. For example, the following creates a connection to a MongoDB instance that runs on mongodb0.example.net and the port of 27017:
#
#
# ```python
# client = MongoClient("mongodb://mongodb0.example.net:27017")
# ```
#
# ### Access Database Objects
#
# The first fundamental class of objects you will interact with using pymongo is Database which represents the database construct in MongoDB. Databases hold groups of logically related collections. MongoDB creates new databases implicitly upon their first use.
#
# To assign the database named primer to the local variable db, you can use attribute access, as in the following:
#
# ```python
# db = client.primer
# ```
# You can also access databases using dictionary-style access, which removes Python-specific naming restrictions, as in the following:
#
# ```python
# db = client['primer']
# ```
#
# ### Access Collection Objects
#
# The second fundamental class of objects you will interact using pymongo is Collection, which represents the collection construct in MongoDB. Collections hold groups of related documents.
#
# You can access collection objects directly using dictionary-style or attribute access from a Database object, as in the following examples:
#
#
# ```python
# db.dataset
# db['dataset']
# ```
# You may also assign the collection object to a variable for use elsewhere, as in the following examples:
#
# ```python
# coll = db.dataset
# coll = db['dataset']
# ```

# %%
config = configparser.ConfigParser()
config.read('./data/mongo.ini')
# Out:
# ['./data/mongo.ini']

# %%
port = config.get('Mongo', 'port')
print (port)
# Out:
# 27017

# %%
client = MongoClient(config.get('Mongo', 'host'), int(port))

# %%
client.analytics
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'analytics')

# %%
client.analytics.collection_names(include_system_collections=False)
# Out:
# ['tweets', 'blog', 'users']

# %%
try:
    result = client.analytics.blog.drop()
    print ("analytics blog dropped")
except:
    pass
# Out:
# analytics blog dropped

# %%
try:
    result = client.analytics.users.drop()
    print ("analytics users dropped")
except:
    pass
# Out:
# analytics users dropped

# %%
try:
    result = client.analytics.tweets.drop()
    print ("analytics tweets dropped")
except:
    pass
# Out:
# analytics tweets dropped

# %%
client.analytics
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'analytics')

# %%
client.analytics.collection_names(include_system_collections=False)
# Out:
# []

# %%
result = client.analytics.users.insert_one({
    "username" : "Goku",
    "firstname" : "Goku",
    "surname" : "Brown",
    "dateofbirth" : datetime(1973, 7, 8),
    "email" : "Goku@GokuBrown.com",
    "score" : 5
})
result.inserted_id
# Out:
# ObjectId('5ac19b70a313fc02d6006fda')

# %%
result = client.analytics.blog.insert_one({
    "post_id": 1,
    "author": "Goku",
    "text": "My first blog post!",
    "tags": ["mongodb", "python", "pymongo"],
    "date": datetime.utcnow()
})
result.inserted_id
# Out:
# ObjectId('5ac19b70a313fc02d6006fdb')

# %% [markdown]
# ## You need to be careful; running a script twice may duplicate your data

# %%
result = client.analytics.blog.insert_one({
    "post_id": 1,
    "author": "Goku",
    "text": "My first blog post!",
    "tags": ["mongodb", "python", "pymongo"],
    "date": datetime.utcnow()
})
result.inserted_id
# Out:
# ObjectId('5ac19b71a313fc02d6006fdc')

# %%
db = client.analytics

# %%
db.collection_names(include_system_collections=False)
# Out:
# ['blog', 'users']

# %%
for post in db.blog.find({"author": "Goku"}):
    pprint.pprint(post)
# You need to be careful; running a script twice may duplicate your data
# Out:
# {'_id': ObjectId('5ac19b70a313fc02d6006fdb'),
#  'author': 'Goku',
#  'date': datetime.datetime(2018, 4, 2, 2, 54, 40, 945000),
#  'post_id': 1,
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'text': 'My first blog post!'}
# {'_id': ObjectId('5ac19b71a313fc02d6006fdc'),
#  'author': 'Goku',
#  'date': datetime.datetime(2018, 4, 2, 2, 54, 41, 4000),
#  'post_id': 1,
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'text': 'My first blog post!'}

# %% [markdown]
# ### Getting a Single Document With find_one()

# %%
pprint.pprint(db.blog.find_one())
# Out:
# {'_id': ObjectId('5ac19b70a313fc02d6006fdb'),
#  'author': 'Goku',
#  'date': datetime.datetime(2018, 4, 2, 2, 54, 40, 945000),
#  'post_id': 1,
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'text': 'My first blog post!'}

# %%
pprint.pprint(db.blog.find_one({"author": "Goku"}))
# Out:
# {'_id': ObjectId('5ac19b70a313fc02d6006fdb'),
#  'author': 'Goku',
#  'date': datetime.datetime(2018, 4, 2, 2, 54, 40, 945000),
#  'post_id': 1,
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'text': 'My first blog post!'}

# %% [markdown]
# ###  Querying By ObjectId

# %%
mid=db.blog.find_one({"author": "Goku"})['_id'] 
mid
# Out:
# ObjectId('5ac19b70a313fc02d6006fdb')

# %%
pprint.pprint(db.blog.find_one({"_id": mid}))
# Out:
# {'_id': ObjectId('5ac19b70a313fc02d6006fdb'),
#  'author': 'Goku',
#  'date': datetime.datetime(2018, 4, 2, 2, 54, 40, 945000),
#  'post_id': 1,
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'text': 'My first blog post!'}

# %% [markdown]
# ### Bulk Inserts

# %%
new_posts = [{"author": "Goku",
    "text": "Another post on bulk inserts!",
    "tags": ["bulk", "insert"],
    "date": datetime(2017, 3, 12, 11, 14)},
    {"author": "Vegeta",
    "title": "MongoDB is fun",
    "text": "and pretty easy too!",
    "date": datetime.utcnow()}]
result = db.blog.insert_many(new_posts)
result.inserted_ids
# Out:
# [ObjectId('5ac19b71a313fc02d6006fdd'), ObjectId('5ac19b71a313fc02d6006fde')]

# %% [markdown]
# ### Querying for More Than One Document

# %%
for post in db.blog.find():
    pprint.pprint(post)
# Out:
# {'_id': ObjectId('5ac19b70a313fc02d6006fdb'),
#  'author': 'Goku',
#  'date': datetime.datetime(2018, 4, 2, 2, 54, 40, 945000),
#  'post_id': 1,
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'text': 'My first blog post!'}
# {'_id': ObjectId('5ac19b71a313fc02d6006fdc'),
#  'author': 'Goku',
#  'date': datetime.datetime(2018, 4, 2, 2, 54, 41, 4000),
#  'post_id': 1,
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'text': 'My first blog post!'}
# {'_id': ObjectId('5ac19b71a313fc02d6006fdd'),
#  'author': 'Goku',
#  'date': datetime.datetime(2017, 3, 12, 11, 14),
#  'tags': ['bulk', 'insert'],
#  'text': 'Another post on bulk inserts!'}
# {'_id': ObjectId('5ac19b71a313fc02d6006fde'),
#  'author': 'Vegeta',
#  'date': datetime.datetime(2018, 4, 2, 2, 54, 41, 69000),
#  'text': 'and pretty easy too!',
#  'title': 'MongoDB is fun'}

# %%
for post in db.blog.find({"author": "Goku"}):
    pprint.pprint(post)
# Out:
# {'_id': ObjectId('5ac19b70a313fc02d6006fdb'),
#  'author': 'Goku',
#  'date': datetime.datetime(2018, 4, 2, 2, 54, 40, 945000),
#  'post_id': 1,
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'text': 'My first blog post!'}
# {'_id': ObjectId('5ac19b71a313fc02d6006fdc'),
#  'author': 'Goku',
#  'date': datetime.datetime(2018, 4, 2, 2, 54, 41, 4000),
#  'post_id': 1,
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'text': 'My first blog post!'}
# {'_id': ObjectId('5ac19b71a313fc02d6006fdd'),
#  'author': 'Goku',
#  'date': datetime.datetime(2017, 3, 12, 11, 14),
#  'tags': ['bulk', 'insert'],
#  'text': 'Another post on bulk inserts!'}

# %% [markdown]
# ### Counting

# %%
db.blog.count()
# Out:
# 4

# %%
db.blog.find({"author": "Goku"}).count()
# Out:
# 3

# %% [markdown]
# ### Range Queries

# %%
d = datetime(2017, 5, 5, 12)
for post in db.blog.find({"date": {"$gt": d}}).sort("author"):
    pprint.pprint(post)
# Out:
# {'_id': ObjectId('5ac19b70a313fc02d6006fdb'),
#  'author': 'Goku',
#  'date': datetime.datetime(2018, 4, 2, 2, 54, 40, 945000),
#  'post_id': 1,
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'text': 'My first blog post!'}
# {'_id': ObjectId('5ac19b71a313fc02d6006fdc'),
#  'author': 'Goku',
#  'date': datetime.datetime(2018, 4, 2, 2, 54, 41, 4000),
#  'post_id': 1,
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'text': 'My first blog post!'}
# {'_id': ObjectId('5ac19b71a313fc02d6006fde'),
#  'author': 'Vegeta',
#  'date': datetime.datetime(2018, 4, 2, 2, 54, 41, 69000),
#  'text': 'and pretty easy too!',
#  'title': 'MongoDB is fun'}

# %% [markdown]
# ### Indexing
#
# Note if there are duplicates you'll get this error.
#
# ```python
# DuplicateKeyError: E11000 duplicate key error collection: analytics.users index: username_1 dup key: { : "Goku" }
# ```

# %%
result = db.users.insert_one({
    "username" : "Vegeta",
    "firstname" : "Vegeta",
    "surname" : "Saiyan",
    "dateofbirth" : datetime(1903, 7, 7),
    "email" : "Vegeta@Saiyan.com",
    "score" : 3
})
result.inserted_id
# Out:
# ObjectId('5ac19b71a313fc02d6006fdf')

# %%
for user in db.users.find():
    pprint.pprint(user)
# Out:
# {'_id': ObjectId('5ac19b70a313fc02d6006fda'),
#  'dateofbirth': datetime.datetime(1973, 7, 8, 0, 0),
#  'email': 'Goku@GokuBrown.com',
#  'firstname': 'Goku',
#  'score': 5,
#  'surname': 'Brown',
#  'username': 'Goku'}
# {'_id': ObjectId('5ac19b71a313fc02d6006fdf'),
#  'dateofbirth': datetime.datetime(1903, 7, 7, 0, 0),
#  'email': 'Vegeta@Saiyan.com',
#  'firstname': 'Vegeta',
#  'score': 3,
#  'surname': 'Saiyan',
#  'username': 'Vegeta'}

# %%
result = db.users.insert_many([{
    "username" : "Bulma",
    "firstname" : "Bulma",
    "surname" : "Saiyan",
    "dateofbirth" : datetime(1919, 7, 7),
    "email" : "Bulma@Saiyan.com",
    "score" : 2},
{
    "username" : "Trunks",
    "firstname" : "Trunks",
    "surname" : "Saiyan",
    "dateofbirth" : datetime(1955, 7, 7),
    "email" : "Trunks@Saiyan.com",
    "score" : 5
}])

# %%
for user in db.users.find():
    pprint.pprint(user)
# Out:
# {'_id': ObjectId('5ac19b70a313fc02d6006fda'),
#  'dateofbirth': datetime.datetime(1973, 7, 8, 0, 0),
#  'email': 'Goku@GokuBrown.com',
#  'firstname': 'Goku',
#  'score': 5,
#  'surname': 'Brown',
#  'username': 'Goku'}
# {'_id': ObjectId('5ac19b71a313fc02d6006fdf'),
#  'dateofbirth': datetime.datetime(1903, 7, 7, 0, 0),
#  'email': 'Vegeta@Saiyan.com',
#  'firstname': 'Vegeta',
#  'score': 3,
#  'surname': 'Saiyan',
#  'username': 'Vegeta'}
# {'_id': ObjectId('5ac19b71a313fc02d6006fe0'),
#  'dateofbirth': datetime.datetime(1919, 7, 7, 0, 0),
#  'email': 'Bulma@Saiyan.com',
#  'firstname': 'Bulma',
#  'score': 2,
#  'surname': 'Saiyan',
#  'username': 'Bulma'}
# {'_id': ObjectId('5ac19b71a313fc02d6006fe1'),
#  'dateofbirth': datetime.datetime(1955, 7, 7, 0, 0),
#  'email': 'Trunks@Saiyan.com',
#  'firstname': 'Trunks',
#  'score': 5,
#  'surname': 'Saiyan',
#  'username': 'Trunks'}

# %%
result = db.users.create_index([('username', pymongo.ASCENDING)], unique=True)
sorted(list(db.users.index_information()))
# Out:
# ['_id_', 'username_1']

# %%
user_profiles = [
{
    "username" : "Vegeta",
    "firstname" : "Vegeta",
    "surname" : "Saiyan",
    "dateofbirth" : datetime(1903, 7, 7),
    "email" : "Vegeta@Saiyan.com",
    "score" : 3
}]

# %%
pprint.pprint(user_profiles)
# Out:
# [{'dateofbirth': datetime.datetime(1903, 7, 7, 0, 0),
#   'email': 'Vegeta@Saiyan.com',
#   'firstname': 'Vegeta',
#   'score': 3,
#   'surname': 'Saiyan',
#   'username': 'Vegeta'}]

# %%
try:
  result = db.users.insert_many(user_profiles)
except:
  print ("insert_many(user_profiles) failed")
# Out:
# insert_many(user_profiles) failed

# %% [markdown]
# _The index prevents us from inserting a document whose username is already in the collection_

# %% [markdown]
# ### Update

# %%
import copy
orig_user = db.users.find_one({"username":"Goku"})
new_user = copy.deepcopy(orig_user)
pprint.pprint(new_user)
# Out:
# {'_id': ObjectId('5ac19b70a313fc02d6006fda'),
#  'dateofbirth': datetime.datetime(1973, 7, 8, 0, 0),
#  'email': 'Goku@GokuBrown.com',
#  'firstname': 'Goku',
#  'score': 5,
#  'surname': 'Brown',
#  'username': 'Goku'}

# %%
# modify the copy to add an email address
l=[]
l.append(new_user["email"])
l.append("Goku@NikBearBrown.com")
l
# Out:
# ['Goku@GokuBrown.com', 'Goku@NikBearBrown.com']

# %%
new_user["email"] = l
pprint.pprint(new_user)
# Out:
# {'_id': ObjectId('5ac19b70a313fc02d6006fda'),
#  'dateofbirth': datetime.datetime(1973, 7, 8, 0, 0),
#  'email': ['Goku@GokuBrown.com', 'Goku@NikBearBrown.com'],
#  'firstname': 'Goku',
#  'score': 5,
#  'surname': 'Brown',
#  'username': 'Goku'}

# %%
# replace the matched document with the contents of new_user
db.users.replace_one({"username":"Goku"}, new_user)

# %%
goku = db.users.find_one({"username":"Goku"})
pprint.pprint(goku)
# Out:
# {'_id': ObjectId('5ac19b70a313fc02d6006fda'),
#  'dateofbirth': datetime.datetime(1973, 7, 8, 0, 0),
#  'email': ['Goku@GokuBrown.com', 'Goku@NikBearBrown.com'],
#  'firstname': 'Goku',
#  'score': 5,
#  'surname': 'Brown',
#  'username': 'Goku'}

# %% [markdown]
# ### Delete

# %%
for user in db.users.find():
    pprint.pprint(user)
# Out:
# {'_id': ObjectId('5ac19b70a313fc02d6006fda'),
#  'dateofbirth': datetime.datetime(1973, 7, 8, 0, 0),
#  'email': ['Goku@GokuBrown.com', 'Goku@NikBearBrown.com'],
#  'firstname': 'Goku',
#  'score': 5,
#  'surname': 'Brown',
#  'username': 'Goku'}
# {'_id': ObjectId('5ac19b71a313fc02d6006fdf'),
#  'dateofbirth': datetime.datetime(1903, 7, 7, 0, 0),
#  'email': 'Vegeta@Saiyan.com',
#  'firstname': 'Vegeta',
#  'score': 3,
#  'surname': 'Saiyan',
#  'username': 'Vegeta'}
# {'_id': ObjectId('5ac19b71a313fc02d6006fe0'),
#  'dateofbirth': datetime.datetime(1919, 7, 7, 0, 0),
#  'email': 'Bulma@Saiyan.com',
#  'firstname': 'Bulma',
#  'score': 2,
#  'surname': 'Saiyan',
#  'username': 'Bulma'}
# {'_id': ObjectId('5ac19b71a313fc02d6006fe1'),
#  'dateofbirth': datetime.datetime(1955, 7, 7, 0, 0),
#  'email': 'Trunks@Saiyan.com',
#  'firstname': 'Trunks',
#  'score': 5,
#  'surname': 'Saiyan',
#  'username': 'Trunks'}

# %%
db.users.delete_one({"score":0})

# %%
for user in db.users.find():
    pprint.pprint(user)
# Out:
# {'_id': ObjectId('5ac19b70a313fc02d6006fda'),
#  'dateofbirth': datetime.datetime(1973, 7, 8, 0, 0),
#  'email': ['Goku@GokuBrown.com', 'Goku@NikBearBrown.com'],
#  'firstname': 'Goku',
#  'score': 5,
#  'surname': 'Brown',
#  'username': 'Goku'}
# {'_id': ObjectId('5ac19b71a313fc02d6006fdf'),
#  'dateofbirth': datetime.datetime(1903, 7, 7, 0, 0),
#  'email': 'Vegeta@Saiyan.com',
#  'firstname': 'Vegeta',
#  'score': 3,
#  'surname': 'Saiyan',
#  'username': 'Vegeta'}
# {'_id': ObjectId('5ac19b71a313fc02d6006fe0'),
#  'dateofbirth': datetime.datetime(1919, 7, 7, 0, 0),
#  'email': 'Bulma@Saiyan.com',
#  'firstname': 'Bulma',
#  'score': 2,
#  'surname': 'Saiyan',
#  'username': 'Bulma'}
# {'_id': ObjectId('5ac19b71a313fc02d6006fe1'),
#  'dateofbirth': datetime.datetime(1955, 7, 7, 0, 0),
#  'email': 'Trunks@Saiyan.com',
#  'firstname': 'Trunks',
#  'score': 5,
#  'surname': 'Saiyan',
#  'username': 'Trunks'}

# %% [markdown]
# ### Query Operators
#
# Queries use a document-style (or python dict) syntax.

# %%
for user in db.users.find({'score': 5}):
    pprint.pprint(user)
# Out:
# {'_id': ObjectId('5ac19b70a313fc02d6006fda'),
#  'dateofbirth': datetime.datetime(1973, 7, 8, 0, 0),
#  'email': ['Goku@GokuBrown.com', 'Goku@NikBearBrown.com'],
#  'firstname': 'Goku',
#  'score': 5,
#  'surname': 'Brown',
#  'username': 'Goku'}
# {'_id': ObjectId('5ac19b71a313fc02d6006fe1'),
#  'dateofbirth': datetime.datetime(1955, 7, 7, 0, 0),
#  'email': 'Trunks@Saiyan.com',
#  'firstname': 'Trunks',
#  'score': 5,
#  'surname': 'Saiyan',
#  'username': 'Trunks'}

# %%
db.users.find({'score': 5}).count()
# Out:
# 2

# %%
for user in db.users.find({'score': {'$lt': 5}}):
    pprint.pprint(user)
# Out:
# {'_id': ObjectId('5ac19b71a313fc02d6006fdf'),
#  'dateofbirth': datetime.datetime(1903, 7, 7, 0, 0),
#  'email': 'Vegeta@Saiyan.com',
#  'firstname': 'Vegeta',
#  'score': 3,
#  'surname': 'Saiyan',
#  'username': 'Vegeta'}
# {'_id': ObjectId('5ac19b71a313fc02d6006fe0'),
#  'dateofbirth': datetime.datetime(1919, 7, 7, 0, 0),
#  'email': 'Bulma@Saiyan.com',
#  'firstname': 'Bulma',
#  'score': 2,
#  'surname': 'Saiyan',
#  'username': 'Bulma'}

# %%
db.users.find({'score': {'$lt': 5}}).count()
# Out:
# 2

# %%
db.users.find_one({'score': {'$lte': 4}})
# Out:
# {'_id': ObjectId('5ac19b71a313fc02d6006fdf'),
#  'dateofbirth': datetime.datetime(1903, 7, 7, 0, 0),
#  'email': 'Vegeta@Saiyan.com',
#  'firstname': 'Vegeta',
#  'score': 3,
#  'surname': 'Saiyan',
#  'username': 'Vegeta'}

# %%
import re
rgx = re.compile('Saiyan.com$')

# %%
for user in db.users.find({'email': rgx}):
    pprint.pprint(user)
# Out:
# {'_id': ObjectId('5ac19b71a313fc02d6006fdf'),
#  'dateofbirth': datetime.datetime(1903, 7, 7, 0, 0),
#  'email': 'Vegeta@Saiyan.com',
#  'firstname': 'Vegeta',
#  'score': 3,
#  'surname': 'Saiyan',
#  'username': 'Vegeta'}
# {'_id': ObjectId('5ac19b71a313fc02d6006fe0'),
#  'dateofbirth': datetime.datetime(1919, 7, 7, 0, 0),
#  'email': 'Bulma@Saiyan.com',
#  'firstname': 'Bulma',
#  'score': 2,
#  'surname': 'Saiyan',
#  'username': 'Bulma'}
# {'_id': ObjectId('5ac19b71a313fc02d6006fe1'),
#  'dateofbirth': datetime.datetime(1955, 7, 7, 0, 0),
#  'email': 'Trunks@Saiyan.com',
#  'firstname': 'Trunks',
#  'score': 5,
#  'surname': 'Saiyan',
#  'username': 'Trunks'}

# %% [markdown]
# ### Sort results
#
# You can sort the query results on the server side using the sort
# method.

# %%
for user in db.users.find({'score': {'$lte': 4}}).sort([('score', pymongo.DESCENDING)]):
    pprint.pprint(user)
# Out:
# {'_id': ObjectId('5ac19b71a313fc02d6006fdf'),
#  'dateofbirth': datetime.datetime(1903, 7, 7, 0, 0),
#  'email': 'Vegeta@Saiyan.com',
#  'firstname': 'Vegeta',
#  'score': 3,
#  'surname': 'Saiyan',
#  'username': 'Vegeta'}
# {'_id': ObjectId('5ac19b71a313fc02d6006fe0'),
#  'dateofbirth': datetime.datetime(1919, 7, 7, 0, 0),
#  'email': 'Bulma@Saiyan.com',
#  'firstname': 'Bulma',
#  'score': 2,
#  'surname': 'Saiyan',
#  'username': 'Bulma'}

# %%
for user in db.users.find({'score': {'$lte': 5}}).sort([('score', pymongo.DESCENDING)]):
    pprint.pprint(user)
# Out:
# {'_id': ObjectId('5ac19b70a313fc02d6006fda'),
#  'dateofbirth': datetime.datetime(1973, 7, 8, 0, 0),
#  'email': ['Goku@GokuBrown.com', 'Goku@NikBearBrown.com'],
#  'firstname': 'Goku',
#  'score': 5,
#  'surname': 'Brown',
#  'username': 'Goku'}
# {'_id': ObjectId('5ac19b71a313fc02d6006fe1'),
#  'dateofbirth': datetime.datetime(1955, 7, 7, 0, 0),
#  'email': 'Trunks@Saiyan.com',
#  'firstname': 'Trunks',
#  'score': 5,
#  'surname': 'Saiyan',
#  'username': 'Trunks'}
# {'_id': ObjectId('5ac19b71a313fc02d6006fdf'),
#  'dateofbirth': datetime.datetime(1903, 7, 7, 0, 0),
#  'email': 'Vegeta@Saiyan.com',
#  'firstname': 'Vegeta',
#  'score': 3,
#  'surname': 'Saiyan',
#  'username': 'Vegeta'}
# {'_id': ObjectId('5ac19b71a313fc02d6006fe0'),
#  'dateofbirth': datetime.datetime(1919, 7, 7, 0, 0),
#  'email': 'Bulma@Saiyan.com',
#  'firstname': 'Bulma',
#  'score': 2,
#  'surname': 'Saiyan',
#  'username': 'Bulma'}

# %% [markdown]
# ### Limit result size

# %%
for user in db.users.find({'score': {'$lte': 5}}).sort([('score', pymongo.DESCENDING)]).limit(2):
    pprint.pprint(user)
# Out:
# {'_id': ObjectId('5ac19b70a313fc02d6006fda'),
#  'dateofbirth': datetime.datetime(1973, 7, 8, 0, 0),
#  'email': ['Goku@GokuBrown.com', 'Goku@NikBearBrown.com'],
#  'firstname': 'Goku',
#  'score': 5,
#  'surname': 'Brown',
#  'username': 'Goku'}
# {'_id': ObjectId('5ac19b71a313fc02d6006fe1'),
#  'dateofbirth': datetime.datetime(1955, 7, 7, 0, 0),
#  'email': 'Trunks@Saiyan.com',
#  'firstname': 'Trunks',
#  'score': 5,
#  'surname': 'Saiyan',
#  'username': 'Trunks'}

# %%
def load_json(j):
    p=os.path.join("data/", j)
    print (p)
    with open(p, 'rU') as f:
      data = [json.loads(row) for row in f]
    return data

# %%
tweets_j=load_json('db_tweets.json')
tweets_j[0]
# Out:
# data/db_tweets.json
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sun Mar 15 21:41:22 +0000 2015',
#  'entities': {'hashtags': [{'indices': [128, 136], 'text': 'Bigdata'},
#    {'indices': [137, 140], 'text': 'IoT'},
#    {'indices': [139, 140], 'text': 'CIO'}],
#   'symbols': [],
#   'trends': [],
#   'urls': [{'display_url': 'bit.ly/1jvQFcK',
#     'expanded_url': 'http://bit.ly/1jvQFcK',
#     'indices': [105, 127],
#     'url': 'http://t.co/gLf50KtZKx'}],
#   'user_mentions': [{'id': 474651213,
#     'id_str': '474651213',
#     'indices': [3, 15],
#     'name': 'Marc Wilczek',
#     'screen_name': 'MarcWilczek'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'filter_level': 'low',
#  'geo': None,
#  'id': 577223085054558208,
#  'id_str': '577223085054558208',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'lang': 'en',
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 15 21:20:26 +0000 2015',
#   'entities': {'hashtags': [{'indices': [111, 119], 'text': 'Bigdata'},
#     {'indices': [120, 124], 'text': 'IoT'},
#     {'indices': [125, 129], 'text': 'CIO'}],
#    'symbols': [],
#    'trends': [],
#    'urls': [{'display_url': 'bit.ly/1jvQFcK',
#      'expanded_url': 'http://bit.ly/1jvQFcK',
#      'indices': [88, 110],
#      'url': 'http://t.co/gLf50KtZKx'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 577217818753548288,
#   'id_str': '577217818753548288',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'lang': 'en',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 1,
#   'retweeted': False,
#   'source': '<a href="http://twuffer.com" rel="nofollow">Twuffer</a>',
#   'text': 'In 2014, the digital universe equaled 1.7 megabytes a minute for every person on Earth: http://t.co/gLf50KtZKx #Bigdata #IoT #CIO',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Jan 26 06:24:30 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Passionate about Tech, Innovation, Strategy and Change. VP Portfolio, Innovation, Architecture @ T-Systems—Deutsche Telekom. Views are my own',
#    'favourites_count': 192,
#    'follow_request_sent': None,
#    'followers_count': 8726,
#    'following': None,
#    'friends_count': 599,
#    'geo_enabled': True,
#    'id': 474651213,
#    'id_str': '474651213',
#    'is_translator': False,
#    'lang': 'de',
#    'listed_count': 158,
#    'location': 'Frankfurt am Main, Germany',
#    'name': 'Marc Wilczek',
#    'notifications': None,
#    'profile_background_color': '030302',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/450722427484385281/kI1yHyhI.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/450722427484385281/kI1yHyhI.jpeg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/474651213/1396102695',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000687547211/66fbdde017be98bcb15ce759766e86cd_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000687547211/66fbdde017be98bcb15ce759766e86cd_normal.jpeg',
#    'profile_link_color': '786A55',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': '12291F',
#    'profile_text_color': '547B61',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'MarcWilczek',
#    'statuses_count': 8725,
#    'time_zone': None,
#    'url': 'http://www.marcwilczek.com',
#    'utc_offset': None,
#    'verified': False}},
#  'source': '<a href="http://www.simbasystems.com" rel="nofollow">NoSQLDigest</a>',
#  'text': 'RT @MarcWilczek: In 2014, the digital universe equaled 1.7 megabytes a minute for every person on Earth: http://t.co/gLf50KtZKx #Bigdata #I…',
#  'timestamp_ms': '1426455682420',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Sun Aug 03 17:07:24 +0000 2014',
#   'default_profile': True,
#   'default_profile_image': False,
#   'description': 'NoSQL Digest of tweets.',
#   'favourites_count': 72,
#   'follow_request_sent': None,
#   'followers_count': 5418,
#   'following': None,
#   'friends_count': 12,
#   'geo_enabled': False,
#   'id': 2704548373,
#   'id_str': '2704548373',
#   'is_translator': False,
#   'lang': 'en',
#   'listed_count': 1799,
#   'location': '',
#   'name': 'NoSQL',
#   'notifications': None,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/499257180009529344/CSWhr7LZ_normal.jpeg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/499257180009529344/CSWhr7LZ_normal.jpeg',
#   'profile_link_color': '0084B4',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'NoSQLDigest',
#   'statuses_count': 362920,
#   'time_zone': None,
#   'url': None,
#   'utc_offset': None,
#   'verified': False}}

# %%
print(tweets_j[0]['text'])
# Out:
# RT @MarcWilczek: In 2014, the digital universe equaled 1.7 megabytes a minute for every person on Earth: http://t.co/gLf50KtZKx #Bigdata #I…

# %%
tweets = pd.DataFrame(tweets_j)
tweets.head()
# Out:
#   contributors coordinates                      created_at  \
# 0         None        None  Sun Mar 15 21:41:22 +0000 2015
# 1         None        None  Sun Mar 15 21:41:30 +0000 2015
# 2         None        None  Sun Mar 15 21:41:31 +0000 2015
# 3         None        None  Sun Mar 15 21:41:40 +0000 2015
# 4         None        None  Sun Mar 15 21:41:46 +0000 2015
#
#                                             entities  \
# 0  {'hashtags': [{'text': 'Bigdata', 'indices': [...
# 1  {'hashtags': [], 'trends': [], 'urls': [], 'us...
# 2  {'hashtags': [{'text': 'AgTech', 'indices': [9...
# 3  {'hashtags': [{'text': 'cloud', 'indices': [92...
# 4  {'hashtags': [{'text': 'BigData', 'indices': [...
#
#                                    extended_entities  favorite_count  \
# 0                                                NaN               0
# 1                                                NaN               0
# 2                                                NaN               0
# 3  {'media': [{'id': 577217491841257473, 'id_str'...               0
# 4                                                NaN               0
#
#    favorited filter_level   geo                  id  \
# 0      False          low  None  577223085054558208
# 1      False          low  None  577223118327926785
# 2      False          low  None  577223124862697472
# 3      False          low  None  577223160195502080
# 4      False          low  None  577223187110330368
#
#                          ...                         place possibly_sensitive  \
# 0                        ...                          None              False
# 1                        ...                          None              False
# 2                        ...                          None              False
# 3                        ...                          None              False
# 4                        ...                          None              False
#
#    retweet_count retweeted                                   retweeted_status  \
# 0              0     False  {'created_at': 'Sun Mar 15 21:20:26 +0000 2015...
# 1              0     False                                                NaN
# 2              0     False  {'created_at': 'Sun Mar 15 21:20:02 +0000 2015...
# 3              0     False  {'created_at': 'Sun Mar 15 21:19:08 +0000 2015...
# 4              0     False  {'created_at': 'Sun Mar 15 21:18:55 +0000 2015...
#
#                                               source  \
# 0  <a href="http://www.simbasystems.com" rel="nof...
# 1  <a href="http://twitter.com" rel="nofollow">Tw...
# 2  <a href="http://www.simbasystems.com" rel="nof...
# 3  <a href="http://www.simbasystems.com" rel="nof...
# 4  <a href="http://www.simbasystems.com" rel="nof...
#
#                                                 text   timestamp_ms  \
# 0  RT @MarcWilczek: In 2014, the digital universe...  1426455682420
# 1                              Tanginang database to  1426455690353
# 2  RT @chrisco: The future of farming: robots + b...  1426455691911
# 3  RT @Brian_Singer_: The EMC Federation Joins th...  1426455700335
# 4  RT @execedia: Learn @execedia: The Business Be...  1426455706752
#
#    truncated                                               user
# 0      False  {'id': 2704548373, 'id_str': '2704548373', 'na...
# 1      False  {'id': 405481463, 'id_str': '405481463', 'name...
# 2      False  {'id': 2704548373, 'id_str': '2704548373', 'na...
# 3      False  {'id': 2704548373, 'id_str': '2704548373', 'na...
# 4      False  {'id': 2704548373, 'id_str': '2704548373', 'na...
#
# [5 rows x 27 columns]

# %%
db.tweets
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'analytics'), 'tweets')

# %%
cnt=0
for tweet in tweets_j:
    print("tweet ", cnt)
    cnt+=1
    pprint.pprint(tweet) 
    print()
# Out:
# tweet  0
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sun Mar 15 21:41:22 +0000 2015',
#  'entities': {'hashtags': [{'indices': [128, 136], 'text': 'Bigdata'},
#                            {'indices': [137, 140], 'text': 'IoT'},
#                            {'indices': [139, 140], 'text': 'CIO'}],
#               'symbols': [],
#               'trends': [],
#               'urls': [{'display_url': 'bit.ly/1jvQFcK',
#                         'expanded_url': 'http://bit.ly/1jvQFcK',
#                         'indices': [105, 127],
#                         'url': 'http://t.co/gLf50KtZKx'}],
#               'user_mentions': [{'id': 474651213,
#                                  'id_str': '474651213',
#                                  'indices': [3, 15],
#                                  'name': 'Marc Wilczek',
#                                  'screen_name': 'MarcWilczek'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'filter_level': 'low',
#  'geo': None,
#  'id': 577223085054558208,
#  'id_str': '577223085054558208',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'lang': 'en',
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#                       'coordinates': None,
#                       'created_at': 'Sun Mar 15 21:20:26 +0000 2015',
#                       'entities': {'hashtags': [{'indices': [111, 119],
#                                                  'text': 'Bigdata'},
#                                                 {'indices': [120, 124],
#                                                  'text': 'IoT'},
#                                                 {'indices': [125, 129],
#                                                  'text': 'CIO'}],
#                                    'symbols': [],
#                                    'trends': [],
#                                    'urls': [{'display_url': 'bit.ly/1jvQFcK',
#                                              'expanded_url': 'http://bit.ly/1jvQFcK',
#                                              'indices': [88, 110],
#                                              'url': 'http://t.co/gLf50KtZKx'}],
#                                    'user_mentions': []},
#                       'favorite_count': 0,
#                       'favorited': False,
#                       'filter_level': 'low',
#                       'geo': None,
#                       'id': 577217818753548288,
#                       'id_str': '577217818753548288',
#                       'in_reply_to_screen_name': None,
#                       'in_reply_to_status_id': None,
#                       'in_reply_to_status_id_str': None,
#                       'in_reply_to_user_id': None,
#                       'in_reply_to_user_id_str': None,
#                       'lang': 'en',
#                       'place': None,
#                       'possibly_sensitive': False,
#                       'retweet_count': 1,
#                       'retweeted': False,
#                       'source': '<a href="http://twuffer.com" '
#                                 'rel="nofollow">Twuffer</a>',
#                       'text': 'In 2014, the digital universe equaled 1.7 '
#                               'megabytes a minute for every person on Earth: '
#                               'http://t.co/gLf50KtZKx #Bigdata #IoT #CIO',
#                       'truncated': False,
#                       'user': {'contributors_enabled': False,
#                                'created_at': 'Thu Jan 26 06:24:30 +0000 2012',
#                                'default_profile': False,
#                                'default_profile_image': False,
#                                'description': 'Passionate about Tech, '
#                                               'Innovation, Strategy and '
#                                               'Change. VP Portfolio, '
#                                               'Innovation, Architecture @ '
#                                               'T-Systems—Deutsche Telekom. '
#                                               'Views are my own',
#                                'favourites_count': 192,
#                                'follow_request_sent': None,
#                                'followers_count': 8726,
#                                'following': None,
#                                'friends_count': 599,
#                                'geo_enabled': True,
#                                'id': 474651213,
#                                'id_str': '474651213',
#                                'is_translator': False,
#                                'lang': 'de',
#                                'listed_count': 158,
#                                'location': 'Frankfurt am Main, Germany',
#                                'name': 'Marc Wilczek',
#                                'notifications': None,
#                                'profile_background_color': '030302',
#                                'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/450722427484385281/kI1yHyhI.jpeg',
#                                'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/450722427484385281/kI1yHyhI.jpeg',
#                                'profile_background_tile': False,
#                                'profile_banner_url': 'https://pbs.twimg.com/profile_banners/474651213/1396102695',
#                                'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000687547211/66fbdde017be98bcb15ce759766e86cd_normal.jpeg',
#                                'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000687547211/66fbdde017be98bcb15ce759766e86cd_normal.jpeg',
#                                'profile_link_color': '786A55',
#                                'profile_sidebar_border_color': 'FFFFFF',
#                                'profile_sidebar_fill_color': '12291F',
#                                'profile_text_color': '547B61',
#                                'profile_use_background_image': False,
#                                'protected': False,
#                                'screen_name': 'MarcWilczek',
#                                'statuses_count': 8725,
#                                'time_zone': None,
#                                'url': 'http://www.marcwilczek.com',
#                                'utc_offset': None,
#                                'verified': False}},
#  'source': '<a href="http://www.simbasystems.com" '
#            'rel="nofollow">NoSQLDigest</a>',
#  'text': 'RT @MarcWilczek: In 2014, the digital universe equaled 1.7 megabytes '
#          'a minute for every person on Earth: http://t.co/gLf50KtZKx #Bigdata '
#          '#I…',
#  'timestamp_ms': '1426455682420',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sun Aug 03 17:07:24 +0000 2014',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': 'NoSQL Digest of tweets.',
#           'favourites_count': 72,
#           'follow_request_sent': None,
#           'followers_count': 5418,
#           'following': None,
#           'friends_count': 12,
#           'geo_enabled': False,
#           'id': 2704548373,
#           'id_str': '2704548373',
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 1799,
#           'location': '',
#           'name': 'NoSQL',
#           'notifications': None,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/499257180009529344/CSWhr7LZ_normal.jpeg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/499257180009529344/CSWhr7LZ_normal.jpeg',
#           'profile_link_color': '0084B4',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'NoSQLDigest',
#           'statuses_count': 362920,
#           'time_zone': None,
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}
# tweet  1
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sun Mar 15 21:41:30 +0000 2015',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'trends': [],
#               'urls': [],
#               'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'filter_level': 'low',
#  'geo': None,
#  'id': 577223118327926785,
#  'id_str': '577223118327926785',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'lang': 'tl',
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#  'text': 'Tanginang database to',
#  'timestamp_ms': '1426455690353',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sat Nov 05 11:21:24 +0000 2011',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'Sin is merely a matter of perspective',
#           'favourites_count': 2343,
#           'follow_request_sent': None,
#           'followers_count': 283,
#           'following': None,
#           'friends_count': 205,
#           'geo_enabled': True,
#           'id': 405481463,
#           'id_str': '405481463',
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 1,
#           'location': 'Manila, Philippines',
#           'name': 'Ian Hidalgo',
#           'notifications': None,
#           'profile_background_color': '1A1B1F',
#           'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/813697305/c21bb8a4d56a45476ab3e1046bd899bb.jpeg',
#           'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/813697305/c21bb8a4d56a45476ab3e1046bd899bb.jpeg',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/405481463/1397544353',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000672540493/4fe139d2c4c03ee2a1ac744f1003a19b_normal.jpeg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000672540493/4fe139d2c4c03ee2a1ac744f1003a19b_normal.jpeg',
#           'profile_link_color': '2FC2EF',
#           'profile_sidebar_border_color': 'FFFFFF',
#           'profile_sidebar_fill_color': '252429',
#           'profile_text_color': '666666',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'hidalgoian',
#           'statuses_count': 11313,
#           'time_zone': 'Hong Kong',
#           'url': None,
#           'utc_offset': 28800,
#           'verified': False}}
#
# tweet  2
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sun Mar 15 21:41:31 +0000 2015',
#  'entities': {'hashtags': [{'indices': [98, 105], 'text': 'AgTech'},
#                            {'indices': [106, 113], 'text': 'AgBots'},
#                            {'indices': [114, 123], 'text': 'Robotics'},
#                            {'indices': [124, 135], 'text': 'Automation'},
#                            {'indices': [136, 140], 'text': 'IoT'},
#                            {'indices': [139, 140], 'text': 'BigData'}],
#               'symbols': [],
#               'trends': [],
#               'urls': [{'display_url': 'buff.ly/1Aqvcbo',
#                         'expanded_url': 'http://buff.ly/1Aqvcbo',
#                         'indices': [55, 77],
#                         'url': 'http://t.co/MiEIZmKzEb'}],
#               'user_mentions': [{'id': 1861461,
#                                  'id_str': '1861461',
#                                  'indices': [3, 11],
#                                  'name': 'Chris Comella',
#                                  'screen_name': 'chrisco'},
#                                 {'id': 16838443,
#                                  'id_str': '16838443',
#                                  'indices': [82, 97],
#                                  'name': 'KurzweilAINews',
#                                  'screen_name': 'KurzweilAINews'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'filter_level': 'low',
#  'geo': None,
#  'id': 577223124862697472,
#  'id_str': '577223124862697472',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'lang': 'en',
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#                       'coordinates': None,
#                       'created_at': 'Sun Mar 15 21:20:02 +0000 2015',
#                       'entities': {'hashtags': [{'indices': [85, 92],
#                                                  'text': 'AgTech'},
#                                                 {'indices': [93, 100],
#                                                  'text': 'AgBots'},
#                                                 {'indices': [101, 110],
#                                                  'text': 'Robotics'},
#                                                 {'indices': [111, 122],
#                                                  'text': 'Automation'},
#                                                 {'indices': [123, 127],
#                                                  'text': 'IoT'},
#                                                 {'indices': [128, 136],
#                                                  'text': 'BigData'}],
#                                    'symbols': [],
#                                    'trends': [],
#                                    'urls': [{'display_url': 'buff.ly/1Aqvcbo',
#                                              'expanded_url': 'http://buff.ly/1Aqvcbo',
#                                              'indices': [42, 64],
#                                              'url': 'http://t.co/MiEIZmKzEb'}],
#                                    'user_mentions': [{'id': 16838443,
#                                                       'id_str': '16838443',
#                                                       'indices': [69, 84],
#                                                       'name': 'KurzweilAINews',
#                                                       'screen_name': 'KurzweilAINews'}]},
#                       'favorite_count': 5,
#                       'favorited': False,
#                       'filter_level': 'low',
#                       'geo': None,
#                       'id': 577217717926776832,
#                       'id_str': '577217717926776832',
#                       'in_reply_to_screen_name': None,
#                       'in_reply_to_status_id': None,
#                       'in_reply_to_status_id_str': None,
#                       'in_reply_to_user_id': None,
#                       'in_reply_to_user_id_str': None,
#                       'lang': 'en',
#                       'place': None,
#                       'possibly_sensitive': False,
#                       'retweet_count': 1,
#                       'retweeted': False,
#                       'source': '<a href="http://bufferapp.com" '
#                                 'rel="nofollow">Buffer</a>',
#                       'text': 'The future of farming: robots + big data: '
#                               'http://t.co/MiEIZmKzEb via @KurzweilAINews '
#                               '#AgTech #AgBots #Robotics #Automation #IoT '
#                               '#BigData',
#                       'truncated': False,
#                       'user': {'contributors_enabled': False,
#                                'created_at': 'Thu Mar 22 11:30:05 +0000 2007',
#                                'default_profile': False,
#                                'default_profile_image': False,
#                                'description': 'Georgetown Hoya. Software '
#                                               'Engineering + MBA. Startup, VC '
#                                               '+ international experience. '
#                                               'Into P2P marketplaces, P2P '
#                                               'lending, crowdfunding, machine '
#                                               'learning, Bitcoin',
#                                'favourites_count': 78,
#                                'follow_request_sent': None,
#                                'followers_count': 671,
#                                'following': None,
#                                'friends_count': 656,
#                                'geo_enabled': False,
#                                'id': 1861461,
#                                'id_str': '1861461',
#                                'is_translator': False,
#                                'lang': 'en',
#                                'listed_count': 32,
#                                'location': 'Boulder Denver FOCO DC Sweden',
#                                'name': 'Chris Comella',
#                                'notifications': None,
#                                'profile_background_color': 'FFFFFF',
#                                'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/3009334/twitter-buzzpal-bk.png',
#                                'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/3009334/twitter-buzzpal-bk.png',
#                                'profile_background_tile': True,
#                                'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1861461/1401205098',
#                                'profile_image_url': 'http://pbs.twimg.com/profile_images/471527205810352128/-5XxbXuA_normal.png',
#                                'profile_image_url_https': 'https://pbs.twimg.com/profile_images/471527205810352128/-5XxbXuA_normal.png',
#                                'profile_link_color': '00ADEE',
#                                'profile_sidebar_border_color': '999999',
#                                'profile_sidebar_fill_color': 'F3F3F3',
#                                'profile_text_color': '000000',
#                                'profile_use_background_image': True,
#                                'protected': False,
#                                'screen_name': 'chrisco',
#                                'statuses_count': 2395,
#                                'time_zone': 'Mountain Time (US & Canada)',
#                                'url': 'http://about.me/chrisco',
#                                'utc_offset': -21600,
#                                'verified': False}},
#  'source': '<a href="http://www.simbasystems.com" '
#            'rel="nofollow">NoSQLDigest</a>',
#  'text': 'RT @chrisco: The future of farming: robots + big data: '
#          'http://t.co/MiEIZmKzEb via @KurzweilAINews #AgTech #AgBots #Robotics '
#          '#Automation #Io…',
#  'timestamp_ms': '1426455691911',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sun Aug 03 17:07:24 +0000 2014',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': 'NoSQL Digest of tweets.',
#           'favourites_count': 72,
#           'follow_request_sent': None,
#           'followers_count': 5418,
#           'following': None,
#           'friends_count': 12,
#           'geo_enabled': False,
#           'id': 2704548373,
#           'id_str': '2704548373',
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 1799,
#           'location': '',
#           'name': 'NoSQL',
#           'notifications': None,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/499257180009529344/CSWhr7LZ_normal.jpeg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/499257180009529344/CSWhr7LZ_normal.jpeg',
#           'profile_link_color': '0084B4',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'NoSQLDigest',
#           'statuses_count': 362921,
#           'time_zone': None,
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}
#
# tweet  3
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sun Mar 15 21:41:40 +0000 2015',
#  'entities': {'hashtags': [{'indices': [92, 98], 'text': 'cloud'},
#                            {'indices': [99, 107], 'text': 'bigdata'},
#                            {'indices': [108, 112], 'text': 'aws'},
#                            {'indices': [113, 117], 'text': 'ec2'}],
#               'media': [{'display_url': 'pic.twitter.com/uYQIXOSMHs',
#                          'expanded_url': 'http://twitter.com/Brian_Singer_/status/577217492034166784/photo/1',
#                          'id': 577217491841257473,
#                          'id_str': '577217491841257473',
#                          'indices': [118, 140],
#                          'media_url': 'http://pbs.twimg.com/media/CAKwQCdXEAEwMrL.png',
#                          'media_url_https': 'https://pbs.twimg.com/media/CAKwQCdXEAEwMrL.png',
#                          'sizes': {'large': {'h': 1044,
#                                              'resize': 'fit',
#                                              'w': 1024},
#                                    'medium': {'h': 611,
#                                               'resize': 'fit',
#                                               'w': 600},
#                                    'small': {'h': 346,
#                                              'resize': 'fit',
#                                              'w': 340},
#                                    'thumb': {'h': 150,
#                                              'resize': 'crop',
#                                              'w': 150}},
#                          'source_status_id': 577217492034166784,
#                          'source_status_id_str': '577217492034166784',
#                          'type': 'photo',
#                          'url': 'http://t.co/uYQIXOSMHs'}],
#               'symbols': [],
#               'trends': [],
#               'urls': [{'display_url': 'vytm.in/gV_k7w',
#                         'expanded_url': 'http://vytm.in/gV_k7w',
#                         'indices': [69, 91],
#                         'url': 'http://t.co/i37gbFthQw'}],
#               'user_mentions': [{'id': 1960998554,
#                                  'id_str': '1960998554',
#                                  'indices': [3, 17],
#                                  'name': 'Brian S',
#                                  'screen_name': 'Brian_Singer_'}]},
#  'extended_entities': {'media': [{'display_url': 'pic.twitter.com/uYQIXOSMHs',
#                                   'expanded_url': 'http://twitter.com/Brian_Singer_/status/577217492034166784/photo/1',
#                                   'id': 577217491841257473,
#                                   'id_str': '577217491841257473',
#                                   'indices': [118, 140],
#                                   'media_url': 'http://pbs.twimg.com/media/CAKwQCdXEAEwMrL.png',
#                                   'media_url_https': 'https://pbs.twimg.com/media/CAKwQCdXEAEwMrL.png',
#                                   'sizes': {'large': {'h': 1044,
#                                                       'resize': 'fit',
#                                                       'w': 1024},
#                                             'medium': {'h': 611,
#                                                        'resize': 'fit',
#                                                        'w': 600},
#                                             'small': {'h': 346,
#                                                       'resize': 'fit',
#                                                       'w': 340},
#                                             'thumb': {'h': 150,
#                                                       'resize': 'crop',
#                                                       'w': 150}},
#                                   'source_status_id': 577217492034166784,
#                                   'source_status_id_str': '577217492034166784',
#                                   'type': 'photo',
#                                   'url': 'http://t.co/uYQIXOSMHs'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'filter_level': 'low',
#  'geo': None,
#  'id': 577223160195502080,
#  'id_str': '577223160195502080',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'lang': 'en',
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#                       'coordinates': None,
#                       'created_at': 'Sun Mar 15 21:19:08 +0000 2015',
#                       'entities': {'hashtags': [{'indices': [73, 79],
#                                                  'text': 'cloud'},
#                                                 {'indices': [80, 88],
#                                                  'text': 'bigdata'},
#                                                 {'indices': [89, 93],
#                                                  'text': 'aws'},
#                                                 {'indices': [94, 98],
#                                                  'text': 'ec2'}],
#                                    'media': [{'display_url': 'pic.twitter.com/uYQIXOSMHs',
#                                               'expanded_url': 'http://twitter.com/Brian_Singer_/status/577217492034166784/photo/1',
#                                               'id': 577217491841257473,
#                                               'id_str': '577217491841257473',
#                                               'indices': [99, 121],
#                                               'media_url': 'http://pbs.twimg.com/media/CAKwQCdXEAEwMrL.png',
#                                               'media_url_https': 'https://pbs.twimg.com/media/CAKwQCdXEAEwMrL.png',
#                                               'sizes': {'large': {'h': 1044,
#                                                                   'resize': 'fit',
#                                                                   'w': 1024},
#                                                         'medium': {'h': 611,
#                                                                    'resize': 'fit',
#                                                                    'w': 600},
#                                                         'small': {'h': 346,
#                                                                   'resize': 'fit',
#                                                                   'w': 340},
#                                                         'thumb': {'h': 150,
#                                                                   'resize': 'crop',
#                                                                   'w': 150}},
#                                               'type': 'photo',
#                                               'url': 'http://t.co/uYQIXOSMHs'}],
#                                    'symbols': [],
#                                    'trends': [],
#                                    'urls': [{'display_url': 'vytm.in/gV_k7w',
#                                              'expanded_url': 'http://vytm.in/gV_k7w',
#                                              'indices': [50, 72],
#                                              'url': 'http://t.co/i37gbFthQw'}],
#                                    'user_mentions': []},
#                       'extended_entities': {'media': [{'display_url': 'pic.twitter.com/uYQIXOSMHs',
#                                                        'expanded_url': 'http://twitter.com/Brian_Singer_/status/577217492034166784/photo/1',
#                                                        'id': 577217491841257473,
#                                                        'id_str': '577217491841257473',
#                                                        'indices': [99, 121],
#                                                        'media_url': 'http://pbs.twimg.com/media/CAKwQCdXEAEwMrL.png',
#                                                        'media_url_https': 'https://pbs.twimg.com/media/CAKwQCdXEAEwMrL.png',
#                                                        'sizes': {'large': {'h': 1044,
#                                                                            'resize': 'fit',
#                                                                            'w': 1024},
#                                                                  'medium': {'h': 611,
#                                                                             'resize': 'fit',
#                                                                             'w': 600},
#                                                                  'small': {'h': 346,
#                                                                            'resize': 'fit',
#                                                                            'w': 340},
#                                                                  'thumb': {'h': 150,
#                                                                            'resize': 'crop',
#                                                                            'w': 150}},
#                                                        'type': 'photo',
#                                                        'url': 'http://t.co/uYQIXOSMHs'}]},
#                       'favorite_count': 2,
#                       'favorited': False,
#                       'filter_level': 'low',
#                       'geo': None,
#                       'id': 577217492034166784,
#                       'id_str': '577217492034166784',
#                       'in_reply_to_screen_name': None,
#                       'in_reply_to_status_id': None,
#                       'in_reply_to_status_id_str': None,
#                       'in_reply_to_user_id': None,
#                       'in_reply_to_user_id_str': None,
#                       'lang': 'en',
#                       'place': None,
#                       'possibly_sensitive': False,
#                       'retweet_count': 2,
#                       'retweeted': False,
#                       'source': '<a href="http://app.vytmn.com/" '
#                                 'rel="nofollow">Vytmn</a>',
#                       'text': 'The EMC Federation Joins the OpenStack '
#                               'Foundation http://t.co/i37gbFthQw #cloud '
#                               '#bigdata #aws #ec2 http://t.co/uYQIXOSMHs',
#                       'truncated': False,
#                       'user': {'contributors_enabled': False,
#                                'created_at': 'Mon Oct 14 16:30:38 +0000 2013',
#                                'default_profile': False,
#                                'default_profile_image': False,
#                                'description': 'Cofounder @Orbitera Experienced '
#                                               'technology professional w/ '
#                                               'focus on bizdev & marketing. '
#                                               'In-depth knowledge of cloud & '
#                                               'SaaS technologies and market.  '
#                                               'Lets chat.',
#                                'favourites_count': 0,
#                                'follow_request_sent': None,
#                                'followers_count': 656,
#                                'following': None,
#                                'friends_count': 1970,
#                                'geo_enabled': False,
#                                'id': 1960998554,
#                                'id_str': '1960998554',
#                                'is_translator': False,
#                                'lang': 'en',
#                                'listed_count': 33,
#                                'location': 'Greater Boston Area',
#                                'name': 'Brian S',
#                                'notifications': None,
#                                'profile_background_color': '000000',
#                                'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme12/bg.gif',
#                                'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme12/bg.gif',
#                                'profile_background_tile': False,
#                                'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1960998554/1424768538',
#                                'profile_image_url': 'http://pbs.twimg.com/profile_images/570147174319534080/K3Ed1-e6_normal.jpeg',
#                                'profile_image_url_https': 'https://pbs.twimg.com/profile_images/570147174319534080/K3Ed1-e6_normal.jpeg',
#                                'profile_link_color': '3B94D9',
#                                'profile_sidebar_border_color': '000000',
#                                'profile_sidebar_fill_color': '000000',
#                                'profile_text_color': '000000',
#                                'profile_use_background_image': False,
#                                'protected': False,
#                                'screen_name': 'Brian_Singer_',
#                                'statuses_count': 124,
#                                'time_zone': 'Pacific Time (US & Canada)',
#                                'url': 'http://Orbitera.com',
#                                'utc_offset': -25200,
#                                'verified': False}},
#  'source': '<a href="http://www.simbasystems.com" '
#            'rel="nofollow">NoSQLDigest</a>',
#  'text': 'RT @Brian_Singer_: The EMC Federation Joins the OpenStack Foundation '
#          'http://t.co/i37gbFthQw #cloud #bigdata #aws #ec2 '
#          'http://t.co/uYQIXOSMHs',
#  'timestamp_ms': '1426455700335',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sun Aug 03 17:07:24 +0000 2014',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': 'NoSQL Digest of tweets.',
#           'favourites_count': 72,
#           'follow_request_sent': None,
#           'followers_count': 5418,
#           'following': None,
#           'friends_count': 12,
#           'geo_enabled': False,
#           'id': 2704548373,
#           'id_str': '2704548373',
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 1799,
#           'location': '',
#           'name': 'NoSQL',
#           'notifications': None,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/499257180009529344/CSWhr7LZ_normal.jpeg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/499257180009529344/CSWhr7LZ_normal.jpeg',
#           'profile_link_color': '0084B4',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'NoSQLDigest',
#           'statuses_count': 362922,
#           'time_zone': None,
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}
#
# tweet  4
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sun Mar 15 21:41:46 +0000 2015',
#  'entities': {'hashtags': [{'indices': [89, 97], 'text': 'BigData'}],
#               'symbols': [],
#               'trends': [],
#               'urls': [{'display_url': 'bit.ly/1jYvuhT',
#                         'expanded_url': 'http://bit.ly/1jYvuhT',
#                         'indices': [65, 87],
#                         'url': 'http://t.co/uQSGCKEiOn'}],
#               'user_mentions': [{'id': 1240314464,
#                                  'id_str': '1240314464',
#                                  'indices': [3, 12],
#                                  'name': 'execedia',
#                                  'screen_name': 'execedia'},
#                                 {'id': 1240314464,
#                                  'id_str': '1240314464',
#                                  'indices': [20, 29],
#                                  'name': 'execedia',
#                                  'screen_name': 'execedia'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'filter_level': 'low',
#  'geo': None,
#  'id': 577223187110330368,
#  'id_str': '577223187110330368',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'lang': 'en',
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#                       'coordinates': None,
#                       'created_at': 'Sun Mar 15 21:18:55 +0000 2015',
#                       'entities': {'hashtags': [{'indices': [75, 83],
#                                                  'text': 'BigData'}],
#                                    'symbols': [],
#                                    'trends': [],
#                                    'urls': [{'display_url': 'bit.ly/1jYvuhT',
#                                              'expanded_url': 'http://bit.ly/1jYvuhT',
#                                              'indices': [51, 73],
#                                              'url': 'http://t.co/uQSGCKEiOn'}],
#                                    'user_mentions': [{'id': 1240314464,
#                                                       'id_str': '1240314464',
#                                                       'indices': [6, 15],
#                                                       'name': 'execedia',
#                                                       'screen_name': 'execedia'}]},
#                       'favorite_count': 0,
#                       'favorited': False,
#                       'filter_level': 'low',
#                       'geo': None,
#                       'id': 577217437701115904,
#                       'id_str': '577217437701115904',
#                       'in_reply_to_screen_name': None,
#                       'in_reply_to_status_id': None,
#                       'in_reply_to_status_id_str': None,
#                       'in_reply_to_user_id': None,
#                       'in_reply_to_user_id_str': None,
#                       'lang': 'en',
#                       'place': None,
#                       'possibly_sensitive': False,
#                       'retweet_count': 1,
#                       'retweeted': False,
#                       'source': '<a href="http://winthecustomer.com/" '
#                                 'rel="nofollow">Win the Customer</a>',
#                       'text': 'Learn @execedia: The Business Benefits of Big '
#                               'Data http://t.co/uQSGCKEiOn\n'
#                               ' #BigData',
#                       'truncated': False,
#                       'user': {'contributors_enabled': False,
#                                'created_at': 'Mon Mar 04 02:27:25 +0000 2013',
#                                'default_profile': True,
#                                'default_profile_image': False,
#                                'description': 'marketplace for management '
#                                               'insight',
#                                'favourites_count': 5,
#                                'follow_request_sent': None,
#                                'followers_count': 499,
#                                'following': None,
#                                'friends_count': 1730,
#                                'geo_enabled': False,
#                                'id': 1240314464,
#                                'id_str': '1240314464',
#                                'is_translator': False,
#                                'lang': 'en',
#                                'listed_count': 92,
#                                'location': '',
#                                'name': 'execedia',
#                                'notifications': None,
#                                'profile_background_color': 'C0DEED',
#                                'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                                'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                                'profile_background_tile': False,
#                                'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1240314464/1362364684',
#                                'profile_image_url': 'http://pbs.twimg.com/profile_images/3399055805/93c1e88ab6e8a397c1aa8fd5ad37d83b_normal.png',
#                                'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3399055805/93c1e88ab6e8a397c1aa8fd5ad37d83b_normal.png',
#                                'profile_link_color': '0084B4',
#                                'profile_sidebar_border_color': 'C0DEED',
#                                'profile_sidebar_fill_color': 'DDEEF6',
#                                'profile_text_color': '333333',
#                                'profile_use_background_image': True,
#                                'protected': False,
#                                'screen_name': 'execedia',
#                                'statuses_count': 15336,
#                                'time_zone': 'Atlantic Time (Canada)',
#                                'url': 'http://execedia.com',
#                                'utc_offset': -10800,
#                                'verified': False}},
#  'source': '<a href="http://www.simbasystems.com" '
#            'rel="nofollow">NoSQLDigest</a>',
#  'text': 'RT @execedia: Learn @execedia: The Business Benefits of Big Data '
#          'http://t.co/uQSGCKEiOn\n'
#          ' #BigData',
#  'timestamp_ms': '1426455706752',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sun Aug 03 17:07:24 +0000 2014',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': 'NoSQL Digest of tweets.',
#           'favourites_count': 72,
#           'follow_request_sent': None,
#           'followers_count': 5418,
#           'following': None,
#           'friends_count': 12,
#           'geo_enabled': False,
#           'id': 2704548373,
#           'id_str': '2704548373',
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 1799,
#           'location': '',
#           'name': 'NoSQL',
#           'notifications': None,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/499257180009529344/CSWhr7LZ_normal.jpeg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/499257180009529344/CSWhr7LZ_normal.jpeg',
#           'profile_link_color': '0084B4',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'NoSQLDigest',
#           'statuses_count': 362923,
#           'time_zone': None,
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}
#
# tweet  5
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sun Mar 15 21:41:54 +0000 2015',
#  'entities': {'hashtags': [{'indices': [42, 50], 'text': 'bigdata'},
#                            {'indices': [106, 117], 'text': 'natgeosxsw'}],
#               'symbols': [],
#               'trends': [],
#               'urls': [],
#               'user_mentions': [{'id': 17027993,
#                                  'id_str': '17027993',
#                                  'indices': [3, 16],
#                                  'name': 'Stephanie B.',
#                                  'screen_name': 'RiverCityGal'},
#                                 {'id': 24024778,
#                                  'id_str': '24024778',
#                                  'indices': [97, 105],
#                                  'name': 'Kal Penn',
#                                  'screen_name': 'kalpenn'},
#                                 {'id': 18244358,
#                                  'id_str': '18244358',
#                                  'indices': [118, 132],
#                                  'name': 'Nat Geo Channel',
#                                  'screen_name': 'NatGeoChannel'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'filter_level': 'low',
#  'geo': None,
#  'id': 577223217942691840,
#  'id_str': '577223217942691840',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'lang': 'en',
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#                       'coordinates': None,
#                       'created_at': 'Sun Mar 15 21:09:35 +0000 2015',
#                       'entities': {'hashtags': [{'indices': [24, 32],
#                                                  'text': 'bigdata'},
#                                                 {'indices': [88, 99],
#                                                  'text': 'natgeosxsw'}],
#                                    'symbols': [],
#                                    'trends': [],
#                                    'urls': [],
#                                    'user_mentions': [{'id': 24024778,
#                                                       'id_str': '24024778',
#                                                       'indices': [79, 87],
#                                                       'name': 'Kal Penn',
#                                                       'screen_name': 'kalpenn'},
#                                                      {'id': 18244358,
#                                                       'id_str': '18244358',
#                                                       'indices': [100, 114],
#                                                       'name': 'Nat Geo Channel',
#                                                       'screen_name': 'NatGeoChannel'}]},
#                       'favorite_count': 9,
#                       'favorited': False,
#                       'filter_level': 'low',
#                       'geo': None,
#                       'id': 577215087611498496,
#                       'id_str': '577215087611498496',
#                       'in_reply_to_screen_name': None,
#                       'in_reply_to_status_id': None,
#                       'in_reply_to_status_id_str': None,
# ...
#                                                  'text': 'Cloud'}],
#                                    'symbols': [],
#                                    'trends': [],
#                                    'urls': [{'display_url': 'huffingtonpost.com/young-entrepre…',
#                                              'expanded_url': 'http://www.huffingtonpost.com/young-entrepreneur-council/where-is-all-the-big-data_b_6808412.html?utm_hp_ref=tw',
#                                              'indices': [67, 89],
#                                              'url': 'http://t.co/fg3Ym2CtOA'}],
#                                    'user_mentions': []},
#                       'favorite_count': 3,
#                       'favorited': False,
#                       'filter_level': 'low',
#                       'geo': None,
#                       'id': 577225277396377600,
#                       'id_str': '577225277396377600',
#                       'in_reply_to_screen_name': None,
#                       'in_reply_to_status_id': None,
#                       'in_reply_to_status_id_str': None,
#                       'in_reply_to_user_id': None,
#                       'in_reply_to_user_id_str': None,
#                       'lang': 'en',
#                       'place': None,
#                       'possibly_sensitive': False,
#                       'retweet_count': 2,
#                       'retweeted': False,
#                       'source': '<a href="http://www.hootsuite.com" '
#                                 'rel="nofollow">Hootsuite</a>',
#                       'text': '4 Ways the Future of Big Data Will Change the '
#                               'Way We Work and Live http://t.co/fg3Ym2CtOA '
#                               '#BigData #Cloud',
#                       'truncated': False,
#                       'user': {'contributors_enabled': False,
#                                'created_at': 'Sat May 23 19:09:46 +0000 2009',
#                                'default_profile': False,
#                                'default_profile_image': False,
#                                'description': 'Product Marketing Manager. '
#                                               'Master Data Management, Data '
#                                               'Quality & Data Governance '
#                                               'Blogger. Data Science, Hadoop, '
#                                               'Big Data & Cloud. Porsche fan. '
#                                               'My Opinions!',
#                                'favourites_count': 2104,
#                                'follow_request_sent': None,
#                                'followers_count': 6269,
#                                'following': None,
#                                'friends_count': 2858,
#                                'geo_enabled': True,
#                                'id': 42079656,
#                                'id_str': '42079656',
#                                'is_translator': False,
#                                'lang': 'en',
#                                'listed_count': 392,
#                                'location': 'San Francisco CA',
#                                'name': 'Prash Chan',
#                                'notifications': None,
#                                'profile_background_color': 'FFF04D',
#                                'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/695534328/af198d66684bbd5a8f4a596e7453080d.jpeg',
#                                'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/695534328/af198d66684bbd5a8f4a596e7453080d.jpeg',
#                                'profile_background_tile': True,
#                                'profile_banner_url': 'https://pbs.twimg.com/profile_banners/42079656/1385777135',
#                                'profile_image_url': 'http://pbs.twimg.com/profile_images/1220200142/dilbert_normal.jpg',
#                                'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1220200142/dilbert_normal.jpg',
#                                'profile_link_color': '0099CC',
#                                'profile_sidebar_border_color': 'FFFFFF',
#                                'profile_sidebar_fill_color': 'F6FFD1',
#                                'profile_text_color': '333333',
#                                'profile_use_background_image': True,
#                                'protected': False,
#                                'screen_name': 'MDMGeek',
#                                'statuses_count': 23575,
#                                'time_zone': 'Eastern Time (US & Canada)',
#                                'url': 'http://www.mdmgeek.com/',
#                                'utc_offset': -14400,
#                                'verified': False}},
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'text': 'RT @MDMGeek: 4 Ways the Future of Big Data Will Change the Way We '
#          'Work and Live http://t.co/fg3Ym2CtOA #BigData #Cloud',
#  'timestamp_ms': '1426456502037',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Mon Sep 29 13:18:07 +0000 2014',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'Industry Expert @themanufacturer. Love  photography, '
#                          'carpentry, and all social media! #ukmfg #smac '
#                          '#bigdata #IoT #cloud #analytics #decodethenoise',
#           'favourites_count': 525,
#           'follow_request_sent': None,
#           'followers_count': 1656,
#           'following': None,
#           'friends_count': 2002,
#           'geo_enabled': True,
#           'id': 2791608621,
#           'id_str': '2791608621',
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 277,
#           'location': 'London',
#           'name': 'Nicholas James Cox',
#           'notifications': None,
#           'profile_background_color': '000000',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2791608621/1416079512',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/520316246902849536/QiqOCINJ_normal.jpeg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/520316246902849536/QiqOCINJ_normal.jpeg',
#           'profile_link_color': '3B94D9',
#           'profile_sidebar_border_color': '000000',
#           'profile_sidebar_fill_color': '000000',
#           'profile_text_color': '000000',
#           'profile_use_background_image': False,
#           'protected': False,
#           'screen_name': 'Nicholas_TM',
#           'statuses_count': 5654,
#           'time_zone': None,
#           'url': 'http://www.themanufacturer.com',
#           'utc_offset': None,
#           'verified': False}}
#
# tweet  166
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sun Mar 15 21:55:02 +0000 2015',
#  'entities': {'hashtags': [{'indices': [80, 84], 'text': 'crm'},
#                            {'indices': [85, 91], 'text': 'sales'},
#                            {'indices': [92, 100], 'text': 'bigdata'}],
#               'symbols': [],
#               'trends': [],
#               'urls': [{'display_url': 'RealZips.com/seven',
#                         'expanded_url': 'http://RealZips.com/seven',
#                         'indices': [57, 79],
#                         'url': 'http://t.co/lJ02A2mMdc'}],
#               'user_mentions': [{'id': 928784881,
#                                  'id_str': '928784881',
#                                  'indices': [3, 12],
#                                  'name': 'RealZips',
#                                  'screen_name': 'realzips'},
#                                 {'id': 241034011,
#                                  'id_str': '241034011',
#                                  'indices': [14, 22],
#                                  'name': 'David Giner',
#                                  'screen_name': 'dginerh'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'filter_level': 'low',
#  'geo': None,
#  'id': 577226526778728448,
#  'id_str': '577226526778728448',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'lang': 'en',
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#                       'coordinates': None,
#                       'created_at': 'Sun Mar 15 21:29:29 +0000 2015',
#                       'entities': {'hashtags': [{'indices': [66, 70],
#                                                  'text': 'crm'},
#                                                 {'indices': [71, 77],
#                                                  'text': 'sales'},
#                                                 {'indices': [78, 86],
#                                                  'text': 'bigdata'}],
#                                    'symbols': [],
#                                    'trends': [],
#                                    'urls': [{'display_url': 'RealZips.com/seven',
#                                              'expanded_url': 'http://RealZips.com/seven',
#                                              'indices': [43, 65],
#                                              'url': 'http://t.co/lJ02A2mMdc'}],
#                                    'user_mentions': [{'id': 241034011,
#                                                       'id_str': '241034011',
#                                                       'indices': [0, 8],
#                                                       'name': 'David Giner',
#                                                       'screen_name': 'dginerh'}]},
#                       'favorite_count': 1,
#                       'favorited': False,
#                       'filter_level': 'low',
#                       'geo': None,
#                       'id': 577220095392542720,
#                       'id_str': '577220095392542720',
#                       'in_reply_to_screen_name': 'dginerh',
#                       'in_reply_to_status_id': None,
#                       'in_reply_to_status_id_str': None,
#                       'in_reply_to_user_id': 241034011,
#                       'in_reply_to_user_id_str': '241034011',
#                       'lang': 'en',
#                       'place': None,
#                       'possibly_sensitive': False,
#                       'retweet_count': 1,
#                       'retweeted': False,
#                       'source': '<a href="http://twitter.com/download/iphone" '
#                                 'rel="nofollow">Twitter for iPhone</a>',
#                       'text': '@dginerh thank you for RealZips Fav! Check '
#                               'http://t.co/lJ02A2mMdc #crm #sales #bigdata',
#                       'truncated': False,
#                       'user': {'contributors_enabled': False,
#                                'created_at': 'Tue Nov 06 01:40:18 +0000 2012',
#                                'default_profile': False,
#                                'default_profile_image': False,
#                                'description': 'http://RealZips.com: Unique app '
#                                               'for Salesforce. GeoData for '
#                                               'Sales Intelligence. #Salesforce '
#                                               '#AppExchange #CRM #Sales '
#                                               '#BigData #IoT',
#                                'favourites_count': 1209,
#                                'follow_request_sent': None,
#                                'followers_count': 216,
#                                'following': None,
#                                'friends_count': 215,
#                                'geo_enabled': False,
#                                'id': 928784881,
#                                'id_str': '928784881',
#                                'is_translator': False,
#                                'lang': 'en',
#                                'listed_count': 97,
#                                'location': 'Ft Lauderdale, Sta Monica, NYC',
#                                'name': 'RealZips',
#                                'notifications': None,
#                                'profile_background_color': 'C0DEED',
#                                'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000161818910/oDKN6nWQ.jpeg',
#                                'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000161818910/oDKN6nWQ.jpeg',
#                                'profile_background_tile': False,
#                                'profile_banner_url': 'https://pbs.twimg.com/profile_banners/928784881/1404767428',
#                                'profile_image_url': 'http://pbs.twimg.com/profile_images/414210718309687296/1_7rF3Uo_normal.png',
#                                'profile_image_url_https': 'https://pbs.twimg.com/profile_images/414210718309687296/1_7rF3Uo_normal.png',
#                                'profile_link_color': '0084B4',
#                                'profile_sidebar_border_color': 'FFFFFF',
#                                'profile_sidebar_fill_color': 'DDEEF6',
#                                'profile_text_color': '333333',
#                                'profile_use_background_image': True,
#                                'protected': False,
#                                'screen_name': 'realzips',
#                                'statuses_count': 2593,
#                                'time_zone': None,
#                                'url': 'http://realzips.com',
#                                'utc_offset': None,
#                                'verified': False}},
#  'source': '<a href="http://www.simbasystems.com" '
#            'rel="nofollow">NoSQLDigest</a>',
#  'text': 'RT @realzips: @dginerh thank you for RealZips Fav! Check '
#          'http://t.co/lJ02A2mMdc #crm #sales #bigdata',
#  'timestamp_ms': '1426456502991',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sun Aug 03 17:07:24 +0000 2014',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': 'NoSQL Digest of tweets.',
#           'favourites_count': 72,
#           'follow_request_sent': None,
#           'followers_count': 5421,
#           'following': None,
#           'friends_count': 12,
#           'geo_enabled': False,
#           'id': 2704548373,
#           'id_str': '2704548373',
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 1838,
#           'location': '',
#           'name': 'NoSQL',
#           'notifications': None,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/499257180009529344/CSWhr7LZ_normal.jpeg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/499257180009529344/CSWhr7LZ_normal.jpeg',
#           'profile_link_color': '0084B4',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'NoSQLDigest',
#           'statuses_count': 362947,
#           'time_zone': None,
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}

# %%
cnt=0
for tweet in tweets_j:
    print (tweet['id'])    
    print (tweet['text'])    
    print (tweet['created_at'])
# Out:
# 577223085054558208
# RT @MarcWilczek: In 2014, the digital universe equaled 1.7 megabytes a minute for every person on Earth: http://t.co/gLf50KtZKx #Bigdata #I…
# Sun Mar 15 21:41:22 +0000 2015
# 577223118327926785
# Tanginang database to
# Sun Mar 15 21:41:30 +0000 2015
# 577223124862697472
# RT @chrisco: The future of farming: robots + big data: http://t.co/MiEIZmKzEb via @KurzweilAINews #AgTech #AgBots #Robotics #Automation #Io…
# Sun Mar 15 21:41:31 +0000 2015
# 577223160195502080
# RT @Brian_Singer_: The EMC Federation Joins the OpenStack Foundation http://t.co/i37gbFthQw #cloud #bigdata #aws #ec2 http://t.co/uYQIXOSMHs
# Sun Mar 15 21:41:40 +0000 2015
# 577223187110330368
# RT @execedia: Learn @execedia: The Business Benefits of Big Data http://t.co/uQSGCKEiOn
#  #BigData
# Sun Mar 15 21:41:46 +0000 2015
# 577223217942691840
# RT @RiverCityGal: The goal is not to keep #bigdata scary but to turn it into something beautiful @kalpenn #natgeosxsw @NatGeoChannel
# Sun Mar 15 21:41:54 +0000 2015
# 577223226444509185
# RT @TheHesterView: MT .@techrepublic WhiteHouse + climate change: hackathons, crowdsourcing, #bigdata http://t.co/6HWjCv3BL5 Lets join in! …
# Sun Mar 15 21:41:56 +0000 2015
# 577223237140148224
# @TurnupPrince if there was some sort of list or database? There is a general rating list, but i don't think it addresses this specifically
# Sun Mar 15 21:41:58 +0000 2015
# 577223250566082560
# Can you replace a recruiter with an algorithm? http://t.co/rLNk2UtnkL
# Sun Mar 15 21:42:01 +0000 2015
# 577223265891934208
# RT @DataScientistFr: Leading Marketing Excellence With Analytics http://t.co/92XV9CUUpO #BigData #Analytics
# Sun Mar 15 21:42:05 +0000 2015
# 577223326289956864
# RT @MatthewB_SEA: Cisco, HP keep the lead in cloud infrastructure http://t.co/fi0MuG9QUH #cloud #amazon #ec2 #bigdata #IT http://t.co/jRLp7…
# Sun Mar 15 21:42:19 +0000 2015
# 577223344141025280
# RT @pritishajoshi: The Geeks Arrive In HR:  People #Analytics Is Here http://t.co/w4xw93Tw19 via @forbes #HRtech #HR #People #Cloud #BigData
# Sun Mar 15 21:42:24 +0000 2015
# 577223365594779648
# RT @Firas_Orbitera: Box raises $175m with IPO, but what is next?  http://t.co/wdK8JZM7db #cloud #amazon #aws #bigdata
# Sun Mar 15 21:42:29 +0000 2015
# 577223397047803904
# RT @CarvMoore: FCC Takes Defensive Legal Stance in 300-Page Open Internet Order http://t.co/tkSfjPpods #data #IT #cloud #bigdata #aws
# Sun Mar 15 21:42:36 +0000 2015
# 577223432296755200
# RT @BIG_DATA_News: Take holistic approach to improve rail reliability: The LTA and SMRT should perhaps incorporate and l... http://t.co/mM0…
# Sun Mar 15 21:42:45 +0000 2015
# 577223448004526080
# RT @caitlinrgreen: Translation of early 11thC runes: 'Óðinn and Heimdallr and Þjálfa, they help thee, Úlfljótr...' (trans. John Hines, http…
# Sun Mar 15 21:42:48 +0000 2015
# 577223448503705603
# RT @KirkDBorne: New breed of scientific researchers, #DataScientists, must be Pi-shaped: https://t.co/BGmnXAOlIY #BigData by @jakevdp http:…
# Sun Mar 15 21:42:49 +0000 2015
# 577223465255759872
# Many websites send out lists of ebooks.The Fussy Librarian uses a database to find novels you'll love: Subscribe now http://t.co/EBChICLch2
# Sun Mar 15 21:42:53 +0000 2015
# 577223468284035073
# RT @caitlinrgreen: This is quite nice too--early 11C runic inscription from Saltfleetby, Lincs, mentions Odin etc http://t.co/SgcfxbdQvZ ht…
# Sun Mar 15 21:42:53 +0000 2015
# 577223480548061184
# RT @CANSQL: Congratulations to #BigData #Hackathon winners in Data Visualization Category: Parking Tickets and Air Flights  #BDH http://t.c…
# Sun Mar 15 21:42:56 +0000 2015
# 577223496767406080
# RT @bobehayes: Be precise about meaning of the data 》Datafloq - Transparency Is Not Enough http://t.co/Jfh5Xc2hQz ht @VanRijmenam #BigData …
# Sun Mar 15 21:43:00 +0000 2015
# 577223532230283264
# RT @RFA_Reading: This is why I wanted to be involved with #sme across the #thamesvalley with #bigdata http://t.co/SIHVND8mDY
# Sun Mar 15 21:43:09 +0000 2015
# 577223536256765952
# RT @CANSQL: Congratulation to #BigData #Hackathon winners in Data Modelling: Toronto Parking Ticket Revenue Forecaster project http://t.co/…
# Sun Mar 15 21:43:09 +0000 2015
# 577223560718086145
# RT @phpusers: Re: Waiting for localhost http://t.co/OGcvtI1663  #php #database
# Sun Mar 15 21:43:15 +0000 2015
# 577223563372941313
# @Aalimah_aah I pull html source from a http://t.co/n5kJRoYydW list &amp; dump into a database.
# Sun Mar 15 21:43:16 +0000 2015
# 577223601696309249
# In your brain are stored hundreds of millions of data and imagery, but the brain is not simply a database.
# Sun Mar 15 21:43:25 +0000 2015
# 577223674400534529
# "Algorithm Clones Facial Expressions and Pastes Them onto Other Faces" https://t.co/TzrPR5rtY8
# Sun Mar 15 21:43:42 +0000 2015
# 577223762321485824
# RT @MDMGeek: Big Data and the Internet of Things: Two Sides of the Same Coin? http://t.co/UQg7q3EvHp #BigData #IoT - By @tamaradull @SmartD…
# Sun Mar 15 21:44:03 +0000 2015
# 577223812770578432
# Unstructured Data: The Other Side of #Analytics - Forbes http://t.co/BZN44MeEYF @Forbes #bigdata
# Sun Mar 15 21:44:15 +0000 2015
# 577223812900646914
# RT @phpusers: Re: Waiting for localhost http://t.co/rPVg5Kd7q1  #php #database
# Sun Mar 15 21:44:15 +0000 2015
# 577223856718508032
# Job Opportunity: Senior Oracle Database Administrator in Pittsburgh, PA http://t.co/gXAsZVt1IQ #job#SeniorOracleDBA
# Sun Mar 15 21:44:26 +0000 2015
# 577223869704065024
# Tinder swipes right for database-as-a-service from Rackspace From the start, Tinder has used the MongoDB NoSQL ope http://t.co/Qh5Lkvcyyz
# Sun Mar 15 21:44:29 +0000 2015
# 577223934678069248
# Important shift in thinking... The BBVA bank vaults that hoard #bigdata instead of bullion http://t.co/d6O7BOcfKQ via @FT #banktech #fintech
# Sun Mar 15 21:44:44 +0000 2015
# 577223978684690432
# via @phpRTBot Re: Waiting for localhost   #php #database http://t.co/CUES54iN0m
# Sun Mar 15 21:44:55 +0000 2015
# 577223979733250049
# RT @IBMbigdata: Have #Analytics ever made you feel like a deer in headlights? Share your #BigData story at http://t.co/Oq7Dkb4TRy http://t.…
# Sun Mar 15 21:44:55 +0000 2015
# 577223982656663552
# RT @pritishajoshi: The Geeks Arrive In HR:  People #Analytics Is Here http://t.co/w4xw93Tw19 via @forbes #HRtech #HR #People #Cloud #BigData
# Sun Mar 15 21:44:56 +0000 2015
# 577224026810150912
# The science of food: How GE is using #BigData to make sense of what you’re eating http://t.co/2nRzT2B4iH
# Sun Mar 15 21:45:06 +0000 2015
# 577224030501117953
# RT @CraigMilroy: Important shift in thinking... The BBVA bank vaults that hoard #bigdata instead of bullion http://t.co/d6O7BOcfKQ via @FT …
# Sun Mar 15 21:45:07 +0000 2015
# 577224031532916737
# RT @WmMichaelTaylor: Unstructured Data: The Other Side of #Analytics - Forbes http://t.co/BZN44MeEYF @Forbes #bigdata
# Sun Mar 15 21:45:08 +0000 2015
# 577224034049499136
# RT @CANSQL: Congratulation to #BigData #Hackathon winners in Data Modelling: Toronto Parking Ticket Revenue Forecaster project http://t.co/…
# Sun Mar 15 21:45:08 +0000 2015
# 577224035320373248
# RT @RFA_Reading: This is why I wanted to be involved with #sme across the #thamesvalley with #bigdata http://t.co/SIHVND8mDY
# Sun Mar 15 21:45:08 +0000 2015
# 577224036947652608
# ★ JOB ALERT ★ #ITJob #Job #Plymouth - SQL Server Integration Services (SSIS) Database… http://t.co/PrsiwzWf5x ☜ view full details
# Sun Mar 15 21:45:09 +0000 2015
# 577224037736165376
# Tinder swipes right for database-as-a-service from Rackspace From the start, Tinder has used the MongoDB NoSQL ope… http://t.co/BSUagSGlOd
# Sun Mar 15 21:45:09 +0000 2015
# 577224054744092672
# Level 1: Bitcoin is scarce -&gt; valuable.
# L. 2: Wait, BTC is just a "friggin database technology"
# L. 3: Aha, *all* money is just database tech
# Sun Mar 15 21:45:13 +0000 2015
# 577224058963521536
# #hiring ★ JOB ALERT ★ #ITJob #Job #Wilmington - SAS Database Programmer http://t.co/x564K5OLun ☜ view full details #job
# Sun Mar 15 21:45:14 +0000 2015
# 577224064390983680
# ☆★☆ JOB ALERT ☆★☆ #ITJob #Job #Sioux Falls - Database Analyst 4 (SQL) http://t.co/5VsZsiRecp ☜ view full details
# Sun Mar 15 21:45:15 +0000 2015
# 577224065540308993
# RT @phpusers: Re: Waiting for localhost http://t.co/FkmBzkP6Zt  #php #database
# Sun Mar 15 21:45:16 +0000 2015
# 577224069965295617
# RT @rkia_twitts: My 17 Predictions for Technology in 2015 #Cloud #Wearables #BigData #IOT #3DPrinting #Selfie: http://t.co/0cmXLWxKoT via @…
# Sun Mar 15 21:45:17 +0000 2015
# 577224085953875968
# RT CraigMilroy: Important shift in thinking... The BBVA bank vaults that hoard #bigdata instead of bullion http://t.co/k0sIrpiELj; via FT …
# Sun Mar 15 21:45:21 +0000 2015
# 577224097165369345
# #Today - RECORDS, LIBRARY AND DATABASE MANAGEMENT WORKSHOP #Zimbabwe  http://t.co/2ZLL1YISmx http://t.co/CyGYsMOXVo
# Sun Mar 15 21:45:23 +0000 2015
# 577224134704422912
# Job: Database Administrator (Data Center) . Are you a fit? in Pittsburgh, PA http://t.co/yE2yhaLqkY #job
# Sun Mar 15 21:45:32 +0000 2015
# 577224141193003008
# The predict is made by using database "PinnaclePlus bet365".
#  http://t.co/9XowKLMwnX
# Sun Mar 15 21:45:34 +0000 2015
# 577224148277207041
# via @phpRTBot Re: Waiting for localhost   #php #database http://t.co/CQMbFnRO1r
# Sun Mar 15 21:45:35 +0000 2015
# 577224164798513152
# RT @joe_caserta: Why businesses should focus on wide data, not big data by @ThorOlavsrud http://t.co/cWslYbhxbk via @CIOonline #bigdata
# Sun Mar 15 21:45:39 +0000 2015
# 577224185216249857
# IRS illegally sent 1.1 million page database of legally protected taxpayer information to FBI http://t.co/uBXDEMJPQN #TeaParty #tcot #PJNet
# Sun Mar 15 21:45:44 +0000 2015
# 577224223782879233
# #nowplaying database feat.TAKUMA(10-FEET) - MAN WITH A MISSION
# Sun Mar 15 21:45:53 +0000 2015
# 577224289339899904
# and who better to speak to the spirit of the American road trip than "data geniuses" using an algorithm  https://t.co/pBXDMGRzkf
# Sun Mar 15 21:46:09 +0000 2015
# 577224294335438849
# The Pioneering Technology In Sport: The Internet of things #iot #mobile #wifi #bigdata
# https://t.co/G81XaAbu3j
# Sun Mar 15 21:46:10 +0000 2015
# 577224297787338752
# @gaab75 @trufae (2/2) i think he is asking for a tradtnl database, with drivers for userfs to access (sometimes) the db as a filesystem.
# Sun Mar 15 21:46:11 +0000 2015
# 577224330158981120
# RT @WSCP1: IRS illegally sent 1.1 million page database of legally protected taxpayer information to FBI http://t.co/uBXDEMJPQN #TeaParty #…
# Sun Mar 15 21:46:19 +0000 2015
# 577224340539863041
# RT @robustus: Level 1: Bitcoin is scarce -&gt; valuable.
# L. 2: Wait, BTC is just a "friggin database technology"
# L. 3: Aha, *all* money is jus…
# Sun Mar 15 21:46:21 +0000 2015
# 577224370193625089
# RT @bbvaopentalent: Financial Times about @bbva : The Bank that hoards bytes instead of
# bullion http://t.co/TS3wDgOcZt #fintech #bigdata ht…
# Sun Mar 15 21:46:28 +0000 2015
# 577224453639303168
# RT @EnzoAngeles_: Usos de #BigData en Gobiernos, La Economía Digital y el poder de las redes sociales “@xataka: http://t.co/6teI0yCz8w http…
# Sun Mar 15 21:46:48 +0000 2015
# 577224472941326336
# RT @MattBors: and who better to speak to the spirit of the American road trip than "data geniuses" using an algorithm  https://t.co/pBXDMGR…
# Sun Mar 15 21:46:53 +0000 2015
# 577224480331714560
# The Algorithm That Tells the Boss Who Might Quit - WSJ http://t.co/mZN75XM9KO
# Sun Mar 15 21:46:55 +0000 2015
# 577224532542402560
# Software Database Developer - Aerotek: (#Frederick, MD) http://t.co/xTkhOHGU20 #Engineering #Job #Jobs
# Sun Mar 15 21:47:07 +0000 2015
# 577224547679793152
# RT @datacentretech: Data Centre Security: Few Useful Tips http://t.co/yzXXgd9bOO #datacentre, #datacenter , #blog, #bigdata,
# Sun Mar 15 21:47:11 +0000 2015
# 577224579938140160
# RT @Networkshashi: #BigData: Your Laptop Can Now Analyze BigData
# http://t.co/3Mqjv1n5kx
# Sun Mar 15 21:47:18 +0000 2015
# 577224724830355456
# @jpflathead FOR PS4 Users tell them put their console into safe mode and rebuild database, thank you
# Sun Mar 15 21:47:53 +0000 2015
# 577224724700254208
# RT @takuma10feet: モブスタイルス15周年広島来てくれたみんなありがとう！写真は今日のマンウィズとのオープニング一曲目"database feat.takuma"の1分前。楽しかったなぁ。そして今日のthe trust… https://t.co/BTDfzG2…
# Sun Mar 15 21:47:53 +0000 2015
# 577224764059705344
# BREAKING: The Algorithm That Tells the Boss Who Might Quit http://t.co/ijfBHJc7B2 #teambho #imsleepyy
# Sun Mar 15 21:48:02 +0000 2015
# 577224797207179264
# ★ JOB ALERT ★ #ITJob #Job #Jacksonville - Oracle Database Administrator http://t.co/5UOrD4P5HV ☜ view full details #job #hiring
# Sun Mar 15 21:48:10 +0000 2015
# 577224797874094080
# RT @KMWeiland: Want to Know More About the Structure of Your Favorite Books and Movies? Announcing the Story Structure Database! http://t.c…
# Sun Mar 15 21:48:10 +0000 2015
# 577224818753323008
# ★ JOB ALERT ★ #ITJob #Job #Burlington - Database Administrator SQL DBA http://t.co/8M4fVlDwPD ☜ view full details
# Sun Mar 15 21:48:15 +0000 2015
# 577224819164364800
# ★ JOB ALERT ★ #ITJob #Job #San Diego - SQL Database Developer http://t.co/8zMhaSEg1j ☜ view full details #job
# Sun Mar 15 21:48:15 +0000 2015
# 577224823065034752
# ★ JOB ALERT ★ #ITJob #Job #San Diego - SQL DATABASE DEVELOPER http://t.co/LYmJGeJrd3 ☜ view full details #job
# Sun Mar 15 21:48:16 +0000 2015
# 577224836092551168
# RT @MattBors: and who better to speak to the spirit of the American road trip than "data geniuses" using an algorithm  https://t.co/pBXDMGR…
# Sun Mar 15 21:48:19 +0000 2015
# 577224905294524416
# RT @KirkDBorne: Free eBook: "Mining of Massive Datasets" http://t.co/UTjL5zQZ15 #abdsc #DataMining #BigData #Analytics #DataScience via @an…
# Sun Mar 15 21:48:36 +0000 2015
# 577224912416436224
# RT @BigDataSoc: Do the Snowden disclosures indicate that#BigData practices are becoming increasingly important to #surveillance? http://t.c…
# Sun Mar 15 21:48:38 +0000 2015
# 577224930137399296
# ¿Qué es la inteligencia de fuentes abiertas? http://t.co/xZaFOt5gKm vía @TICbeat
# Sun Mar 15 21:48:42 +0000 2015
# 577224984361246720
# RT @MattBors: and who better to speak to the spirit of the American road trip than "data geniuses" using an algorithm  https://t.co/pBXDMGR…
# Sun Mar 15 21:48:55 +0000 2015
# 577224985103630336
# RT @MattBors: and who better to speak to the spirit of the American road trip than "data geniuses" using an algorithm  https://t.co/pBXDMGR…
# Sun Mar 15 21:48:55 +0000 2015
# 577225009678196737
# RT @MattBors: and who better to speak to the spirit of the American road trip than "data geniuses" using an algorithm  https://t.co/pBXDMGR…
# Sun Mar 15 21:49:01 +0000 2015
# 577225040241946624
# @fuIani i feel like their only database for west Africa is igbo lol so everything west african automatically clusters to that smh
# Sun Mar 15 21:49:08 +0000 2015
# 577225051491184640
# RT @SStavrinoudakis: Fast detection of Cyber Threats through advanced #BigData #Analytics http://t.co/Fov296lNtj #CyberSecurity
# Sun Mar 15 21:49:11 +0000 2015
# 577225100568702976
# RT @MarcWilczek: In 2014, the digital universe equaled 1.7 megabytes a minute for every person on Earth: http://t.co/gLf50KtZKx #Bigdata #I…
# Sun Mar 15 21:49:22 +0000 2015
# 577225115793895424
# RT @benayapaul: How to connect MySql database with Nodejs http://t.co/Zpjy352KBs
# Sun Mar 15 21:49:26 +0000 2015
# 577225128267923456
# RT @CalogeroRavenna: Gartner predicts 3 Big data trends for business intelligence
# #bigdata #businessintelligence http://t.co/rJ3pm3rfGy
# Sun Mar 15 21:49:29 +0000 2015
# 577225152301268993
# Checkout our checklist for starting a staffing agency! WATCH THE VIDEO: http://t.co/kGziayNRd2 #bigdata #java #iot #salesforce #startup #yes
# Sun Mar 15 21:49:35 +0000 2015
# 577225158663872513
# Database (DBA) Manager http://t.co/pxhj2j4riY
# Sun Mar 15 21:49:36 +0000 2015
# 577225181711753216
# RCMP database remains out of date, police and prosecutors say  http://t.co/TmFmkHJ8wF
# Sun Mar 15 21:49:42 +0000 2015
# 577225183070691329
# Now hiring for: T-SQL Database / SSIS ETL Developer – “This is the place for Data Geeks” in Milwaukee, WI http://t.co/ICoK2VwplX #job
# Sun Mar 15 21:49:42 +0000 2015
# 577225228062838784
# RT @WSCP1: IRS illegally sent 1.1 million page database of legally protected taxpayer information to FBI http://t.co/uBXDEMJPQN #TeaParty #…
# Sun Mar 15 21:49:53 +0000 2015
# 577225259843231745
# So....what exactly is #bigdata? [Blog]  http://t.co/E2f74eNrOO
# Sun Mar 15 21:50:00 +0000 2015
# 577225277396377600
# 4 Ways the Future of Big Data Will Change the Way We Work and Live http://t.co/fg3Ym2CtOA #BigData #Cloud
# Sun Mar 15 21:50:05 +0000 2015
# 577225286699360257
# Oracle Database Developer/ Engineer - Rockville, MD http://t.co/yzhs7GqmGG
# Sun Mar 15 21:50:07 +0000 2015
# 577225344987480064
# Expedia Asia Pacific: Application Engineer II (#Gurgaon) http://t.co/wDThMbzRlX #Database #ExpediaJobs #Job #Jobs
# Sun Mar 15 21:50:21 +0000 2015
# 577225356769366016
# RT @CANSQL: Congratulation to #BigData #Hackathon winners in Data Modelling: Toronto Parking Ticket Revenue Forecaster project http://t.co/…
# Sun Mar 15 21:50:24 +0000 2015
# 577225361550909440
# New Paper: An Improved Image Mosaicing Algorithm for Damaged Documents
# http://t.co/NxmUcmRH98 #forensic
# Sun Mar 15 21:50:25 +0000 2015
# 577225397978460160
# RT @DByresPHC: How much data is generated every minute? #BigData never sleeps. @EddieBeardDNP @MaryJaneNeri1 http://t.co/7dwgtphJ3B
# Sun Mar 15 21:50:33 +0000 2015
# 577225446754000896
# RT @MDMGeek: 4 Ways the Future of Big Data Will Change the Way We Work and Live http://t.co/fg3Ym2CtOA #BigData #Cloud
# Sun Mar 15 21:50:45 +0000 2015
# 577225447269928960
# RT @sarahaustin: NYC bound #NewYork #advertising #madisonave #BigData #deeplistening #conferencetime
# Sun Mar 15 21:50:45 +0000 2015
# 577225447521546240
# RT @TrendSource: So....what exactly is #bigdata? [Blog]  http://t.co/E2f74eNrOO
# Sun Mar 15 21:50:45 +0000 2015
# 577225448599457792
# RT @no1networker: Checkout our checklist for starting a staffing agency! WATCH THE VIDEO: http://t.co/kGziayNRd2 #bigdata #java #iot #sales…
# Sun Mar 15 21:50:45 +0000 2015
# 577225449375399936
# RT @CalogeroRavenna: Gartner predicts 3 Big data trends for business intelligence
# #bigdata #businessintelligence http://t.co/rJ3pm3rfGy
# Sun Mar 15 21:50:46 +0000 2015
# 577225507885973504
# What Is #BigData #Discovery? A #trend to watch out in next two years! http://t.co/sWJ0sp9DBH
# Sun Mar 15 21:51:00 +0000 2015
# 577225545676677120
# RT @IMAGINiT_Tech: Autodesk Foundation's new #impactdesign database; resources to help create a better world http://t.co/tNA0pvTtG6 http://…
# Sun Mar 15 21:51:09 +0000 2015
# 577225595186061312
# Pagerank Algorithm Reveals World's All-Time Top Soccer Team http://t.co/UMxpLtH8iu
# Sun Mar 15 21:51:20 +0000 2015
# 577225598017220608
# ☆★☆ JOB ALERT ☆★☆ #ITJob #Job #Los Angeles - Access Database Programmer http://t.co/MRvEBCJ8f8 ☜ view full details
# Sun Mar 15 21:51:21 +0000 2015
# 577225611363688448
# @KerryRoushey @trutherbot Do you understand hacking moron?  Trutherbot is an algorithm muncher.  Try again evil.
# Sun Mar 15 21:51:24 +0000 2015
# 577225655579860992
# Database appraising abrege: nwLzFLMkp
# Sun Mar 15 21:51:35 +0000 2015
# 577225676056489985
# RT @portlandhead: Your site's not mobile friendly? You may want to get moving. @Google's changing its algorithm: http://t.co/NfxJlLOULA #mt…
# Sun Mar 15 21:51:40 +0000 2015
# 577225676811583488
# Adapt your customer service strategies, or die. http://t.co/qGVqGtWmgI #VoiceOfCustomer #BigData #Tungsten
# Sun Mar 15 21:51:40 +0000 2015
# 577225693966176256
# RT @takuma10feet: モブスタイルス15周年広島来てくれたみんなありがとう！写真は今日のマンウィズとのオープニング一曲目"database feat.takuma"の1分前。楽しかったなぁ。そして今日のthe trust… https://t.co/BTDfzG2…
# Sun Mar 15 21:51:44 +0000 2015
# 577225709174845440
# @danechkin send data to graphite or compatible database
# Sun Mar 15 21:51:48 +0000 2015
# 577225749100363777
# @BiancaGoes68 zie het nu pas, źit bijna nooit meer op Twitter. Lijken ok te zijn. Ik laat het voor de zekerheid checken in de land. database
# Sun Mar 15 21:51:57 +0000 2015
# 577225779387494400
# ¿Qué es la inteligencia de fuentes abiertas? http://t.co/vBHfYvOgHi
# Sun Mar 15 21:52:04 +0000 2015
# 577225792364670976
# Tus #tickets d compra en tu #smartphone http://t.co/Ush5fCgQ3n …  #bigdata #gifts #shopping #WanasConceptStore
# #Zamalek #Cairo
# Sun Mar 15 21:52:07 +0000 2015
# 577225822399942656
# No she didn't just write "highjean..." Adding it to the database. #MinusWell
# Sun Mar 15 21:52:15 +0000 2015
# 577225838950637568
# What's in Your Movie Database? http://t.co/7l1SH1zJcP #BestMovieStories
# Sun Mar 15 21:52:19 +0000 2015
# 577225887713771521
# RT @jalopezg70: 23andMe to Use Genetic Database for Drug Discovery http://t.co/8s6OpKTEOx via @rightrelevance thanks @wsjhealth
# Sun Mar 15 21:52:30 +0000 2015
# 577225905157718016
# Transmittance skills: guest blog in keeping with jessica sanders3 ways in order to impose algorithm forasmuch as… http://t.co/4RnL5ELMaw
# Sun Mar 15 21:52:34 +0000 2015
# 577225950150176769
# “@ForensicDocHW: New Paper: An Improved Image Mosaicing Algorithm for Damaged Documents
# http://t.co/xRAJRY1uDe #forensic”
# Sun Mar 15 21:52:45 +0000 2015
# 577225951202971649
# RT @robustus: Level 1: Bitcoin is scarce -&gt; valuable.
# L. 2: Wait, BTC is just a "friggin database technology"
# L. 3: Aha, *all* money is jus…
# Sun Mar 15 21:52:45 +0000 2015
# 577225961076187136
# @Contexti at @CiscoLiveMEL sharing lessons from 36+ engagements in #BigData #Platforms for #Analytics &amp; #IoT  #CLMel
# Sun Mar 15 21:52:48 +0000 2015
# 577225963769110528
# Everilion:the evolution of #Commerce: http://t.co/pIKJ0ZphGK #bigdata #ecommerce #gifts #shopping #WanasConceptStore
# #Zamalek #Cairo
# Sun Mar 15 21:52:48 +0000 2015
# 577225968043057153
# It’s time for action in EU Data Protection Directive #BigData - http://t.co/Iv8Q6ZGCPO
# Sun Mar 15 21:52:49 +0000 2015
# 577225973504049152
# RT @VPROTegenlicht: Planten groeien met LED-lampen, een database vol smaken en meer Digitaal Voedsel straks om 21.05 uur op #npo2 bij VPRO …
# Sun Mar 15 21:52:51 +0000 2015
# 577225977023066112
# RT @robustus: Level 1: Bitcoin is scarce -&gt; valuable.
# L. 2: Wait, BTC is just a "friggin database technology"
# L. 3: Aha, *all* money is jus…
# Sun Mar 15 21:52:51 +0000 2015
# 577226001047904256
# Is it Pokémon or #bigdata technology? https://t.co/q0WL7c77uM
# Sun Mar 15 21:52:57 +0000 2015
# 577226041028038656
# Facial Expression Cloning with Elastic and Muscle Models: a novel algorithm is proposed for facial expression cloning http://t.co/LAKQCmL6kx
# Sun Mar 15 21:53:07 +0000 2015
# 577226084355280897
# Apply to this job: Big Data Technologist / Architect in New York, NY http://t.co/8zpq8q9XYA #job#BigData
# Sun Mar 15 21:53:17 +0000 2015
# 577226086557319168
# RT @no1networker: Checkout our checklist for starting a staffing agency! WATCH THE VIDEO: http://t.co/kGziayNRd2 #bigdata #java #iot #sales…
# Sun Mar 15 21:53:18 +0000 2015
# 577226101354823683
# RT @fintechna: RT CraigMilroy: Important shift in thinking... The BBVA bank vaults that hoard #bigdata instead of bullion http://t.co/k0sIr…
# Sun Mar 15 21:53:21 +0000 2015
# 577226110758338561
# RT @link2i: Using #Analytics to build A #BigData #Workforce http://t.co/i6mAykoAjI #talentAnalytics #hr
# Sun Mar 15 21:53:23 +0000 2015
# 577226113396711425
# RT @bretones: La solution de big data « #FluxVision » plébiscitée par les acteurs du #tourisme http://t.co/aaae5g2zAT via @orange #bigdata
# Sun Mar 15 21:53:24 +0000 2015
# 577226119805448193
# Quickly &amp; easily manage your website &amp; database. No more tedious website builders which make you do all of the work
# http://t.co/km6NDdcwoI
# Sun Mar 15 21:53:25 +0000 2015
# 577226121890164736
# Facebook's Steve Hatch: The algorithm is king, but people still set the rules http://t.co/DdB94wK0XB
# Sun Mar 15 21:53:26 +0000 2015
# 577226133474713600
# RT @D3EKSHA: #Chicago #BigData Job Seekers &amp; #Recruiters, Checkout #Data #AnalyticsFair on #24MAR2015 http://t.co/u6wFVtEJGM #ord
# Sun Mar 15 21:53:29 +0000 2015
# 577226164478996481
# RT @Intellipaat: Script level functions and chart level functions knowledge with Qlikview Training. http://t.co/xSeORpyyDO #Bigdata #BI #Ql…
# Sun Mar 15 21:53:36 +0000 2015
# 577226187329523713
# RT @anthonylrx: #Bigdata makes big promises but for the most part it has been a big let down. - @tylerdouglas http://t.co/GvQysKAKtT #ILove…
# Sun Mar 15 21:53:42 +0000 2015
# 577226190504620032
# 11 Database Administrator Tools For System Admins http://t.co/Yp12Za8Xrd
# Sun Mar 15 21:53:42 +0000 2015
# 577226272721383424
# Speculation on Google Fact Database finding errors in common beliefs and other interesting stories on ReflectiveAir16 http://t.co/LrVBCvQU0U
# Sun Mar 15 21:54:02 +0000 2015
# 577226280023797760
# Oracle Exadata Database и приложений наших клиентов появляются новые возможности хранения данных. Комплексное
# Sun Mar 15 21:54:04 +0000 2015
# 577226284901773313
# RT @zackjesus: 17 Predictions for Technology in 2015 #Cloud #Wearables #BigData #IOT #3DPrinting #Selfie: http://t.co/cTAQxjQ4Oq via @Timot…
# Sun Mar 15 21:54:05 +0000 2015
# 577226287720230912
# RT @DataMentors: Three #BigData Use Cases for #Marketers http://t.co/hytr0D7JLb http://t.co/ohK7dUk9LB
# Sun Mar 15 21:54:05 +0000 2015
# 577226308905791488
# For those who live in the age of the algorithm, remember all algorithms ultimately hit up against a moral issue http://t.co/VKNZ0ZvjTy
# Sun Mar 15 21:54:11 +0000 2015
# 577226309086085120
# RT D3EKSHA: #Chicago #BigData Job Seekers &amp; #Recruiters, Checkout #Data #AnalyticsFair on #24MAR2015 … http://t.co/Lt2hK8O3w2
# Sun Mar 15 21:54:11 +0000 2015
# 577226309727825920
# For those who live in the age of the algorithm, remember all algorithms ultimately hit up against a moral issue http://t.co/wtUXNQ7Qd6
# Sun Mar 15 21:54:11 +0000 2015
# 577226312667914240
# RT @takuma10feet: モブスタイルス15周年広島来てくれたみんなありがとう！写真は今日のマンウィズとのオープニング一曲目"database feat.takuma"の1分前。楽しかったなぁ。そして今日のthe trust… https://t.co/BTDfzG2…
# Sun Mar 15 21:54:11 +0000 2015
# 577226327297798145
# Important shift in thinking: The #BBVA #bank vaults that hoard #bigdata instead of bullion http://t.co/YbKPTZQuyb @fintechna @CraigMilroy
# Sun Mar 15 21:54:15 +0000 2015
# 577226327343771648
# RT @cobusinessSol: The third #technological era is coming #IoT http://t.co/KbRBtWeCyJ #wearables #SmartCities #cloud #BigData http://t.co/I…
# Sun Mar 15 21:54:15 +0000 2015
# 577226337494175744
# #Environment #Environmental Concerns &amp; Issues #Green Industry International Media Contact Database: 15,946 Contacts http://t.co/jeywugxSJh
# Sun Mar 15 21:54:17 +0000 2015
# 577226355768713216
# RT @mgzeuthen: I'm looking for a publisher/blogger to alpha test our new mobile ad technology. DM me or sign up at http://t.co/oLgTS7Ewnv #…
# Sun Mar 15 21:54:22 +0000 2015
# 577226362689224704
# RT @JohndeVoogd: Big data, meet dumb data: How CMOs are driving value from data (report) | VentureBeat  | by VB Staff http://t.co/p78DxIQK9…
# Sun Mar 15 21:54:23 +0000 2015
# 577226369781915648
# @atomsoffice @maxschrems German car industry wants to use #bigdata hence #Merkel's @RegSprecher's volte face
# Sun Mar 15 21:54:25 +0000 2015
# 577226406104424448
# RT @AdvanceVentures: Adding Security of Things to the #InternetofThings http://t.co/VQUtGIdn4S #CIO #hacking #VC #startups #BigData #M2M #s…
# Sun Mar 15 21:54:34 +0000 2015
# 577226415390777346
# BethanyHedger1: RT zackjesus: 17 Predictions for Technology in 2015 #Cloud #Wearables #BigData #IOT #3DPrinting #Selfie: …
# Sun Mar 15 21:54:36 +0000 2015
# 577226426086256640
# RT @Startuppodden: Ute nu: #StartuppoddengoesSUP46   @JohanAttby vd Fishbrain, om hur man bygger community med #bigdata #sthlmtech http://t…
# Sun Mar 15 21:54:38 +0000 2015
# 577226453487616000
# Opening up data unlocks citizenship http://t.co/cahubKsL2U #BigData
# Sun Mar 15 21:54:45 +0000 2015
# 577226454901137410
# German industry is poised to exploit rural broadband http://t.co/IPMr0CEziy #BigData
# Sun Mar 15 21:54:45 +0000 2015
# 577226466422710272
# RT @bobehayes: #DataScience team has #statistics, business &amp; comp engine skills 》 How #bigdata can make tracks in the rail industry http://…
# Sun Mar 15 21:54:48 +0000 2015
# 577226470428377088
# RT @robustus: Level 1: Bitcoin is scarce -&gt; valuable.
# L. 2: Wait, BTC is just a "friggin database technology"
# L. 3: Aha, *all* money is jus…
# Sun Mar 15 21:54:49 +0000 2015
# 577226472819150848
# RT @DataScientistFr: Leading Marketing Excellence With Analytics http://t.co/92XV9CUUpO #BigData #Analytics
# Sun Mar 15 21:54:50 +0000 2015
# 577226501369831425
# Go to http://t.co/CXA80Vrygd RT BethanyHedger1 RT zackjesus: 17 Predictions for Technology in 2015 #Cloud #Wearables #BigData #IOT #3DPri…
# Sun Mar 15 21:54:56 +0000 2015
# 577226522777534464
# RT @MDMGeek: 4 Ways the Future of Big Data Will Change the Way We Work and Live http://t.co/fg3Ym2CtOA #BigData #Cloud
# Sun Mar 15 21:55:02 +0000 2015
# 577226526778728448
# RT @realzips: @dginerh thank you for RealZips Fav! Check http://t.co/lJ02A2mMdc #crm #sales #bigdata
# Sun Mar 15 21:55:02 +0000 2015

# %%
def tweet_json(tid,text,created):
    j={
    "tweet_id" : tid,
    "text" : text,
    "created_at" : created}
    return j

# %%
ts=datetime.now()
# "Current date and time using strftime:"
ts.strftime("%Y-%m-%d %H:%M")
# Out:
# '2018-04-01 22:54'

# %%
ts = datetime.strptime('Jun 1 2005  1:33PM', '%b %d %Y %I:%M%p')
ts.strftime("%Y-%m-%d %H:%M")
# Out:
# '2005-06-01 13:33'

# %%
# Twitter dates are of the form Sun Mar 15 21:41:54 +0000 2015
datestrings=['Sun Mar 15 21:41:54 +0000 2015','Tue Mar 29 08:11:25 +0000 2011']
from datetime import timedelta
from email.utils import parsedate_tz

def to_datetime(datestring):
    time_tuple = parsedate_tz(datestring.strip())
    dt = datetime(*time_tuple[:6])
    return dt - timedelta(seconds=time_tuple[-1])

ts=to_datetime(datestrings[0])
print (ts.strftime("%Y-%m-%d %H:%M"))
ts=to_datetime(datestrings[1])
print (ts.strftime("%Y-%m-%d %H:%M"))
# Out:
# 2015-03-15 21:41
# 2011-03-29 08:11

# %%
cnt=0
for tweet in tweets_j:
    ts=datetime.now()
    try:
        ts=to_datetime(tweet['created_at'])
    except:
        pass     
    try:
        j=tweet_json(tweet['id'],tweet['text'],ts)
        result = db.tweets.insert_one(j)
        cnt+=1
    except:
        pass       
print ("%d tweets inserted."%cnt)
# Out:
# 167 tweets inserted.

# %%
for tweet in db.tweets.find():
    pprint.pprint(tweet)
# Out:
# {'_id': ObjectId('5ac19b77a313fc02d6006fe3'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 41, 22),
#  'text': 'RT @MarcWilczek: In 2014, the digital universe equaled 1.7 megabytes '
#          'a minute for every person on Earth: http://t.co/gLf50KtZKx #Bigdata '
#          '#I…',
#  'tweet_id': 577223085054558208}
# {'_id': ObjectId('5ac19b77a313fc02d6006fe4'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 41, 30),
#  'text': 'Tanginang database to',
#  'tweet_id': 577223118327926785}
# {'_id': ObjectId('5ac19b77a313fc02d6006fe5'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 41, 31),
#  'text': 'RT @chrisco: The future of farming: robots + big data: '
#          'http://t.co/MiEIZmKzEb via @KurzweilAINews #AgTech #AgBots #Robotics '
#          '#Automation #Io…',
#  'tweet_id': 577223124862697472}
# {'_id': ObjectId('5ac19b77a313fc02d6006fe6'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 41, 40),
#  'text': 'RT @Brian_Singer_: The EMC Federation Joins the OpenStack Foundation '
#          'http://t.co/i37gbFthQw #cloud #bigdata #aws #ec2 '
#          'http://t.co/uYQIXOSMHs',
#  'tweet_id': 577223160195502080}
# {'_id': ObjectId('5ac19b77a313fc02d6006fe7'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 41, 46),
#  'text': 'RT @execedia: Learn @execedia: The Business Benefits of Big Data '
#          'http://t.co/uQSGCKEiOn\n'
#          ' #BigData',
#  'tweet_id': 577223187110330368}
# {'_id': ObjectId('5ac19b77a313fc02d6006fe8'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 41, 54),
#  'text': 'RT @RiverCityGal: The goal is not to keep #bigdata scary but to turn '
#          'it into something beautiful @kalpenn #natgeosxsw @NatGeoChannel',
#  'tweet_id': 577223217942691840}
# {'_id': ObjectId('5ac19b77a313fc02d6006fe9'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 41, 56),
#  'text': 'RT @TheHesterView: MT .@techrepublic WhiteHouse + climate change: '
#          'hackathons, crowdsourcing, #bigdata http://t.co/6HWjCv3BL5 Lets join '
#          'in! …',
#  'tweet_id': 577223226444509185}
# {'_id': ObjectId('5ac19b77a313fc02d6006fea'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 41, 58),
#  'text': '@TurnupPrince if there was some sort of list or database? There is a '
#          "general rating list, but i don't think it addresses this "
#          'specifically',
#  'tweet_id': 577223237140148224}
# {'_id': ObjectId('5ac19b77a313fc02d6006feb'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 42, 1),
#  'text': 'Can you replace a recruiter with an algorithm? '
#          'http://t.co/rLNk2UtnkL',
#  'tweet_id': 577223250566082560}
# {'_id': ObjectId('5ac19b77a313fc02d6006fec'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 42, 5),
#  'text': 'RT @DataScientistFr: Leading Marketing Excellence With Analytics '
#          'http://t.co/92XV9CUUpO #BigData #Analytics',
#  'tweet_id': 577223265891934208}
# {'_id': ObjectId('5ac19b77a313fc02d6006fed'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 42, 19),
#  'text': 'RT @MatthewB_SEA: Cisco, HP keep the lead in cloud infrastructure '
#          'http://t.co/fi0MuG9QUH #cloud #amazon #ec2 #bigdata #IT '
#          'http://t.co/jRLp7…',
#  'tweet_id': 577223326289956864}
# {'_id': ObjectId('5ac19b77a313fc02d6006fee'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 42, 24),
#  'text': 'RT @pritishajoshi: The Geeks Arrive In HR:  People #Analytics Is '
#          'Here http://t.co/w4xw93Tw19 via @forbes #HRtech #HR #People #Cloud '
#          '#BigData',
#  'tweet_id': 577223344141025280}
# {'_id': ObjectId('5ac19b77a313fc02d6006fef'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 42, 29),
#  'text': 'RT @Firas_Orbitera: Box raises $175m with IPO, but what is next?  '
#          'http://t.co/wdK8JZM7db #cloud #amazon #aws #bigdata',
#  'tweet_id': 577223365594779648}
# {'_id': ObjectId('5ac19b77a313fc02d6006ff0'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 42, 36),
#  'text': 'RT @CarvMoore: FCC Takes Defensive Legal Stance in 300-Page Open '
#          'Internet Order http://t.co/tkSfjPpods #data #IT #cloud #bigdata #aws',
#  'tweet_id': 577223397047803904}
# {'_id': ObjectId('5ac19b77a313fc02d6006ff1'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 42, 45),
#  'text': 'RT @BIG_DATA_News: Take holistic approach to improve rail '
#          'reliability: The LTA and SMRT should perhaps incorporate and l... '
#          'http://t.co/mM0…',
#  'tweet_id': 577223432296755200}
# {'_id': ObjectId('5ac19b77a313fc02d6006ff2'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 42, 48),
#  'text': "RT @caitlinrgreen: Translation of early 11thC runes: 'Óðinn and "
#          "Heimdallr and Þjálfa, they help thee, Úlfljótr...' (trans. John "
#          'Hines, http…',
#  'tweet_id': 577223448004526080}
# {'_id': ObjectId('5ac19b77a313fc02d6006ff3'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 42, 49),
#  'text': 'RT @KirkDBorne: New breed of scientific researchers, '
#          '#DataScientists, must be Pi-shaped: https://t.co/BGmnXAOlIY #BigData '
#          'by @jakevdp http:…',
#  'tweet_id': 577223448503705603}
# {'_id': ObjectId('5ac19b77a313fc02d6006ff4'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 42, 53),
#  'text': 'Many websites send out lists of ebooks.The Fussy Librarian uses a '
#          "database to find novels you'll love: Subscribe now "
#          'http://t.co/EBChICLch2',
#  'tweet_id': 577223465255759872}
# {'_id': ObjectId('5ac19b77a313fc02d6006ff5'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 42, 53),
#  'text': 'RT @caitlinrgreen: This is quite nice too--early 11C runic '
#          'inscription from Saltfleetby, Lincs, mentions Odin etc '
#          'http://t.co/SgcfxbdQvZ ht…',
#  'tweet_id': 577223468284035073}
# {'_id': ObjectId('5ac19b77a313fc02d6006ff6'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 42, 56),
#  'text': 'RT @CANSQL: Congratulations to #BigData #Hackathon winners in Data '
#          'Visualization Category: Parking Tickets and Air Flights  #BDH '
#          'http://t.c…',
#  'tweet_id': 577223480548061184}
# {'_id': ObjectId('5ac19b77a313fc02d6006ff7'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 43),
#  'text': 'RT @bobehayes: Be precise about meaning of the data 》Datafloq - '
#          'Transparency Is Not Enough http://t.co/Jfh5Xc2hQz ht @VanRijmenam '
#          '#BigData …',
#  'tweet_id': 577223496767406080}
# {'_id': ObjectId('5ac19b77a313fc02d6006ff8'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 43, 9),
#  'text': 'RT @RFA_Reading: This is why I wanted to be involved with #sme '
#          'across the #thamesvalley with #bigdata http://t.co/SIHVND8mDY',
#  'tweet_id': 577223532230283264}
# {'_id': ObjectId('5ac19b77a313fc02d6006ff9'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 43, 9),
#  'text': 'RT @CANSQL: Congratulation to #BigData #Hackathon winners in Data '
#          'Modelling: Toronto Parking Ticket Revenue Forecaster project '
#          'http://t.co/…',
#  'tweet_id': 577223536256765952}
# {'_id': ObjectId('5ac19b77a313fc02d6006ffa'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 43, 15),
#  'text': 'RT @phpusers: Re: Waiting for localhost http://t.co/OGcvtI1663  #php '
#          '#database',
#  'tweet_id': 577223560718086145}
# {'_id': ObjectId('5ac19b77a313fc02d6006ffb'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 43, 16),
#  'text': '@Aalimah_aah I pull html source from a http://t.co/n5kJRoYydW list '
#          '&amp; dump into a database.',
#  'tweet_id': 577223563372941313}
# {'_id': ObjectId('5ac19b77a313fc02d6006ffc'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 43, 25),
#  'text': 'In your brain are stored hundreds of millions of data and imagery, '
#          'but the brain is not simply a database.',
#  'tweet_id': 577223601696309249}
# {'_id': ObjectId('5ac19b77a313fc02d6006ffd'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 43, 42),
#  'text': '"Algorithm Clones Facial Expressions and Pastes Them onto Other '
#          'Faces" https://t.co/TzrPR5rtY8',
#  'tweet_id': 577223674400534529}
# {'_id': ObjectId('5ac19b77a313fc02d6006ffe'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 44, 3),
#  'text': 'RT @MDMGeek: Big Data and the Internet of Things: Two Sides of the '
#          'Same Coin? http://t.co/UQg7q3EvHp #BigData #IoT - By @tamaradull '
#          '@SmartD…',
#  'tweet_id': 577223762321485824}
# {'_id': ObjectId('5ac19b77a313fc02d6006fff'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 44, 15),
#  'text': 'Unstructured Data: The Other Side of #Analytics - Forbes '
#          'http://t.co/BZN44MeEYF @Forbes #bigdata',
#  'tweet_id': 577223812770578432}
# {'_id': ObjectId('5ac19b77a313fc02d6007000'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 44, 15),
#  'text': 'RT @phpusers: Re: Waiting for localhost http://t.co/rPVg5Kd7q1  #php '
#          '#database',
#  'tweet_id': 577223812900646914}
# {'_id': ObjectId('5ac19b77a313fc02d6007001'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 44, 26),
#  'text': 'Job Opportunity: Senior Oracle Database Administrator in Pittsburgh, '
#          'PA http://t.co/gXAsZVt1IQ #job#SeniorOracleDBA',
#  'tweet_id': 577223856718508032}
# {'_id': ObjectId('5ac19b77a313fc02d6007002'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 44, 29),
#  'text': 'Tinder swipes right for database-as-a-service from Rackspace From '
#          'the start, Tinder has used the MongoDB NoSQL ope '
#          'http://t.co/Qh5Lkvcyyz',
#  'tweet_id': 577223869704065024}
# {'_id': ObjectId('5ac19b77a313fc02d6007003'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 44, 44),
#  'text': 'Important shift in thinking... The BBVA bank vaults that hoard '
#          '#bigdata instead of bullion http://t.co/d6O7BOcfKQ via @FT #banktech '
#          '#fintech',
#  'tweet_id': 577223934678069248}
# {'_id': ObjectId('5ac19b77a313fc02d6007004'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 44, 55),
#  'text': 'via @phpRTBot Re: Waiting for localhost   #php #database '
#          'http://t.co/CUES54iN0m',
#  'tweet_id': 577223978684690432}
# {'_id': ObjectId('5ac19b77a313fc02d6007005'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 44, 55),
#  'text': 'RT @IBMbigdata: Have #Analytics ever made you feel like a deer in '
#          'headlights? Share your #BigData story at http://t.co/Oq7Dkb4TRy '
#          'http://t.…',
#  'tweet_id': 577223979733250049}
# {'_id': ObjectId('5ac19b77a313fc02d6007006'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 44, 56),
#  'text': 'RT @pritishajoshi: The Geeks Arrive In HR:  People #Analytics Is '
#          'Here http://t.co/w4xw93Tw19 via @forbes #HRtech #HR #People #Cloud '
#          '#BigData',
#  'tweet_id': 577223982656663552}
# {'_id': ObjectId('5ac19b77a313fc02d6007007'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 45, 6),
#  'text': 'The science of food: How GE is using #BigData to make sense of what '
#          'you’re eating http://t.co/2nRzT2B4iH',
#  'tweet_id': 577224026810150912}
# {'_id': ObjectId('5ac19b77a313fc02d6007008'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 45, 7),
#  'text': 'RT @CraigMilroy: Important shift in thinking... The BBVA bank vaults '
#          'that hoard #bigdata instead of bullion http://t.co/d6O7BOcfKQ via '
#          '@FT …',
#  'tweet_id': 577224030501117953}
# {'_id': ObjectId('5ac19b77a313fc02d6007009'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 45, 8),
#  'text': 'RT @WmMichaelTaylor: Unstructured Data: The Other Side of #Analytics '
#          '- Forbes http://t.co/BZN44MeEYF @Forbes #bigdata',
#  'tweet_id': 577224031532916737}
# {'_id': ObjectId('5ac19b77a313fc02d600700a'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 45, 8),
#  'text': 'RT @CANSQL: Congratulation to #BigData #Hackathon winners in Data '
#          'Modelling: Toronto Parking Ticket Revenue Forecaster project '
#          'http://t.co/…',
#  'tweet_id': 577224034049499136}
# {'_id': ObjectId('5ac19b77a313fc02d600700b'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 45, 8),
#  'text': 'RT @RFA_Reading: This is why I wanted to be involved with #sme '
#          'across the #thamesvalley with #bigdata http://t.co/SIHVND8mDY',
#  'tweet_id': 577224035320373248}
# {'_id': ObjectId('5ac19b77a313fc02d600700c'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 45, 9),
#  'text': '★ JOB ALERT ★ #ITJob #Job #Plymouth - SQL Server Integration '
#          'Services (SSIS) Database… http://t.co/PrsiwzWf5x ☜ view full details',
#  'tweet_id': 577224036947652608}
# {'_id': ObjectId('5ac19b77a313fc02d600700d'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 45, 9),
#  'text': 'Tinder swipes right for database-as-a-service from Rackspace From '
#          'the start, Tinder has used the MongoDB NoSQL ope… '
#          'http://t.co/BSUagSGlOd',
#  'tweet_id': 577224037736165376}
# {'_id': ObjectId('5ac19b77a313fc02d600700e'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 45, 13),
#  'text': 'Level 1: Bitcoin is scarce -&gt; valuable.\n'
#          'L. 2: Wait, BTC is just a "friggin database technology"\n'
#          'L. 3: Aha, *all* money is just database tech',
#  'tweet_id': 577224054744092672}
# {'_id': ObjectId('5ac19b77a313fc02d600700f'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 45, 14),
#  'text': '#hiring ★ JOB ALERT ★ #ITJob #Job #Wilmington - SAS Database '
#          'Programmer http://t.co/x564K5OLun ☜ view full details #job',
#  'tweet_id': 577224058963521536}
# {'_id': ObjectId('5ac19b77a313fc02d6007010'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 45, 15),
#  'text': '☆★☆ JOB ALERT ☆★☆ #ITJob #Job #Sioux Falls - Database Analyst 4 '
#          '(SQL) http://t.co/5VsZsiRecp ☜ view full details',
#  'tweet_id': 577224064390983680}
# {'_id': ObjectId('5ac19b77a313fc02d6007011'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 45, 16),
#  'text': 'RT @phpusers: Re: Waiting for localhost http://t.co/FkmBzkP6Zt  #php '
#          '#database',
#  'tweet_id': 577224065540308993}
# {'_id': ObjectId('5ac19b77a313fc02d6007012'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 45, 17),
#  'text': 'RT @rkia_twitts: My 17 Predictions for Technology in 2015 #Cloud '
#          '#Wearables #BigData #IOT #3DPrinting #Selfie: http://t.co/0cmXLWxKoT '
#          'via @…',
#  'tweet_id': 577224069965295617}
# {'_id': ObjectId('5ac19b77a313fc02d6007013'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 45, 21),
#  'text': 'RT CraigMilroy: Important shift in thinking... The BBVA bank vaults '
#          'that hoard #bigdata instead of bullion http://t.co/k0sIrpiELj; via '
#          'FT …',
#  'tweet_id': 577224085953875968}
# {'_id': ObjectId('5ac19b77a313fc02d6007014'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 45, 23),
#  'text': '#Today - RECORDS, LIBRARY AND DATABASE MANAGEMENT WORKSHOP '
#          '#Zimbabwe  http://t.co/2ZLL1YISmx http://t.co/CyGYsMOXVo',
#  'tweet_id': 577224097165369345}
# {'_id': ObjectId('5ac19b77a313fc02d6007015'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 45, 32),
#  'text': 'Job: Database Administrator (Data Center) . Are you a fit? in '
#          'Pittsburgh, PA http://t.co/yE2yhaLqkY #job',
#  'tweet_id': 577224134704422912}
# {'_id': ObjectId('5ac19b77a313fc02d6007016'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 45, 34),
#  'text': 'The predict is made by using database "PinnaclePlus bet365".\n'
#          ' http://t.co/9XowKLMwnX',
#  'tweet_id': 577224141193003008}
# {'_id': ObjectId('5ac19b77a313fc02d6007017'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 45, 35),
#  'text': 'via @phpRTBot Re: Waiting for localhost   #php #database '
#          'http://t.co/CQMbFnRO1r',
#  'tweet_id': 577224148277207041}
# {'_id': ObjectId('5ac19b77a313fc02d6007018'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 45, 39),
#  'text': 'RT @joe_caserta: Why businesses should focus on wide data, not big '
#          'data by @ThorOlavsrud http://t.co/cWslYbhxbk via @CIOonline #bigdata',
#  'tweet_id': 577224164798513152}
# {'_id': ObjectId('5ac19b77a313fc02d6007019'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 45, 44),
#  'text': 'IRS illegally sent 1.1 million page database of legally protected '
#          'taxpayer information to FBI http://t.co/uBXDEMJPQN #TeaParty #tcot '
#          '#PJNet',
#  'tweet_id': 577224185216249857}
# {'_id': ObjectId('5ac19b77a313fc02d600701a'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 45, 53),
#  'text': '#nowplaying database feat.TAKUMA(10-FEET) - MAN WITH A MISSION',
#  'tweet_id': 577224223782879233}
# {'_id': ObjectId('5ac19b77a313fc02d600701b'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 46, 9),
#  'text': 'and who better to speak to the spirit of the American road trip than '
#          '"data geniuses" using an algorithm  https://t.co/pBXDMGRzkf',
#  'tweet_id': 577224289339899904}
# {'_id': ObjectId('5ac19b77a313fc02d600701c'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 46, 10),
#  'text': 'The Pioneering Technology In Sport: The Internet of things #iot '
#          '#mobile #wifi #bigdata\n'
#          'https://t.co/G81XaAbu3j',
#  'tweet_id': 577224294335438849}
# {'_id': ObjectId('5ac19b77a313fc02d600701d'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 46, 11),
#  'text': '@gaab75 @trufae (2/2) i think he is asking for a tradtnl database, '
#          'with drivers for userfs to access (sometimes) the db as a '
#          'filesystem.',
#  'tweet_id': 577224297787338752}
# {'_id': ObjectId('5ac19b77a313fc02d600701e'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 46, 19),
#  'text': 'RT @WSCP1: IRS illegally sent 1.1 million page database of legally '
#          'protected taxpayer information to FBI http://t.co/uBXDEMJPQN '
#          '#TeaParty #…',
#  'tweet_id': 577224330158981120}
# {'_id': ObjectId('5ac19b77a313fc02d600701f'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 46, 21),
#  'text': 'RT @robustus: Level 1: Bitcoin is scarce -&gt; valuable.\n'
#          'L. 2: Wait, BTC is just a "friggin database technology"\n'
#          'L. 3: Aha, *all* money is jus…',
#  'tweet_id': 577224340539863041}
# {'_id': ObjectId('5ac19b77a313fc02d6007020'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 46, 28),
#  'text': 'RT @bbvaopentalent: Financial Times about @bbva : The Bank that '
#          'hoards bytes instead of\n'
#          'bullion http://t.co/TS3wDgOcZt #fintech #bigdata ht…',
#  'tweet_id': 577224370193625089}
# {'_id': ObjectId('5ac19b77a313fc02d6007021'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 46, 48),
#  'text': 'RT @EnzoAngeles_: Usos de #BigData en Gobiernos, La Economía Digital '
#          'y el poder de las redes sociales “@xataka: http://t.co/6teI0yCz8w '
#          'http…',
#  'tweet_id': 577224453639303168}
# {'_id': ObjectId('5ac19b77a313fc02d6007022'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 46, 53),
#  'text': 'RT @MattBors: and who better to speak to the spirit of the American '
#          'road trip than "data geniuses" using an algorithm  '
#          'https://t.co/pBXDMGR…',
#  'tweet_id': 577224472941326336}
# {'_id': ObjectId('5ac19b77a313fc02d6007023'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 46, 55),
#  'text': 'The Algorithm That Tells the Boss Who Might Quit - WSJ '
#          'http://t.co/mZN75XM9KO',
#  'tweet_id': 577224480331714560}
# {'_id': ObjectId('5ac19b77a313fc02d6007024'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 47, 7),
#  'text': 'Software Database Developer - Aerotek: (#Frederick, MD) '
#          'http://t.co/xTkhOHGU20 #Engineering #Job #Jobs',
#  'tweet_id': 577224532542402560}
# {'_id': ObjectId('5ac19b77a313fc02d6007025'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 47, 11),
#  'text': 'RT @datacentretech: Data Centre Security: Few Useful Tips '
#          'http://t.co/yzXXgd9bOO #datacentre, #datacenter , #blog, #bigdata,',
#  'tweet_id': 577224547679793152}
# {'_id': ObjectId('5ac19b77a313fc02d6007026'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 47, 18),
#  'text': 'RT @Networkshashi: #BigData: Your Laptop Can Now Analyze BigData\n'
#          'http://t.co/3Mqjv1n5kx',
#  'tweet_id': 577224579938140160}
# {'_id': ObjectId('5ac19b77a313fc02d6007027'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 47, 53),
#  'text': '@jpflathead FOR PS4 Users tell them put their console into safe mode '
#          'and rebuild database, thank you',
#  'tweet_id': 577224724830355456}
# {'_id': ObjectId('5ac19b77a313fc02d6007028'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 47, 53),
#  'text': 'RT @takuma10feet: '
#          'モブスタイルス15周年広島来てくれたみんなありがとう！写真は今日のマンウィズとのオープニング一曲目"database '
#          'feat.takuma"の1分前。楽しかったなぁ。そして今日のthe trust… https://t.co/BTDfzG2…',
#  'tweet_id': 577224724700254208}
# {'_id': ObjectId('5ac19b77a313fc02d6007029'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 48, 2),
#  'text': 'BREAKING: The Algorithm That Tells the Boss Who Might Quit '
#          'http://t.co/ijfBHJc7B2 #teambho #imsleepyy',
#  'tweet_id': 577224764059705344}
# {'_id': ObjectId('5ac19b77a313fc02d600702a'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 48, 10),
#  'text': '★ JOB ALERT ★ #ITJob #Job #Jacksonville - Oracle Database '
#          'Administrator http://t.co/5UOrD4P5HV ☜ view full details #job '
#          '#hiring',
#  'tweet_id': 577224797207179264}
# {'_id': ObjectId('5ac19b77a313fc02d600702b'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 48, 10),
#  'text': 'RT @KMWeiland: Want to Know More About the Structure of Your '
#          'Favorite Books and Movies? Announcing the Story Structure Database! '
#          'http://t.c…',
#  'tweet_id': 577224797874094080}
# {'_id': ObjectId('5ac19b77a313fc02d600702c'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 48, 15),
#  'text': '★ JOB ALERT ★ #ITJob #Job #Burlington - Database Administrator SQL '
#          'DBA http://t.co/8M4fVlDwPD ☜ view full details',
#  'tweet_id': 577224818753323008}
# {'_id': ObjectId('5ac19b77a313fc02d600702d'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 48, 15),
#  'text': '★ JOB ALERT ★ #ITJob #Job #San Diego - SQL Database Developer '
#          'http://t.co/8zMhaSEg1j ☜ view full details #job',
#  'tweet_id': 577224819164364800}
# {'_id': ObjectId('5ac19b77a313fc02d600702e'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 48, 16),
#  'text': '★ JOB ALERT ★ #ITJob #Job #San Diego - SQL DATABASE DEVELOPER '
#          'http://t.co/LYmJGeJrd3 ☜ view full details #job',
#  'tweet_id': 577224823065034752}
# {'_id': ObjectId('5ac19b77a313fc02d600702f'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 48, 19),
#  'text': 'RT @MattBors: and who better to speak to the spirit of the American '
#          'road trip than "data geniuses" using an algorithm  '
#          'https://t.co/pBXDMGR…',
#  'tweet_id': 577224836092551168}
# {'_id': ObjectId('5ac19b77a313fc02d6007030'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 48, 36),
#  'text': 'RT @KirkDBorne: Free eBook: "Mining of Massive Datasets" '
#          'http://t.co/UTjL5zQZ15 #abdsc #DataMining #BigData #Analytics '
#          '#DataScience via @an…',
#  'tweet_id': 577224905294524416}
# {'_id': ObjectId('5ac19b77a313fc02d6007031'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 48, 38),
#  'text': 'RT @BigDataSoc: Do the Snowden disclosures indicate that#BigData '
#          'practices are becoming increasingly important to #surveillance? '
#          'http://t.c…',
#  'tweet_id': 577224912416436224}
# {'_id': ObjectId('5ac19b77a313fc02d6007032'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 48, 42),
#  'text': '¿Qué es la inteligencia de fuentes abiertas? http://t.co/xZaFOt5gKm '
#          'vía @TICbeat',
#  'tweet_id': 577224930137399296}
# {'_id': ObjectId('5ac19b77a313fc02d6007033'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 48, 55),
#  'text': 'RT @MattBors: and who better to speak to the spirit of the American '
#          'road trip than "data geniuses" using an algorithm  '
#          'https://t.co/pBXDMGR…',
#  'tweet_id': 577224984361246720}
# {'_id': ObjectId('5ac19b77a313fc02d6007034'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 48, 55),
#  'text': 'RT @MattBors: and who better to speak to the spirit of the American '
#          'road trip than "data geniuses" using an algorithm  '
#          'https://t.co/pBXDMGR…',
#  'tweet_id': 577224985103630336}
# {'_id': ObjectId('5ac19b77a313fc02d6007035'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 49, 1),
#  'text': 'RT @MattBors: and who better to speak to the spirit of the American '
#          'road trip than "data geniuses" using an algorithm  '
#          'https://t.co/pBXDMGR…',
#  'tweet_id': 577225009678196737}
# {'_id': ObjectId('5ac19b77a313fc02d6007036'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 49, 8),
#  'text': '@fuIani i feel like their only database for west Africa is igbo lol '
#          'so everything west african automatically clusters to that smh',
#  'tweet_id': 577225040241946624}
# {'_id': ObjectId('5ac19b77a313fc02d6007037'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 49, 11),
#  'text': 'RT @SStavrinoudakis: Fast detection of Cyber Threats through '
#          'advanced #BigData #Analytics http://t.co/Fov296lNtj #CyberSecurity',
#  'tweet_id': 577225051491184640}
# {'_id': ObjectId('5ac19b77a313fc02d6007038'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 49, 22),
#  'text': 'RT @MarcWilczek: In 2014, the digital universe equaled 1.7 megabytes '
#          'a minute for every person on Earth: http://t.co/gLf50KtZKx #Bigdata '
#          '#I…',
#  'tweet_id': 577225100568702976}
# {'_id': ObjectId('5ac19b77a313fc02d6007039'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 49, 26),
#  'text': 'RT @benayapaul: How to connect MySql database with Nodejs '
#          'http://t.co/Zpjy352KBs',
#  'tweet_id': 577225115793895424}
# {'_id': ObjectId('5ac19b77a313fc02d600703a'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 49, 29),
#  'text': 'RT @CalogeroRavenna: Gartner predicts 3 Big data trends for business '
#          'intelligence\n'
#          '#bigdata #businessintelligence http://t.co/rJ3pm3rfGy',
#  'tweet_id': 577225128267923456}
# {'_id': ObjectId('5ac19b77a313fc02d600703b'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 49, 35),
#  'text': 'Checkout our checklist for starting a staffing agency! WATCH THE '
#          'VIDEO:\xa0http://t.co/kGziayNRd2\xa0#bigdata #java #iot #salesforce '
#          '#startup #yes',
#  'tweet_id': 577225152301268993}
# {'_id': ObjectId('5ac19b77a313fc02d600703c'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 49, 36),
#  'text': 'Database (DBA) Manager http://t.co/pxhj2j4riY',
#  'tweet_id': 577225158663872513}
# {'_id': ObjectId('5ac19b77a313fc02d600703d'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 49, 42),
#  'text': 'RCMP database remains out of date, police and prosecutors say  '
#          'http://t.co/TmFmkHJ8wF',
#  'tweet_id': 577225181711753216}
# {'_id': ObjectId('5ac19b77a313fc02d600703e'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 49, 42),
#  'text': 'Now hiring for: T-SQL Database / SSIS ETL Developer – “This is the '
#          'place for Data Geeks” in Milwaukee, WI http://t.co/ICoK2VwplX #job',
#  'tweet_id': 577225183070691329}
# {'_id': ObjectId('5ac19b77a313fc02d600703f'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 49, 53),
#  'text': 'RT @WSCP1: IRS illegally sent 1.1 million page database of legally '
#          'protected taxpayer information to FBI http://t.co/uBXDEMJPQN '
#          '#TeaParty #…',
#  'tweet_id': 577225228062838784}
# {'_id': ObjectId('5ac19b77a313fc02d6007040'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 50),
#  'text': 'So....what exactly is #bigdata? [Blog]  http://t.co/E2f74eNrOO',
#  'tweet_id': 577225259843231745}
# {'_id': ObjectId('5ac19b77a313fc02d6007041'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 50, 5),
#  'text': '4 Ways the Future of Big Data Will Change the Way We Work and Live '
#          'http://t.co/fg3Ym2CtOA #BigData #Cloud',
#  'tweet_id': 577225277396377600}
# {'_id': ObjectId('5ac19b77a313fc02d6007042'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 50, 7),
#  'text': 'Oracle Database Developer/ Engineer - Rockville, MD '
#          'http://t.co/yzhs7GqmGG',
#  'tweet_id': 577225286699360257}
# {'_id': ObjectId('5ac19b77a313fc02d6007043'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 50, 21),
#  'text': 'Expedia Asia Pacific: Application Engineer II (#Gurgaon) '
#          'http://t.co/wDThMbzRlX #Database #ExpediaJobs #Job #Jobs',
#  'tweet_id': 577225344987480064}
# {'_id': ObjectId('5ac19b77a313fc02d6007044'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 50, 24),
#  'text': 'RT @CANSQL: Congratulation to #BigData #Hackathon winners in Data '
#          'Modelling: Toronto Parking Ticket Revenue Forecaster project '
#          'http://t.co/…',
#  'tweet_id': 577225356769366016}
# {'_id': ObjectId('5ac19b77a313fc02d6007045'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 50, 25),
#  'text': 'New Paper: An Improved Image Mosaicing Algorithm for Damaged '
#          'Documents \n'
#          'http://t.co/NxmUcmRH98 #forensic',
#  'tweet_id': 577225361550909440}
# {'_id': ObjectId('5ac19b77a313fc02d6007046'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 50, 33),
#  'text': 'RT @DByresPHC: How much data is generated every minute? #BigData '
#          'never sleeps. @EddieBeardDNP @MaryJaneNeri1 http://t.co/7dwgtphJ3B',
#  'tweet_id': 577225397978460160}
# {'_id': ObjectId('5ac19b77a313fc02d6007047'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 50, 45),
#  'text': 'RT @MDMGeek: 4 Ways the Future of Big Data Will Change the Way We '
#          'Work and Live http://t.co/fg3Ym2CtOA #BigData #Cloud',
#  'tweet_id': 577225446754000896}
# {'_id': ObjectId('5ac19b77a313fc02d6007048'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 50, 45),
#  'text': 'RT @sarahaustin: NYC bound #NewYork #advertising #madisonave '
#          '#BigData #deeplistening #conferencetime',
#  'tweet_id': 577225447269928960}
# {'_id': ObjectId('5ac19b77a313fc02d6007049'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 50, 45),
#  'text': 'RT @TrendSource: So....what exactly is #bigdata? [Blog]  '
#          'http://t.co/E2f74eNrOO',
#  'tweet_id': 577225447521546240}
# {'_id': ObjectId('5ac19b77a313fc02d600704a'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 50, 45),
#  'text': 'RT @no1networker: Checkout our checklist for starting a staffing '
#          'agency! WATCH THE VIDEO:\xa0http://t.co/kGziayNRd2\xa0#bigdata #java '
#          '#iot #sales…',
#  'tweet_id': 577225448599457792}
# {'_id': ObjectId('5ac19b77a313fc02d600704b'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 50, 46),
#  'text': 'RT @CalogeroRavenna: Gartner predicts 3 Big data trends for business '
#          'intelligence\n'
#          '#bigdata #businessintelligence http://t.co/rJ3pm3rfGy',
#  'tweet_id': 577225449375399936}
# {'_id': ObjectId('5ac19b77a313fc02d600704c'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 51),
#  'text': 'What Is #BigData #Discovery? A #trend to watch out in next two '
#          'years! http://t.co/sWJ0sp9DBH',
#  'tweet_id': 577225507885973504}
# {'_id': ObjectId('5ac19b77a313fc02d600704d'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 51, 9),
#  'text': "RT @IMAGINiT_Tech: Autodesk Foundation's new #impactdesign database; "
#          'resources to help create a better world http://t.co/tNA0pvTtG6 '
#          'http://…',
#  'tweet_id': 577225545676677120}
# {'_id': ObjectId('5ac19b77a313fc02d600704e'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 51, 20),
#  'text': "Pagerank Algorithm Reveals World's All-Time Top Soccer Team "
#          'http://t.co/UMxpLtH8iu',
#  'tweet_id': 577225595186061312}
# {'_id': ObjectId('5ac19b77a313fc02d600704f'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 51, 21),
#  'text': '☆★☆ JOB ALERT ☆★☆ #ITJob #Job #Los Angeles - Access Database '
#          'Programmer http://t.co/MRvEBCJ8f8 ☜ view full details',
#  'tweet_id': 577225598017220608}
# {'_id': ObjectId('5ac19b77a313fc02d6007050'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 51, 24),
#  'text': '@KerryRoushey @trutherbot Do you understand hacking moron?  '
#          'Trutherbot is an algorithm muncher.  Try again evil.',
#  'tweet_id': 577225611363688448}
# {'_id': ObjectId('5ac19b77a313fc02d6007051'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 51, 35),
#  'text': 'Database appraising abrege: nwLzFLMkp',
#  'tweet_id': 577225655579860992}
# {'_id': ObjectId('5ac19b77a313fc02d6007052'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 51, 40),
#  'text': "RT @portlandhead: Your site's not mobile friendly? You may want to "
#          "get moving. @Google's changing its algorithm: http://t.co/NfxJlLOULA "
#          '#mt…',
#  'tweet_id': 577225676056489985}
# {'_id': ObjectId('5ac19b77a313fc02d6007053'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 51, 40),
#  'text': 'Adapt your customer service strategies, or die. '
#          'http://t.co/qGVqGtWmgI #VoiceOfCustomer #BigData #Tungsten',
#  'tweet_id': 577225676811583488}
# {'_id': ObjectId('5ac19b77a313fc02d6007054'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 51, 44),
#  'text': 'RT @takuma10feet: '
#          'モブスタイルス15周年広島来てくれたみんなありがとう！写真は今日のマンウィズとのオープニング一曲目"database '
#          'feat.takuma"の1分前。楽しかったなぁ。そして今日のthe trust… https://t.co/BTDfzG2…',
#  'tweet_id': 577225693966176256}
# {'_id': ObjectId('5ac19b77a313fc02d6007055'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 51, 48),
#  'text': '@danechkin send data to graphite or compatible database',
#  'tweet_id': 577225709174845440}
# {'_id': ObjectId('5ac19b77a313fc02d6007056'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 51, 57),
#  'text': '@BiancaGoes68 zie het nu pas, źit bijna nooit meer op Twitter. '
#          'Lijken ok te zijn. Ik laat het voor de zekerheid checken in de land. '
#          'database',
#  'tweet_id': 577225749100363777}
# {'_id': ObjectId('5ac19b77a313fc02d6007057'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 52, 4),
#  'text': '¿Qué es la inteligencia de fuentes abiertas? http://t.co/vBHfYvOgHi',
#  'tweet_id': 577225779387494400}
# {'_id': ObjectId('5ac19b77a313fc02d6007058'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 52, 7),
#  'text': 'Tus #tickets d compra en tu #smartphone http://t.co/Ush5fCgQ3n …  '
#          '#bigdata #gifts #shopping #WanasConceptStore\n'
#          '#Zamalek #Cairo',
#  'tweet_id': 577225792364670976}
# {'_id': ObjectId('5ac19b77a313fc02d6007059'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 52, 15),
#  'text': 'No she didn\'t just write "highjean..." Adding it to the database. '
#          '#MinusWell',
#  'tweet_id': 577225822399942656}
# {'_id': ObjectId('5ac19b77a313fc02d600705a'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 52, 19),
#  'text': "What's in Your Movie Database? http://t.co/7l1SH1zJcP "
#          '#BestMovieStories',
#  'tweet_id': 577225838950637568}
# {'_id': ObjectId('5ac19b77a313fc02d600705b'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 52, 30),
#  'text': 'RT @jalopezg70: 23andMe to Use Genetic Database for Drug Discovery '
#          'http://t.co/8s6OpKTEOx via @rightrelevance thanks @wsjhealth',
#  'tweet_id': 577225887713771521}
# {'_id': ObjectId('5ac19b77a313fc02d600705c'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 52, 34),
#  'text': 'Transmittance skills: guest blog in keeping with jessica sanders3 '
#          'ways in order to impose algorithm forasmuch as… '
#          'http://t.co/4RnL5ELMaw',
#  'tweet_id': 577225905157718016}
# {'_id': ObjectId('5ac19b77a313fc02d600705d'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 52, 45),
#  'text': '“@ForensicDocHW: New Paper: An Improved Image Mosaicing Algorithm '
#          'for Damaged Documents \n'
#          'http://t.co/xRAJRY1uDe #forensic”',
#  'tweet_id': 577225950150176769}
# {'_id': ObjectId('5ac19b77a313fc02d600705e'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 52, 45),
#  'text': 'RT @robustus: Level 1: Bitcoin is scarce -&gt; valuable.\n'
#          'L. 2: Wait, BTC is just a "friggin database technology"\n'
#          'L. 3: Aha, *all* money is jus…',
#  'tweet_id': 577225951202971649}
# {'_id': ObjectId('5ac19b77a313fc02d600705f'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 52, 48),
#  'text': '@Contexti at @CiscoLiveMEL sharing lessons from 36+ engagements in '
#          '#BigData #Platforms for #Analytics &amp; #IoT  #CLMel',
#  'tweet_id': 577225961076187136}
# {'_id': ObjectId('5ac19b77a313fc02d6007060'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 52, 48),
#  'text': 'Everilion:the evolution of #Commerce: http://t.co/pIKJ0ZphGK '
#          '#bigdata #ecommerce #gifts #shopping #WanasConceptStore\n'
#          '#Zamalek #Cairo',
#  'tweet_id': 577225963769110528}
# {'_id': ObjectId('5ac19b77a313fc02d6007061'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 52, 49),
#  'text': 'It’s time for action in EU Data Protection Directive #BigData - '
#          'http://t.co/Iv8Q6ZGCPO',
#  'tweet_id': 577225968043057153}
# {'_id': ObjectId('5ac19b77a313fc02d6007062'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 52, 51),
#  'text': 'RT @VPROTegenlicht: Planten groeien met LED-lampen, een database vol '
#          'smaken en meer Digitaal Voedsel straks om 21.05 uur op #npo2 bij '
#          'VPRO …',
#  'tweet_id': 577225973504049152}
# {'_id': ObjectId('5ac19b77a313fc02d6007063'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 52, 51),
#  'text': 'RT @robustus: Level 1: Bitcoin is scarce -&gt; valuable.\n'
#          'L. 2: Wait, BTC is just a "friggin database technology"\n'
#          'L. 3: Aha, *all* money is jus…',
#  'tweet_id': 577225977023066112}
# {'_id': ObjectId('5ac19b77a313fc02d6007064'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 52, 57),
#  'text': 'Is it Pokémon or #bigdata technology? https://t.co/q0WL7c77uM',
#  'tweet_id': 577226001047904256}
# {'_id': ObjectId('5ac19b77a313fc02d6007065'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 53, 7),
#  'text': 'Facial Expression Cloning with Elastic and Muscle Models: a novel '
#          'algorithm is proposed for facial expression cloning '
#          'http://t.co/LAKQCmL6kx',
#  'tweet_id': 577226041028038656}
# {'_id': ObjectId('5ac19b77a313fc02d6007066'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 53, 17),
#  'text': 'Apply to this job: Big Data Technologist / Architect in New York, NY '
#          'http://t.co/8zpq8q9XYA #job#BigData',
#  'tweet_id': 577226084355280897}
# {'_id': ObjectId('5ac19b77a313fc02d6007067'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 53, 18),
#  'text': 'RT @no1networker: Checkout our checklist for starting a staffing '
#          'agency! WATCH THE VIDEO:\xa0http://t.co/kGziayNRd2\xa0#bigdata #java '
#          '#iot #sales…',
#  'tweet_id': 577226086557319168}
# {'_id': ObjectId('5ac19b77a313fc02d6007068'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 53, 21),
#  'text': 'RT @fintechna: RT CraigMilroy: Important shift in thinking... The '
#          'BBVA bank vaults that hoard #bigdata instead of bullion '
#          'http://t.co/k0sIr…',
#  'tweet_id': 577226101354823683}
# {'_id': ObjectId('5ac19b77a313fc02d6007069'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 53, 23),
#  'text': 'RT @link2i: Using #Analytics to build A #BigData #Workforce '
#          'http://t.co/i6mAykoAjI #talentAnalytics #hr',
#  'tweet_id': 577226110758338561}
# {'_id': ObjectId('5ac19b77a313fc02d600706a'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 53, 24),
#  'text': 'RT @bretones: La solution de big data « #FluxVision » plébiscitée '
#          'par les acteurs du #tourisme http://t.co/aaae5g2zAT via @orange '
#          '#bigdata',
#  'tweet_id': 577226113396711425}
# {'_id': ObjectId('5ac19b77a313fc02d600706b'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 53, 25),
#  'text': 'Quickly &amp; easily manage your website &amp; database. No more '
#          'tedious website builders which make you do all of the work\n'
#          'http://t.co/km6NDdcwoI',
#  'tweet_id': 577226119805448193}
# {'_id': ObjectId('5ac19b77a313fc02d600706c'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 53, 26),
#  'text': "Facebook's Steve Hatch: The algorithm is king, but people still set "
#          'the rules http://t.co/DdB94wK0XB',
#  'tweet_id': 577226121890164736}
# {'_id': ObjectId('5ac19b77a313fc02d600706d'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 53, 29),
#  'text': 'RT @D3EKSHA: #Chicago #BigData Job Seekers &amp; #Recruiters, '
#          'Checkout #Data #AnalyticsFair on #24MAR2015 http://t.co/u6wFVtEJGM '
#          '#ord',
#  'tweet_id': 577226133474713600}
# {'_id': ObjectId('5ac19b77a313fc02d600706e'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 53, 36),
#  'text': 'RT @Intellipaat: Script level functions and chart level functions '
#          'knowledge with Qlikview Training. http://t.co/xSeORpyyDO #Bigdata '
#          '#BI #Ql…',
#  'tweet_id': 577226164478996481}
# {'_id': ObjectId('5ac19b77a313fc02d600706f'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 53, 42),
#  'text': 'RT @anthonylrx: #Bigdata makes big promises but for the most part it '
#          'has been a big let down. - @tylerdouglas http://t.co/GvQysKAKtT '
#          '#ILove…',
#  'tweet_id': 577226187329523713}
# {'_id': ObjectId('5ac19b77a313fc02d6007070'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 53, 42),
#  'text': '11 Database Administrator Tools For System Admins '
#          'http://t.co/Yp12Za8Xrd',
#  'tweet_id': 577226190504620032}
# {'_id': ObjectId('5ac19b77a313fc02d6007071'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 54, 2),
#  'text': 'Speculation on Google Fact Database finding errors in common beliefs '
#          'and other interesting stories on ReflectiveAir16 '
#          'http://t.co/LrVBCvQU0U',
#  'tweet_id': 577226272721383424}
# {'_id': ObjectId('5ac19b77a313fc02d6007072'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 54, 4),
#  'text': 'Oracle Exadata Database и приложений наших клиентов появляются новые '
#          'возможности хранения данных. Комплексное',
#  'tweet_id': 577226280023797760}
# {'_id': ObjectId('5ac19b77a313fc02d6007073'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 54, 5),
#  'text': 'RT @zackjesus: 17 Predictions for Technology in 2015 #Cloud '
#          '#Wearables #BigData #IOT #3DPrinting #Selfie: http://t.co/cTAQxjQ4Oq '
#          'via @Timot…',
#  'tweet_id': 577226284901773313}
# {'_id': ObjectId('5ac19b77a313fc02d6007074'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 54, 5),
#  'text': 'RT @DataMentors: Three #BigData Use Cases for #Marketers '
#          'http://t.co/hytr0D7JLb http://t.co/ohK7dUk9LB',
#  'tweet_id': 577226287720230912}
# {'_id': ObjectId('5ac19b77a313fc02d6007075'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 54, 11),
#  'text': 'For those who live in the age of the algorithm, remember all '
#          'algorithms ultimately hit up against a moral issue '
#          'http://t.co/VKNZ0ZvjTy',
#  'tweet_id': 577226308905791488}
# {'_id': ObjectId('5ac19b77a313fc02d6007076'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 54, 11),
#  'text': 'RT D3EKSHA: #Chicago #BigData Job Seekers &amp; #Recruiters, '
#          'Checkout #Data #AnalyticsFair on #24MAR2015 … http://t.co/Lt2hK8O3w2',
#  'tweet_id': 577226309086085120}
# {'_id': ObjectId('5ac19b77a313fc02d6007077'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 54, 11),
#  'text': 'For those who live in the age of the algorithm, remember all '
#          'algorithms ultimately hit up against a moral issue '
#          'http://t.co/wtUXNQ7Qd6',
#  'tweet_id': 577226309727825920}
# {'_id': ObjectId('5ac19b77a313fc02d6007078'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 54, 11),
#  'text': 'RT @takuma10feet: '
#          'モブスタイルス15周年広島来てくれたみんなありがとう！写真は今日のマンウィズとのオープニング一曲目"database '
#          'feat.takuma"の1分前。楽しかったなぁ。そして今日のthe trust… https://t.co/BTDfzG2…',
#  'tweet_id': 577226312667914240}
# {'_id': ObjectId('5ac19b77a313fc02d6007079'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 54, 15),
#  'text': 'Important shift in thinking: The #BBVA #bank vaults that hoard '
#          '#bigdata instead of bullion http://t.co/YbKPTZQuyb @fintechna '
#          '@CraigMilroy',
#  'tweet_id': 577226327297798145}
# {'_id': ObjectId('5ac19b77a313fc02d600707a'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 54, 15),
#  'text': 'RT @cobusinessSol: The third #technological era is coming #IoT '
#          'http://t.co/KbRBtWeCyJ #wearables #SmartCities #cloud #BigData '
#          'http://t.co/I…',
#  'tweet_id': 577226327343771648}
# {'_id': ObjectId('5ac19b77a313fc02d600707b'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 54, 17),
#  'text': '#Environment #Environmental Concerns &amp; Issues #Green Industry '
#          'International Media Contact Database: 15,946 Contacts '
#          'http://t.co/jeywugxSJh',
#  'tweet_id': 577226337494175744}
# {'_id': ObjectId('5ac19b77a313fc02d600707c'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 54, 22),
#  'text': "RT @mgzeuthen: I'm looking for a publisher/blogger to alpha test our "
#          'new mobile ad technology. DM me or sign up at http://t.co/oLgTS7Ewnv '
#          '#…',
#  'tweet_id': 577226355768713216}
# {'_id': ObjectId('5ac19b77a313fc02d600707d'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 54, 23),
#  'text': 'RT @JohndeVoogd: Big data, meet dumb data: How CMOs are driving '
#          'value from data (report) | VentureBeat  | by VB Staff '
#          'http://t.co/p78DxIQK9…',
#  'tweet_id': 577226362689224704}
# {'_id': ObjectId('5ac19b77a313fc02d600707e'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 54, 25),
#  'text': '@atomsoffice @maxschrems German car industry wants to use #bigdata '
#          "hence #Merkel's @RegSprecher's volte face",
#  'tweet_id': 577226369781915648}
# {'_id': ObjectId('5ac19b77a313fc02d600707f'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 54, 34),
#  'text': 'RT @AdvanceVentures: Adding Security of Things to the '
#          '#InternetofThings http://t.co/VQUtGIdn4S #CIO #hacking #VC #startups '
#          '#BigData #M2M #s…',
#  'tweet_id': 577226406104424448}
# {'_id': ObjectId('5ac19b77a313fc02d6007080'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 54, 36),
#  'text': 'BethanyHedger1: RT zackjesus: 17 Predictions for Technology in 2015 '
#          '#Cloud #Wearables #BigData #IOT #3DPrinting #Selfie: …',
#  'tweet_id': 577226415390777346}
# {'_id': ObjectId('5ac19b77a313fc02d6007081'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 54, 38),
#  'text': 'RT @Startuppodden: Ute nu: #StartuppoddengoesSUP46   @JohanAttby vd '
#          'Fishbrain, om hur man bygger community med #bigdata #sthlmtech '
#          'http://t…',
#  'tweet_id': 577226426086256640}
# {'_id': ObjectId('5ac19b77a313fc02d6007082'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 54, 45),
#  'text': 'Opening up data unlocks citizenship http://t.co/cahubKsL2U #BigData',
#  'tweet_id': 577226453487616000}
# {'_id': ObjectId('5ac19b77a313fc02d6007083'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 54, 45),
#  'text': 'German industry is poised to exploit rural broadband '
#          'http://t.co/IPMr0CEziy #BigData',
#  'tweet_id': 577226454901137410}
# {'_id': ObjectId('5ac19b77a313fc02d6007084'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 54, 48),
#  'text': 'RT @bobehayes: #DataScience team has #statistics, business &amp; '
#          'comp engine skills 》 How #bigdata can make tracks in the rail '
#          'industry http://…',
#  'tweet_id': 577226466422710272}
# {'_id': ObjectId('5ac19b77a313fc02d6007085'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 54, 49),
#  'text': 'RT @robustus: Level 1: Bitcoin is scarce -&gt; valuable.\n'
#          'L. 2: Wait, BTC is just a "friggin database technology"\n'
#          'L. 3: Aha, *all* money is jus…',
#  'tweet_id': 577226470428377088}
# {'_id': ObjectId('5ac19b77a313fc02d6007086'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 54, 50),
#  'text': 'RT @DataScientistFr: Leading Marketing Excellence With Analytics '
#          'http://t.co/92XV9CUUpO #BigData #Analytics',
#  'tweet_id': 577226472819150848}
# {'_id': ObjectId('5ac19b77a313fc02d6007087'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 54, 56),
#  'text': 'Go to http://t.co/CXA80Vrygd RT BethanyHedger1 RT zackjesus: 17 '
#          'Predictions for Technology in 2015 #Cloud #Wearables #BigData #IOT '
#          '#3DPri…',
#  'tweet_id': 577226501369831425}
# {'_id': ObjectId('5ac19b77a313fc02d6007088'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 55, 2),
#  'text': 'RT @MDMGeek: 4 Ways the Future of Big Data Will Change the Way We '
#          'Work and Live http://t.co/fg3Ym2CtOA #BigData #Cloud',
#  'tweet_id': 577226522777534464}
# {'_id': ObjectId('5ac19b77a313fc02d6007089'),
#  'created_at': datetime.datetime(2015, 3, 15, 21, 55, 2),
#  'text': 'RT @realzips: @dginerh thank you for RealZips Fav! Check '
#          'http://t.co/lJ02A2mMdc #crm #sales #bigdata',
#  'tweet_id': 577226526778728448}

# %% [markdown]
# Updated April 1, 2018
