# %% [markdown]
# # MongoDB Load CSV with python

# %%
# %matplotlib inline
import pymongo
from pymongo import MongoClient
from pymongo.errors import ConnectionFailure
from bson import json_util, ObjectId
import pandas as pd
from pandas import DataFrame
from pandas.io.json import json_normalize
import numpy as np
import requests
import json, os
import configparser
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import seaborn as sns
import warnings
import random
import pprint
from datetime import datetime
random.seed(datetime.now())
warnings.filterwarnings('ignore')

# Make plots larger
plt.rcParams['figure.figsize'] = (10, 6)

# %%
config = configparser.ConfigParser()
config.read('./data/mongo.ini')
# Out:
# ['./data/mongo.ini']

# %%
client = MongoClient(config.get('Mongo', 'host'), int(config.get('Mongo', 'port')))

# %%
db=client.tweets

# %%
db.collection_names(include_system_collections=False)
# Out:
# []

# %%
try:
    result = db.tweets.drop()
    print ("analytics tweets dropped")
except:
    pass
# Out:
# analytics tweets dropped

# %%
def load_csv(csv):
    p=os.path.join("data/", csv)
    print (p)
    data=pd.read_csv(p, encoding = "ISO-8859-1", engine='python')
    return data

# %%
tweets_csv=load_csv('Twitter.csv')
tweets_csv.head()
# Out:
# data/Twitter.csv
#                    id           created_at  retweet_count user_screen_name  \
# 0  967184683178930000  2018-02-23 23:49:32             36         1AvgGirl
# 1  967184696890352000  2018-02-23 23:49:35              1     sadiepeaches
# 2  967184759792263000  2018-02-23 23:49:50              0           csgoKW
# 3  967184785310409000  2018-02-23 23:49:56              0    MaxContrerasR
# 4  967184841467974000  2018-02-23 23:50:10              0        WAVEDUPZO
#
#    user_followers_count                 user_location  hashtags  \
# 0                    45               California, USA        []
# 1                  5225  cabin 4 ? i was here too. VM        []
# 2                    76       Cape Town, South Africa        []
# 3                   177                     Room #427        []
# 4                  5195          WESTCOAST ?? HOUSTON  [ "Duh"]
#
#                                                 text
# 0  RT @netflix: When Letitia Wright gets behind t...
# 1  RT @its_willyu: STOP. WRITING. AROUND. US. @ne...
# 2  @lostinspacetv @netflix Looks Amazing! Can?t w...
# 3  @joelmchale @netflix @NetflixLAT Siempre quere...
# 4  I think @netflix should buy the rights to ?Pop...

# %%
tweets_j=json.loads(tweets_csv.to_json(orient='records'))
tweets_j[0]
# Out:
# {'created_at': '2018-02-23 23:49:32',
#  'hashtags': '[]',
#  'id': 967184683178930000,
#  'retweet_count': 36,
#  'text': 'RT @netflix: When Letitia Wright gets behind the wheel, you know something badass is about to happen.',
#  'user_followers_count': 45,
#  'user_location': 'California, USA',
#  'user_screen_name': '1AvgGirl'}

# %%
print(tweets_j[0]['text'])
# Out:
# RT @netflix: When Letitia Wright gets behind the wheel, you know something badass is about to happen.

# %%
def tweet_json(tid,text,created):
    j={
    "tweet_id" : tid,
    "text" : text,
    "created_at" : created}
    return j

# %%
# Twitter dates are of the form Sun Mar 15 21:41:54 +0000 2015
datestrings=['Sun Mar 15 21:41:54 +0000 2015','Tue Mar 29 08:11:25 +0000 2011']
datestringsTwo=['2018-02-23 23:49:32','2018-02-23 23:49:32']
from datetime import timedelta
from email.utils import parsedate_tz
from dateutil.parser import parse

def to_datetime(datestring):   
    time_tuple = parse(datestring.strip())   
    dt = datetime.strptime(datestring.strip(), '%Y-%m-%d %H:%M:%S') 
    return dt

ts=to_datetime(datestringsTwo[0])
print (ts.strftime("%Y-%m-%d %H:%M"))
ts=to_datetime(datestringsTwo[1])
print (ts.strftime("%Y-%m-%d %H:%M"))
# Out:
# 2018-02-23 23:49
# 2018-02-23 23:49

# %%
cnt=0
for tweet in tweets_j:
    ts=datetime.now()
    try:
        ts=to_datetime(tweet['created_at'])
    except:
        continue     
    try:
        j=tweet_json(tweet['id'],tweet['text'],ts)
        result = db.tweets.insert_one(j)
        cnt+=1
    except:
        pass       
print ("%d tweets inserted."%cnt)
# Out:
# 534 tweets inserted.

# %%
for tweet in db.tweets.find():
    pprint.pprint(tweet)
# Out:
# {'_id': ObjectId('5ac44aafa313fc07c984ebac'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 49, 32),
#  'text': 'RT @netflix: When Letitia Wright gets behind the wheel, you know '
#          'something badass is about to happen.',
#  'tweet_id': 967184683178930000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebad'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 49, 35),
#  'text': 'RT @its_willyu: STOP. WRITING. AROUND. US. @netflix',
#  'tweet_id': 967184696890352000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebae'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 49, 50),
#  'text': '@lostinspacetv @netflix Looks Amazing! Can?t wait!',
#  'tweet_id': 967184759792263000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebaf'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 49, 56),
#  'text': '@joelmchale @netflix @NetflixLAT Siempre queremos m\xa0s!',
#  'tweet_id': 967184785310409000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebb0'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 50, 10),
#  'text': 'I think @netflix should buy the rights to ?Pop Up Video? and make '
#          'the pop-ups an option you can turn on and off on?',
#  'tweet_id': 967184841467974000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebb1'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 50, 39),
#  'text': "Wow. Bump the studios. @Netflix is setting the race now. Y'all keep "
#          'tripping and snubbing they gonna force their wa?',
#  'tweet_id': 967184962846888000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebb2'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 50, 47),
#  'text': 'RT @WestNewYorker: Enjoy our look around Boulder City, #Nevada at '
#          "Antique shops. In today's post, I suggest some great @netflix shows "
#          'that?',
#  'tweet_id': 967184997680529000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebb3'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 51, 3),
#  'text': 'RT @lostinspacetv: Danger, Will Robinson! #LostInSpace arrives April '
#          '13 on @Netflix.',
#  'tweet_id': 967185064185553000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebb4'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 51, 4),
#  'text': "Why does @netflix never put out the sequels of movies????? I've "
#          'already watched the first one, let me watch them all!',
#  'tweet_id': 967185068010738000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebb5'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 51, 7),
#  'text': 'Why don?t you make it easy on me and be merciful on my heart and '
#          'just be free .. please? @Netflix',
#  'tweet_id': 967185080555721000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebb6'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 51, 15),
#  'text': '@rachlanger @ytv @netflix @reboottgc No.',
#  'tweet_id': 967185114001162000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebb7'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 51, 43),
#  'text': 'RT @netflix: All trust issues with people named "Sarah" can be '
#          'traced back to this moment in "The Land Before Time"',
#  'tweet_id': 967185230955188000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebb8'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 51, 47),
#  'text': 'RT @RobbieAmell: I will be on season 2 of A series of Unfortunate '
#          'Events! Streaming soon on @netflix Unfortunately the mustache isn?t '
#          'real?',
#  'tweet_id': 967185249523319000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebb9'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 51, 56),
#  'text': 'RT @Kai56405432: #ReneeOConnor #XenaRevival and Original Cast '
#          '@NetflixLifee @netflix @robtapert @NBCUniversal please, please, '
#          'please!!! @SY?',
#  'tweet_id': 967185287779627000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebba'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 52, 3),
#  'text': 'RT @DavidKHarbour: quit flirting with me @netflix . ??',
#  'tweet_id': 967185317953397000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebbb'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 52, 25),
#  'text': '@Mardigroan @netflix Come on I wasted $2.50 !',
#  'tweet_id': 967185410182058000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebbc'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 52, 34),
#  'text': '@NetflixFR hello @netflix, depuis la derni\x8are mise \x85'
#          " jour de l'apps sur @PlayStation #ps4 (le 17/2). Voici le messa?",
#  'tweet_id': 967185444717941000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebbd'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 52, 43),
#  'text': 'Thoughts on the new @netflix original film @mute the latest from '
#          '@ManMadeMoon - come for the awesome Rudd performan?',
#  'tweet_id': 967185485226480000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebbe'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 52, 49),
#  'text': '@JohnBechard @netflix Documentary?',
#  'tweet_id': 967185510128026000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebbf'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 52, 49),
#  'text': 'RT @Nastentsija: I want Friday with the Season 3 #DirkGently '
#          '@Netflix, please, #SaveDirkGently We love this wonderful show!????',
#  'tweet_id': 967185510824399000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebc0'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 53, 1),
#  'text': "the cluster appearing behind wolfgang and kala with her 'bring it "
#          "bitch' will always be so epic?",
#  'tweet_id': 967185560065511000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebc1'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 53, 7),
#  'text': 'circles of hell: 1. limbo 2. lust 3. gluttony 4. greed 5. anger 6. '
#          'heresy 7. violence 8. fraud 9. treachery 10. the?',
#  'tweet_id': 967185583893180000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebc2'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 53, 10),
#  'text': '@Stitchpunk83 @netflix I may, too. So many other things to watch, '
#          'though. You should see my Tivos ??',
#  'tweet_id': 967185599001084000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebc3'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 53, 13),
#  'text': '@netflix Yasss #Shuri #WakandaForever Love to you @letitiawright '
#          '??????',
#  'tweet_id': 967185609948189000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebc4'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 53, 23),
#  'text': 'RT @Danadavidss: @NetflixUK @netflix',
#  'tweet_id': 967185650188542000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebc5'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 53, 24),
#  'text': "@JohnBechard @netflix I recommend you don't feel guilty about that.",
#  'tweet_id': 967185657625043000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebc6'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 53, 34),
#  'text': 'Dear @davidchang, you?re awesome and @uglydelicious @netflix is '
#          'awesome. #UglyDelicious',
#  'tweet_id': 967185696669618000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebc7'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 53, 36),
#  'text': '@netflix i miss doctor who fuck u guys',
#  'tweet_id': 967185706505314000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebc8'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 53, 40),
#  'text': 'RT @Kira38931594: Xena deserve Revival or Movie @robtapert @SYFY '
#          '@NBCUniversal @netflix @HBO @nbc and we no need reboot! #XenaRevival '
#          'https?',
#  'tweet_id': 967185722837905000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebc9'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 53, 47),
#  'text': '@keriqbaum @netflix @MINDHUNTER_ I will check it out!',
#  'tweet_id': 967185751858278000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebca'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 53, 52),
#  'text': 'RT @netflix: Everything In My Life Changed When @The_OA Cast Me As A '
#          'Transgender Teen',
#  'tweet_id': 967185773354209000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebcb'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 53, 53),
#  'text': '@shudder &gt;&gt;&gt; @netflix',
#  'tweet_id': 967185775799529000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebcc'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 53, 55),
#  'text': 'RT @AnaMSL4ever: #XenaRevival #XenaMovie #XXisforXENA Original Cast '
#          '@NetflixLifee @netflix @NBCUniversal @robtapert @nbc '
#          '@RealLucyLawless @?',
#  'tweet_id': 967185786113266000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebcd'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 53, 56),
#  'text': 'RT @MalalaFund: SAVE THE DATE: @Malala appears on @Netflix with '
#          'legendary talk show host David @Letterman on March 9! ????',
#  'tweet_id': 967185791494521000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebce'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 54, 3),
#  'text': 'RT @JohnBechard: I haven?t watched @Netflix for a week or so and now '
#          'I?m feeling guilty. Recommendations?',
#  'tweet_id': 967185820263375000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebcf'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 54, 16),
#  'text': "@pieeatingchamp @netflix I know what I'm watching tonight!",
#  'tweet_id': 967185874818687000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebd0'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 54, 19),
#  'text': 'RT @AnaMSL4ever: #XenaRevival #XenaMovie #XXisforXENA Original Cast '
#          '#ReneeOConnor @NetflixLifee @netflix @NBCUniversal @robtapert @nbc '
#          '@Rea?',
#  'tweet_id': 967185886931808000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebd1'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 54, 22),
#  'text': "RT @VibeMagazine: Review: @Netflix's #SevenSeconds and the worth of "
#          'black bodies in America',
#  'tweet_id': 967185898545779000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebd2'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 54, 23),
#  'text': '@JohnBechard @netflix Just started watching Frankenstein Chronicles '
#          'this week. Dark but good!',
#  'tweet_id': 967185902815494000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebd3'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 54, 25),
#  'text': '@netflix OMFG I KNEW I KNEW HER',
#  'tweet_id': 967185911401230000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebd4'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 54, 28),
#  'text': 'RT @Elena11575: #XenaRevival with #OriginalCast LucyLawless '
#          'ReneeOConnor @NBCUniversal @nbc @netflix @RealLucyLawless @robtapert '
#          '@SYFY???????',
#  'tweet_id': 967185926299451000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebd5'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 54, 29),
#  'text': 'RT @IAmWeCampaign: No no @Netflix must release a trailer or at least '
#          "a special premier date. We've not settled for less before and we "
#          'shall?',
#  'tweet_id': 967185929189278000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebd6'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 54, 31),
#  'text': '@JohnBechard @netflix Have you seen @MINDHUNTER_ ??',
#  'tweet_id': 967185936391004000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebd7'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 54, 31),
#  'text': '@MarvelIronFist @netflix #IronFist #Marvel @Marvel',
#  'tweet_id': 967185938806989000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebd8'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 54, 33),
#  'text': 'RT @LenaDalli: @AnaMSL4ever @NetflixLifee @netflix @NBCUniversal '
#          '@robtapert @nbc @RealLucyLawless @Zenja20 @thebigloc @Dianafowles '
#          '@Silvera?',
#  'tweet_id': 967185946033644000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebd9'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 54, 35),
#  'text': '@netflix put pitch perfect 3 on netflix as soon as you can',
#  'tweet_id': 967185954694881000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebda'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 54, 37),
#  'text': '@LLindsey3rd @purpose1958 @Hollaworldwide @funder @netflix Hope you '
#          'enjoy it!',
#  'tweet_id': 967185961753903000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebdb'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 54, 42),
#  'text': 'RT @joelmchale: \xadllame a su congresista, sacerdote, entrenador, '
#          'paseador de perros y @netflix @netflixLAT (por supuesto) y '
#          'd\x82jelos saber qu?',
#  'tweet_id': 967185982561776000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebdc'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 54, 54),
#  'text': 'RT @Alex79692759: We need #XenaRevival with original cast, No '
#          'reboot! @robtapert @UniversalTV @nbc @NBCUniversal @netflix',
#  'tweet_id': 967186035309294000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebdd'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 55),
#  'text': 'RT @RachLWhitehurst: the best birthday present i could receive is '
#          '@netflix adding all the mary-kate and ashley movies',
#  'tweet_id': 967186057988116000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebde'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 55, 5),
#  'text': 'RT @raygord48449699: #XenaRevival #Xena org cast, please, do '
#          '#XenaRevival #XenaMovie @netflix @SYFY @nbc @NBCUniversal '
#          '@NetflixLifee',
#  'tweet_id': 967186078368174000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebdf'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 55, 10),
#  'text': 'RT @adamhattan: Dear @QueerEye aka @netflix, I need 9 more seasons '
#          'greenlit. Each season needs a MINIMUM of 24 episodes. I want Antoni '
#          'ki?',
#  'tweet_id': 967186102405779000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebe0'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 55, 21),
#  'text': '@NageenH @MeganPTweets @CherFeldman @MarkTossell @miller_becka '
#          '@justicesikakane @danieljpeter @ZacOtero?',
#  'tweet_id': 967186146622132000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebe1'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 55, 21),
#  'text': 'WineShop Fan Friday ~ What pairs with a Friday night in, @netflix '
#          '&amp; a yummy cheese board? The Fleur Bleu 2016 Seven?',
#  'tweet_id': 967186146672480000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebe2'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 55, 22),
#  'text': 'RT @sydney_sweeney: Remember when untagging was violent? '
#          '@EverythingSuxTV coming to @netflix February 16th!!',
#  'tweet_id': 967186148987736000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebe3'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 55, 31),
#  'text': "RT @NobrowPress: Guess who's coming to @netflix? @thatlukeperson's "
#          'HILDA! Thanks to @PublishersWkly for announcing the world premiere '
#          'at @N?',
#  'tweet_id': 967186190582538000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebe4'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 55, 32),
#  'text': 'Dragon ball super para @netflix por favor!',
#  'tweet_id': 967186194109948000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebe5'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 55, 35),
#  'text': 'Fuck you @netflix for #IrreplaceableYou I feel personally attacked '
#          'from the final half of the movie. It is beautifu?',
#  'tweet_id': 967186206948839000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebe6'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 55, 44),
#  'text': '- ¨Y qu\x82 te pareci¢ la tan promocionada pelicula de @netflix, '
#          '#TheCloverfieldParadox? Yo:',
#  'tweet_id': 967186244848546000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebe7'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 55, 51),
#  'text': '@TheDefenders @netflix #Marvel #Netflix #FridayFeeling',
#  'tweet_id': 967186273885704000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebe8'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 55, 52),
#  'text': '@GraceRandolph @netflix The theatrical one suits the theatres '
#          'perfectly and the Netflix one suits the Netflix site. They?re both '
#          'stunning.',
#  'tweet_id': 967186275865416000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebe9'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 55, 59),
#  'text': 'RT @ReynoldsLayla: Productive Fridaze! Watching #TheRitual now on '
#          '@netflix .... back online ?? tomorrow ?? #FilmClub #MovieClub '
#          '#Flirt4?',
#  'tweet_id': 967186307280667000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebea'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 56, 2),
#  'text': 'The animation in #TheLittlePrince is absolutely superb! I love the '
#          'mix of two different creative styles. Kudos, @netflix',
#  'tweet_id': 967186320501170000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebeb'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 56, 8),
#  'text': 'RT @SantosRobertoo: @netflix Tom and jerry please? Can we?',
#  'tweet_id': 967186345717252000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebec'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 56, 15),
#  'text': '@netflix Chris Rock?s new comedy is disgusting. Murder children? '
#          'Really? is this entertainment? I and many others w?',
#  'tweet_id': 967186371533156000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebed'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 56, 15),
#  'text': '@its_willyu @netflix How are they so different? Anyway, it must be '
#          'exhausting to be "outraged" all the time. In the?',
#  'tweet_id': 967186373240226000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebee'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 56, 23),
#  'text': 'There are at least two Saudi actresses on @netflix already. I love '
#          "me some Ahd Kamel but I'm tired of this trope.",
#  'tweet_id': 967186405507056000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebef'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 56, 25),
#  'text': 'RT @MakingStarWars: @RianJohnson Q&amp;A with @ManMadeMoon for '
#          '@Netflix\'s "Mute." #Mute #Moon #StarWars',
#  'tweet_id': 967186416701706000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebf0'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 56, 31),
#  'text': '@its_willyu @netflix Seems you should write your own movie script '
#          'then and stop complaining about other people?s art....',
#  'tweet_id': 967186439078203000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebf1'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 56, 37),
#  'text': 'RT @Kai56405432: We want a #XenaRevival with original cast '
#          '@NBCUniversal @netflix @hulu @AmazonStudios #Xena',
#  'tweet_id': 967186464369992000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebf2'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 56, 38),
#  'text': 'RT @Sanaryelle: @IndieWire @netflix Jared Leto becomes a ?Yakuza '
#          'Killing Machine?? Like Tom Cruise was ?The Last Samurai?? Seriously?',
#  'tweet_id': 967186470787105000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebf3'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 56, 57),
#  'text': 'RT @anokhina_1997: We need #XenaRevival with #OriginalCast '
#          '#NoReboot! @robtapert @UniversalTV @nbc @NBCUniversal @netflix',
#  'tweet_id': 967186549111534000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebf4'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 56, 59),
#  'text': "Ok Olympics are over.... @netflix it's time to #RenewTravelers",
#  'tweet_id': 967186558162936000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebf5'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 57, 4),
#  'text': 'The Chris Rock @Netflix comedy had some laughs and some pandering '
#          'about being black that was embarrassing. And he?',
#  'tweet_id': 967186580791284000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebf6'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 57, 17),
#  'text': 'RT @TheKenReedyShow: @IndieWire @netflix And still no one has a '
#          'problem with the main Italian characters in The Assassination of '
#          'Gianni Ver?',
#  'tweet_id': 967186634084180000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebf7'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 57, 25),
#  'text': 'RT @kJ0uIgaDACht9c0: #XenaRevival with original cast or #XenaMovie '
#          '@robtapert @UniversalTV @nbc @netflix @NetflixLifee @NBCUniversal '
#          'https?',
#  'tweet_id': 967186665851769000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebf8'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 57, 26),
#  'text': '@SaveTLT @netflix @Netflix_CA @NetflixUK Please sign our petition to '
#          '#SaveTheLastTycoon',
#  'tweet_id': 967186669408461000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebf9'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 57, 30),
#  'text': '7 episodes into ALTERED CARBON and I?m now just realizing how trash '
#          'this show is. I tried @netflix ???????',
#  'tweet_id': 967186689096585000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebfa'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 57, 31),
#  'text': 'RT @Elena11575: @nbc @NBCUniversal @robtapert please! Do '
#          '#XenaRevival @netflix @SYFY',
#  'tweet_id': 967186690489111000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebfb'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 57, 32),
#  'text': 'RT @IndieWire: #TheOutsider Trailer: Jared Leto Becomes a Yakuza '
#          'Killing Machine in @netflix Original',
#  'tweet_id': 967186695350301000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebfc'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 57, 34),
#  'text': 'I haven?t watched @Netflix for a week or so and now I?m feeling '
#          'guilty. Recommendations?',
#  'tweet_id': 967186705819161000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebfd'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 57, 40),
#  'text': 'Watching buddy ???? @netflix @OneDayAtATime #OneDayAtATime',
#  'tweet_id': 967186730871935000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebfe'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 57, 41),
#  'text': '@MarvelIronFist @netflix',
#  'tweet_id': 967186732637704000}
# {'_id': ObjectId('5ac44aafa313fc07c984ebff'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 57, 41),
#  'text': '@Netflix why do you feel the need to advertise this move as a '
#          '?strong? black lead? We can see the main characters a?',
#  'tweet_id': 967186732809630000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec00'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 57, 43),
#  'text': '@joelmchale @netflix @NetflixLAT Did you learn all this at '
#          'Greendale??',
#  'tweet_id': 967186743240741000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec01'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 57, 47),
#  'text': '@dan_corkery @QueerEye @netflix It legitimately warmed my heart - '
#          'how many things can do that these days?',
#  'tweet_id': 967186757103047000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec02'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 57, 50),
#  'text': 'RT @ManMadeMoon: Well! That should be @mute gone live on @netflix '
#          'all over the world! ?? you all! I?m off to bed!',
#  'tweet_id': 967186771598602000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec03'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 57, 52),
#  'text': 'RT @Alina72649228: @NetflixLifee @netflix @nbc @NBCUniversal '
#          '#XXisforXENA #XenaRevival #XenitesUnitebrng legend back, give us '
#          'Xena Revival?',
#  'tweet_id': 967186780276609000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec04'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 57, 57),
#  'text': 'RT @JohnGilles6: @netflix @NBCUniversal @nbc @SYFY @robtapert '
#          'PLEASE! We want just full 7th season of #XenaRevival with '
#          '#LucyLawless and #R?',
#  'tweet_id': 967186802950853000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec05'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 58, 10),
#  'text': 'RT @spidadmitchell: So @netflix took @BurnNotice_USA off its '
#          'website!! This really hurts me honestly! This is my favorite show '
#          'and if there?',
#  'tweet_id': 967186854226420000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec06'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 58, 16),
#  'text': 'RT @Kira38931594: #XenaRevival with original cast will be epic and '
#          'we will stand up calling for it until it happens. @NBCUniversal '
#          '@netflix?',
#  'tweet_id': 967186881489375000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec07'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 58, 17),
#  'text': '@joelmchale @netflix @NetflixLAT Ver a @joelmchale, @alisonbrie y '
#          '@RashisTVUgly me ilusion\x82 con una pel¡cula de?',
#  'tweet_id': 967186884198851000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec08'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 58, 17),
#  'text': "I'm more than a little obsessed with the Dirty Money episode about "
#          'the Maple Syrup Heist in Canada on @netflix. Bec?',
#  'tweet_id': 967186886472151000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec09'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 58, 22),
#  'text': '@netflix, I love you so much, but I also hate you (but not rlly). '
#          '@QueerEye should?ve come out in a box set series?',
#  'tweet_id': 967186907162583000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec0a'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 58, 23),
#  'text': 'Have plans tonight? Yes you do ?? The new docuseries, UGLY '
#          'DELICIOUS, premieres TONIGHT on @netflix. UHD finishing?',
#  'tweet_id': 967186911885451000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec0b'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 58, 29),
#  'text': 'RT @Corey_Champagne: Alright world, ?Seven Seconds? is now yours. '
#          'Enjoy ?? @netflix',
#  'tweet_id': 967186933527986000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec0c'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 58, 35),
#  'text': '@cbbzor @angryasianman @netflix Wait..This shit is on @netflix ??? '
#          'WTF Netflix? GET RID OF THIS CRAP!!!',
#  'tweet_id': 967186958945485000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec0d'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 58, 45),
#  'text': "Review: @Netflix's #SevenSeconds and the worth of black bodies in "
#          'America',
#  'tweet_id': 967187001115075000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec0e'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 58, 49),
#  'text': 'RT @doblajeVe: RositaFresita #Frutillita #doblaje @NetflixLAT '
#          '@netflix @Discovery_Kids @DisneyJunior1',
#  'tweet_id': 967187019398033000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec0f'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 58, 52),
#  'text': 'RT @The_Real_IMAN: Today is the day! Don?t miss out on watching '
#          '@ManMadeMoon Duncan Jones? movie Mute @mute on @netflix #Mute '
#          '#manmademovie?',
#  'tweet_id': 967187033079861000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec10'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 59, 1),
#  'text': '@netflix I?m just try and keep it together during ?Irreplaceable '
#          'You.?',
#  'tweet_id': 967187070392455000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec11'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 59, 4),
#  'text': 'RT @_mike_torres: Dear @netflix , thanks for bringing back The Sou- '
#          'I mean the @JoelMcHaleShow with @joelmchale',
#  'tweet_id': 967187082358731000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec12'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 59, 14),
#  'text': 'I?m sick. I am contagious. I am not leaving my house. I *need* '
#          '@netflix or @amazon prime recommendations pronto please!!!!',
#  'tweet_id': 967187125987873000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec13'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 59, 16),
#  'text': '@its_willyu @netflix Cause Asian movies give American actors such '
#          'juicy roles. Right?',
#  'tweet_id': 967187130433679000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec14'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 59, 19),
#  'text': '@its_willyu @netflix Reminder that Japan has a huge movie industry '
#          'of their own, almost always staring all Asian ca?',
#  'tweet_id': 967187146015683000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec15'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 59, 22),
#  'text': 'Heeeey @Netflix if you make me wait two years for season 2 of '
#          'Altered Carbon and @joelkinnaman Imma unsubscribe. N?',
#  'tweet_id': 967187158212665000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec16'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 59, 30),
#  'text': '@MoKrier @netflix Not long to wait. The Jupiter 2 is about to take '
#          'off for an amazing journey of wonder.',
#  'tweet_id': 967187190177346000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec17'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 59, 30),
#  'text': "RT @netflix: If you're looking for #LostInSpace spoilers, just ask "
#          '@NASA',
#  'tweet_id': 967187193021305000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec18'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 59, 31),
#  'text': '@joelmchale @netflix @NetflixLAT Netflix y fr¡o (mi espa¤ol no es '
#          'perfecto. ¨Fr¡o es mismo de ?chill??)',
#  'tweet_id': 967187194870890000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec19'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 59, 31),
#  'text': '@netflix plz put Fresh Prince of Bel Air on thank u',
#  'tweet_id': 967187196741607000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec1a'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 59, 38),
#  'text': 'RT @sedirox: @netflix I just watched that episode of Black Mirror.',
#  'tweet_id': 967187226542166000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec1b'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 59, 41),
#  'text': 'RT @Eben_Lompo: Donc apr\x8as Death Note c?est au tour de Full Metal '
#          'Alchemist @netflix ? Touchez \x85'
#          ' Hunter x Hunter \x87a va sortir dans les rues?',
#  'tweet_id': 967187236658725000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec1c'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 59, 41),
#  'text': 'Praying for @netflix hopefully y?all make sum shake. Add movies that '
#          'will get y?all ratings up #Duh ?????????',
#  'tweet_id': 967187239150215000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec1d'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 59, 53),
#  'text': '@joelmchale @netflix @NetflixLAT You are tremendo!!',
#  'tweet_id': 967187286600413000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec1e'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 59, 54),
#  'text': 'every show I end up watching with deep intent and interest, ends up '
#          'being cancelled on @netflix ... Bring back @DamnationTV :/',
#  'tweet_id': 967187292896014000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec1f'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 59, 55),
#  'text': '@schsnapp @SadieSink @noah_schnapp @Stranger_Things @netflix '
#          '@SadieSink @noah_schnapp @Stranger_Things @netflix',
#  'tweet_id': 967187297623052000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec20'),
#  'created_at': datetime.datetime(2018, 2, 23, 23, 59, 58),
#  'text': 'RT @PetsforPatriots: Let King make your home a castle! Senior pup '
#          'loves binging on @netflix + lounging on the couch w/his humans. Ok '
#          'with o?',
#  'tweet_id': 967187308138045000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec21'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 42),
#  'text': 'RT @detroitnews: .@netflix is releasing a new documentary on Flint '
#          'police called #FlintTown. Check out the trailer here:',
#  'tweet_id': 967545175928009000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec22'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 42, 3),
#  'text': 'RT @netflix: When Letitia Wright gets behind the wheel, you know '
#          'something badass is about to happen.',
#  'tweet_id': 967545186418151000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec23'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 42, 4),
#  'text': 'RT @ALT1053Radio: Jared Leto &amp; Emile Hirsch are among the stars '
#          'of this @netflix movie coming in March.',
#  'tweet_id': 967545193707856000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec24'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 42, 14),
#  'text': '@Netflix depois desse final eu preciso da season 2 de Everything '
#          'Sucks pra ontem pls',
#  'tweet_id': 967545231901159000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec25'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 42, 41),
#  'text': '@MicrophoneJones @netflix ????',
#  'tweet_id': 967545347626082000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec26'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 42, 56),
#  'text': 'RT @ILoveEvilEnigma: #Roswell is my favorite show. @netflix dropped '
#          'the ball when they let it go &amp; @hulu picked it up. Now they have '
#          'a chan?',
#  'tweet_id': 967545409525740000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec27'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 42, 58),
#  'text': '@its_willyu @netflix Where I think there is an interesting '
#          'opportunity for exploration of themes in this kind of st?',
#  'tweet_id': 967545420363846000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec28'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 43, 2),
#  'text': 'RT @its_willyu: STOP. WRITING. AROUND. US. @netflix',
#  'tweet_id': 967545436671234000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec29'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 43, 2),
#  'text': 'RT @SFXmagazine: The 25 best TV shows on @Netflix (February 2018)',
#  'tweet_id': 967545436838990000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec2a'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 43, 9),
#  'text': '@netflix @NetflixLAT lo peor q pudieron hacer es sacar How i met '
#          'your mother necesito ver unos episodios ??',
#  'tweet_id': 967545465892954000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec2b'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 43, 10),
#  'text': "RT @netflix: Don't drop your Eggos. Rumors that the Duffer Bros are "
#          'leaving Stranger Things after season 3 are false.',
#  'tweet_id': 967545467218420000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec2c'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 43, 13),
#  'text': 'Join the #SaturdayNightSciFi crew for our livetweet of '
#          '#ThePrestige?? on @netflix at 10pmEST. Prepare to be amazed?',
#  'tweet_id': 967545480501715000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec2d'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 43, 13),
#  'text': '@ChiragMadhrani @netflix It is actually good.. Especially the 3rd '
#          'epi: Drug Short',
#  'tweet_id': 967545480925229000}
# {'_id': ObjectId('5ac44aafa313fc07c984ec2e'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 43, 15),
#  'text': 'From award winning #Screenwriter @BenFiore59 A Pilot script for an '
#          "all-new crime drama TV series project! Ben's id?",
#  'tweet_id': 967545487606862000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec2f'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 43, 17),
#  'text': 'RT @spidadmitchell: So @netflix took @BurnNotice_USA off its '
#          'website!! This really hurts me honestly! This is my favorite show '
#          'and if there?',
#  'tweet_id': 967545496599372000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec30'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 43, 27),
#  'text': '@agriff1979 @netflix But my first question was how many peope are '
#          'watching? You claimed to know that correct?',
#  'tweet_id': 967545537997160000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec31'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 43, 35),
#  'text': 'RT @spidadmitchell: #BRINGBACKBURNNOTICE @netflix',
#  'tweet_id': 967545574038954000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec32'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 43, 48),
#  'text': 'RT @shadowandact: Trailer released for Roxanne Shant\x82 biopic, '
#          'starring Chant\x82 Adams, #MahershalaAli and @NiaLong set to debut '
#          'on @Netflix.?',
#  'tweet_id': 967545626182504000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec33'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 44, 1),
#  'text': 'RT @SamuelDeats: @Matthew_26 @netflix Haha, we are working on it '
#          'super hard, 8 episodes this time!',
#  'tweet_id': 967545682050601000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec34'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 44, 8),
#  'text': '@spidadmitchell @CaseyFraleigh @netflix Literally started watching '
#          "this get five episodes in and it's getting take off two days later. "
#          'Fml',
#  'tweet_id': 967545712694116000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec35'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 44, 27),
#  'text': 'RT @_AlienAdvocates: Whatever it takes! @Netflix #NetflixforBandT '
#          'Hmm.. we will help to promote it.',
#  'tweet_id': 967545790620230000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec36'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 44, 37),
#  'text': 'Damn it I miss @FamilyGuyonFOX. Why did @netflix have to remove it '
#          '??. @SethMacFarlane',
#  'tweet_id': 967545833934631000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec37'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 44, 49),
#  'text': 'Everyone went BANANAS over the reboot news but why can?t we have '
#          '#BARONandTOLUCA too?! The #Dans need your help .?',
#  'tweet_id': 967545884799009000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec38'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 45, 2),
#  'text': '@oh_JodieBaby @SavageTV1 @LeonardRaymundo @eveirecarolina '
#          '@TommyKeavy @its_willyu @netflix I love First Class and D?',
#  'tweet_id': 967545936917524000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec39'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 45, 2),
#  'text': 'Everyone needs to watch @Netflix Dirty Money episode about '
#          '@realDonaldTrump (episode six)',
#  'tweet_id': 967545940247708000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec3a'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 45, 3),
#  'text': '#SexyIn5Words: #JakeBaron and #TolucaMendez! ?????? @netflix '
#          '#NETFLIXforBandT @hulu #HULUforBandT @SYFY #SYFYforBandT?',
#  'tweet_id': 967545942118461000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec3b'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 45, 11),
#  'text': 'RT @_AlienAdvocates: TOLUCA is amazing.She needs a best friend..Liz, '
#          "Hm..What rhymes?Liz..We need @MajandraD's creativity. @netflix let's "
#          's?',
#  'tweet_id': 967545975714828000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec3c'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 45, 25),
#  'text': '@coltsmith2714 @LeonardRaymundo @SavageTV1 @eveirecarolina '
#          '@TommyKeavy @its_willyu @netflix They all had their mome?',
#  'tweet_id': 967546034518884000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec3d'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 45, 28),
#  'text': '@uglydelicious I just watched the 1st episode, I ?? @azizansari '
#          '&amp; @davidchang, pizza in Tokyo! @netflix is the bes?',
#  'tweet_id': 967546047315829000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec3e'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 45, 29),
#  'text': 'RT @jymmeash: Y?all, go watch Crazyhead. It is definitely worth the '
#          'time put into watching it. It is hilarious! @netflix',
#  'tweet_id': 967546052206322000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec3f'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 45, 31),
#  'text': 'These streaming services been sleeping on the Selena movie too long '
#          'heller @netflix may we get the hook-up plz',
#  'tweet_id': 967546058741047000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec40'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 45, 32),
#  'text': '@netflix WHY WOULD U TAKE FAMILY GUY OFF?',
#  'tweet_id': 967546063648371000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec41'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 45, 34),
#  'text': 'RT @andrewcurryla: Can we take a moment to appreciate @netflix?s '
#          '@QueerEye excellent casting ... @antoni #QueerEye #foodandwine (1/5) '
#          'http?',
#  'tweet_id': 967546074209677000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec42'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 45, 48),
#  'text': 'RT @guerinsss: Okay .@netflix here?s the deal: there?s this new '
#          'amazing show that I need u check out #NETFLIXforBan?',
#  'tweet_id': 967546132535497000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec43'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 45, 58),
#  'text': 'RT @sam_the_samrock: MAN I?D REALLY LIKE TO WATCH SOME HOW I MET '
#          'YOUR MOTHER RIGHT NOW @netflix @Netflix_CA @NetflixUK @NetflixMENA '
#          '@Netfli?',
#  'tweet_id': 967546171177816000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec44'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 46),
#  'text': '@NeutralZoneChat @blakeussery007 @netflix @CBS @thegoodfight @JWagz '
#          'According to CBS of course, the show had critic?',
#  'tweet_id': 967546181097329000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec45'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 46, 1),
#  'text': '@Ryan_M_Unicomb @netflix But Netflix isn?t mainstream cinema. What '
#          'do critics have to gain from reviewing Netflix f?',
#  'tweet_id': 967546184444203000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec46'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 46, 13),
#  'text': '@agriff1979 @kayla_gabrielle @hausmuva @chancetherapper @netflix '
#          'Lol. I have it sweetie. In fact I need it considering where I live '
#          '????.',
#  'tweet_id': 967546236550214000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec47'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 46, 14),
#  'text': '@coltsmith2714 @SavageTV1 @LeonardRaymundo @eveirecarolina '
#          '@TommyKeavy @its_willyu @netflix I feel you on that. Tha?',
#  'tweet_id': 967546242032198000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec48'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 46, 16),
#  'text': "@netflix What did I just watch, and why does this exist? I'm so "
#          'beyond confused??',
#  'tweet_id': 967546249770660000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec49'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 46, 18),
#  'text': 'Mis amores, ya vieron #Eldesconocido por @netflix No se pierdan la '
#          'vida de Karla en esta historia ???',
#  'tweet_id': 967546257093906000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec4a'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 46, 23),
#  'text': 'RT @billburr: It?s about f***ing time! #FIsForFamily is back May 30 '
#          'on @Netflix.',
#  'tweet_id': 967546278526767000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec4b'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 46, 26),
#  'text': 'BUT THEN. I met these guys @jvn @antoni @QueerEye @bobbyberk '
#          '@KaramoBrown @tanfrance who have opened my eyes and sh?',
#  'tweet_id': 967546291482853000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec4c'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 46, 32),
#  'text': '@Contrarah @INNSMOUTHxSHADE @uren_marc @AlanTudyk @netflix Mine are '
#          'spending the year dead for tax reasons.',
#  'tweet_id': 967546316153917000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec4d'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 46, 33),
#  'text': '@its_willyu @netflix IMO, is a Supply and demand issue. There is '
#          'demand for Asian actors in lead rolls, but little?',
#  'tweet_id': 967546320201294000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec4e'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 46, 38),
#  'text': 'Is @netflix tracking my menstrual cycle?',
#  'tweet_id': 967546341348950000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec4f'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 46, 47),
#  'text': '@netflix put labyrinth back on or so help me god',
#  'tweet_id': 967546376807739000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec50'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 47),
#  'text': 'Remember to tell everyone you know to sign the petition! We can make '
#          'it to 100K! Then @netflix will have a very har?',
#  'tweet_id': 967546433032225000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec51'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 47, 1),
#  'text': '@Edges_N_Paris @agriff1979 @hausmuva @chancetherapper @netflix If '
#          'she was doing so well why didn?t they offer her a lot of money then '
#          '?',
#  'tweet_id': 967546437641753000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec52'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 47, 3),
#  'text': 'RT @_AlienAdvocates: .@netflix @hulu @syfy @AmazonStudios I am '
#          'writing because of #BARONandTOLUCA! We miss Majandra + Brendan on '
#          'TV. #NETFL?',
#  'tweet_id': 967546444063396000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec53'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 47, 17),
#  'text': '@schibnight @netflix @idofmovie Nice!!!! Keep that shit up!',
#  'tweet_id': 967546503492354000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec54'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 47, 21),
#  'text': '@nowthisisliving ok now you have me hooked on Everything Sucks on '
#          '@Netflix . The soundtrack is crazy good! ???? I fee?',
#  'tweet_id': 967546521402135000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec55'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 47, 23),
#  'text': 'Binge watching a show on @netflix called, ? DARK? I am really '
#          'enjoying it!! #checkitout #netflixandchill',
#  'tweet_id': 967546529157403000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec56'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 47, 29),
#  'text': '@LeonardRaymundo @oh_JodieBaby @SavageTV1 @eveirecarolina '
#          '@TommyKeavy @its_willyu @netflix The focus on Wolverine d?',
#  'tweet_id': 967546553639485000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec57'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 47, 32),
#  'text': '@SmithRamparts @INNSMOUTHxSHADE @uren_marc @AlanTudyk @netflix My '
#          'people are in suspended animation so it could take a while',
#  'tweet_id': 967546566792884000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec58'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 47, 33),
#  'text': 'RT @_AlienAdvocates: @netflix? Please do your TV magic! '
#          '#RoswellMagic #BARONandTOLUCA',
#  'tweet_id': 967546572148912000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec59'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 47, 37),
#  'text': "RT @seangares: @C9shroud @netflix DUDEEEE, i've been trying to get "
#          'ppl on the big mouth train for a while now.... fkn hilarious',
#  'tweet_id': 967546588632617000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec5a'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 47, 54),
#  'text': '@kayla_gabrielle @agriff1979 @hausmuva @chancetherapper @netflix '
#          '#FactsMatter',
#  'tweet_id': 967546659600306000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec5b'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 48, 2),
#  'text': '@LeonardRaymundo @coltsmith2714 @SavageTV1 @eveirecarolina '
#          '@TommyKeavy @its_willyu @netflix Legion is pretty crazy,?',
#  'tweet_id': 967546692886286000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec5c'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 48, 3),
#  'text': "RT @C9shroud: I'd just like to say Big Mouth on @netflix might just "
#          'be my new favorite comedy show. That is all, going live soon.',
#  'tweet_id': 967546698535858000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec5d'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 48, 10),
#  'text': 'Hello? @netflix, @hulu, @PrimeVideo, @SYFY are any of you realizing '
#          'yet that #BaronAndToluca is too good to pass up?',
#  'tweet_id': 967546726809833000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec5e'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 48, 21),
#  'text': 'Needed a new show to watch &amp; I?ve got a few recommendations for '
#          'the new version of 90210 on @netflix &amp; I?m actually?',
#  'tweet_id': 967546774293381000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec5f'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 48, 23),
#  'text': '@MalalaFund @Malala @netflix @Letterman Sure, will be watching.',
#  'tweet_id': 967546782556209000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec60'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 48, 25),
#  'text': '@QueerEye @netflix We need more episodes of this show @netflix ! It '
#          'is so uplifting and much needed right now .',
#  'tweet_id': 967546790605132000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ec61'),
#  'created_at': datetime.datetime(2018, 2, 24, 23, 48, 31),
# ...
#  'text': "@ScorseseFanboy @ManMadeMoon @netflix I couldn't agree more. Just "
#          'finished watching and I find myself in complete d?',
#  'tweet_id': 967909985542984000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ed84'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 51, 47),
#  'text': 'RT @kate_mccrea: @mrlawsonpants @netflix I know what I?m doing '
#          'tomorrow. Why didn?t it show up in my notifications @netflix???',
#  'tweet_id': 967910025338507000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ed85'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 51, 57),
#  'text': 'RT @IndieWire: #Dismissed is now streaming on @netflix. We spoke to '
#          '@dylansprouse about how he made his return to acting:',
#  'tweet_id': 967910067914920000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ed86'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 52, 6),
#  'text': 'my little sister made her science fair project ?stranger things? '
#          'inspired, you could say she?s a big fan @netflix?',
#  'tweet_id': 967910103323218000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ed87'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 52, 10),
#  'text': 'Yo @netflix I just finished Everythuhg Sucks and I want you to know '
#          'that you?re excused for 13 Reasons Why',
#  'tweet_id': 967910120616288000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ed88'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 52, 11),
#  'text': 'RT @netflix: aLl Of OuR tWeEtS aBoUt EvErYtHiNg SuCkS wIlL bE '
#          'wRiTtEn LiKe ThIs. aLsO iT iS nOw StReAmInG',
#  'tweet_id': 967910125808779000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ed89'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 52, 14),
#  'text': '@BekaOurs @hallmarkchannel @netflix No, I didn?t get a chance to '
#          'watch, but I did see the previews of it.',
#  'tweet_id': 967910136978334000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ed8a'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 52, 17),
#  'text': '@netflix y?all gonna add more anime or na',
#  'tweet_id': 967910150144131000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ed8b'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 52, 20),
#  'text': '@netflix please make another season of ?Unbreakable Kimmy Schmidt?',
#  'tweet_id': 967910161506554000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ed8c'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 52, 21),
#  'text': 'Watching Altered Carbon #AlteredCarbon @Netflix #nowwatching #telfie '
#          '(via @telfieapp)',
#  'tweet_id': 967910165667185000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ed8d'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 52, 31),
#  'text': '@BembiAnn @netflix @HemlockGrove @ITMovieOfficial I?m in shock. You '
#          'outdid your previous phenomenal work. I didn?t?',
#  'tweet_id': 967910208054940000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ed8e'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 52, 35),
#  'text': '@netflix I just binged the whole first season of Everything Sucks!',
#  'tweet_id': 967910227231367000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ed8f'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 52, 46),
#  'text': 'Holy shit! @netflix has a #FullMetalAlchemist movie! '
#          '@Sakura_Steph309',
#  'tweet_id': 967910272449917000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ed90'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 52, 46),
#  'text': 'RT @netflix: ??@DavidKHarbour, we wish you a...',
#  'tweet_id': 967910273838404000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ed91'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 52, 48),
#  'text': '@netflix I need approximately 9,000 more episodes of @QueerEye. I am '
#          'liiiviiiing for this show',
#  'tweet_id': 967910282717811000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ed92'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 52, 49),
#  'text': '@netflix pick up a season 3 for one day at a time',
#  'tweet_id': 967910287016800000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ed93'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 53, 9),
#  'text': '@KatieForte @ImpostersBravo @netflix That?s my show!',
#  'tweet_id': 967910369690866000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ed94'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 53, 10),
#  'text': '@MaryElizabethK9 @hallmarkchannel @netflix Did you watch '
#          '#royalhearts last night? It is my new favorite @hallmarkchannel '
#          'movie.',
#  'tweet_id': 967910374572900000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ed95'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 53, 19),
#  'text': "@0saama1 @netflix Great suggestion, Osama! We're all about improving "
#          'the Netflix experience and appreciate you sharing your thoughts! *JF',
#  'tweet_id': 967910410736189000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ed96'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 53, 29),
#  'text': '@netflix is getting to the point where I?m going to only renew my '
#          'subscription for the months when my favorite orig?',
#  'tweet_id': 967910454507926000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ed97'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 53, 32),
#  'text': 'Love your new show. I just wish it was longer. I am sure @netflix '
#          'can afford it. @joelmchale',
#  'tweet_id': 967910463815193000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ed98'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 53, 34),
#  'text': 'RT @ayyebabyy: S/O to @netflix for Seven Seconds. Hands down one of '
#          'the best shows I?ve watched.',
#  'tweet_id': 967910473155928000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ed99'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 53, 46),
#  'text': 'Why Watching One More Show On @netflix Can Wreck Your #Sleep',
#  'tweet_id': 967910524359934000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ed9a'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 53, 50),
#  'text': '@BradPaquin1 @netflix You asked for it by pooping in her Valentine '
#          'card.',
#  'tweet_id': 967910540013122000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ed9b'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 54, 1),
#  'text': 'RT @7SecondsNetflix: A mother on a mission. #SevenSeconds premieres '
#          'February 23 on @Netflix.',
#  'tweet_id': 967910588151226000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ed9c'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 54, 2),
#  'text': '@netflix I just canceled and alarmed everyone I know who has '
#          "netflix. They did Mo'nique wrong #boycottnetflix",
#  'tweet_id': 967910589854093000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ed9d'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 54, 4),
#  'text': '@falenkdwb @netflix 1 800 876 5353',
#  'tweet_id': 967910598041154000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ed9e'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 54, 28),
#  'text': '#NowStillWatching ?????????? @ABC @netflix @hulu @WWENetwork '
#          '@CBSBigBrother @BachelorABC @FamilyFeudABC @ABCSharkTank?',
#  'tweet_id': 967910700101308000}
# {'_id': ObjectId('5ac44ab0a313fc07c984ed9f'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 54, 28),
#  'text': '@cheezynacho1 @netflix lynch this asshole',
#  'tweet_id': 967910701758013000}
# {'_id': ObjectId('5ac44ab0a313fc07c984eda0'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 54, 41),
#  'text': 'I need Prisoners to be on @netflix plz.',
#  'tweet_id': 967910754983834000}
# {'_id': ObjectId('5ac44ab0a313fc07c984eda1'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 55, 14),
#  'text': 'Life hasn?t seemed quite as bright since THE SOUP went off the air. '
#          'Thankfully the razor sharp @joelmchale is back?',
#  'tweet_id': 967910892607345000}
# {'_id': ObjectId('5ac44ab0a313fc07c984eda2'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 55, 20),
#  'text': "So....... @netflix can y'all add season 13 of criminal minds because "
#          "I'm about to cry not having anymore episodes t?",
#  'tweet_id': 967910918972637000}
# {'_id': ObjectId('5ac44ab0a313fc07c984eda3'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 55, 24),
#  'text': '@NarcoticMedley @netflix Do you have his phone #?',
#  'tweet_id': 967910937159139000}
# {'_id': ObjectId('5ac44ab0a313fc07c984eda4'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 55, 39),
#  'text': "Let's get started @NetflixBrasil @netflix @7SecondsNetflix",
#  'tweet_id': 967910999083901000}
# {'_id': ObjectId('5ac44ab0a313fc07c984eda5'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 55, 47),
#  'text': '@TheRealAnnaCamp @netflix @SkylarAstin YOUR LAUGH GIVES ME LIFE '
#          'OMG!!????',
#  'tweet_id': 967911033145889000}
# {'_id': ObjectId('5ac44ab0a313fc07c984eda6'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 56, 18),
#  'text': 'RT @ajashoates: imma need iCarly, Victorious, and Drake and Josh on '
#          '@netflix real soon',
#  'tweet_id': 967911160417833000}
# {'_id': ObjectId('5ac44ab0a313fc07c984eda7'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 56, 21),
#  'text': '@BMileskiKFAN @netflix I don?t know them personally.',
#  'tweet_id': 967911173873009000}
# {'_id': ObjectId('5ac44ab0a313fc07c984eda8'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 57, 3),
#  'text': 'RT @JohnGilles6: We need #XenaRevival #XenitesUnite give us Revival! '
#          '@nbc @netflix @NetflixLifee',
#  'tweet_id': 967911349757121000}
# {'_id': ObjectId('5ac44ab0a313fc07c984eda9'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 57, 20),
#  'text': '@Lucyt_aussie @startrekcbs @netflix @NetflixANZ I want to rewatch '
#          '@StarTrek Next Generation now. So good!',
#  'tweet_id': 967911419852329000}
# {'_id': ObjectId('5ac44ab0a313fc07c984edaa'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 57, 25),
#  'text': 'RT @ulusoy_ar: New!! ?????? @cagatayulusoyy #cagatayulusoyy '
#          '#\x80a?atayUlusoy #Westandbyyou\x80agatayUlusoyNetflixYavuz '
#          '@netflixturkiye @netflix @03?',
#  'tweet_id': 967911443248148000}
# {'_id': ObjectId('5ac44ab0a313fc07c984edab'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 57, 55),
#  'text': 'RT @jedeamjo: .@netflix @SYFY @hulu #BandT; @BaronAndToluca is just '
#          'right for paranormal sci-fi adventures. Nostagia with original cast '
#          'of?',
#  'tweet_id': 967911568548729000}
# {'_id': ObjectId('5ac44ab0a313fc07c984edac'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 57, 59),
#  'text': '@Corey_Champagne @netflix Corey, great work on the series loving it '
#          'here in the uk! Any chance of a signed picture?',
#  'tweet_id': 967911585904775000}
# {'_id': ObjectId('5ac44ab0a313fc07c984edad'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 58, 8),
#  'text': 'RT @DeadlySiriusSXM: To celebrate the release of #Humanity on '
#          '@netflix, following @rickygervais is #DeadlySirius on Tues. March '
#          '13th we wil?',
#  'tweet_id': 967911622869242000}
# {'_id': ObjectId('5ac44ab0a313fc07c984edae'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 58, 13),
#  'text': 'RT @blakmarketmusik: ok but @netflix consider this: a series with '
#          'ancient greek philosophers. Like, Plato, Socrates, Aristotle, hell '
#          'Diogen?',
#  'tweet_id': 967911645208023000}
# {'_id': ObjectId('5ac44ab0a313fc07c984edaf'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 58, 19),
#  'text': 'RT @Elena11575: #XenaRevival and Original cast! @nbc @netflix '
#          '@NBCUniversal @nbc @robtapert @FSUWriter someone bring XENA back!',
#  'tweet_id': 967911670264812000}
# {'_id': ObjectId('5ac44ab0a313fc07c984edb0'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 58, 20),
#  'text': 'The ?My List? feature on @netflix is a microcosm of the American '
#          'problem; the list of things I want keeps getting b?',
#  'tweet_id': 967911674341708000}
# {'_id': ObjectId('5ac44ab0a313fc07c984edb1'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 58, 27),
#  'text': '@netflix still waiting..',
#  'tweet_id': 967911700925207000}
# {'_id': ObjectId('5ac44ab0a313fc07c984edb2'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 58, 27),
#  'text': '@honey_crazygirl @SoDaCookSon @AlexLesha3 @HJH_Alex @sr4mylove2 '
#          '@MARBEAR333 @treesarelife2 @easy_tigers @s13965019?',
#  'tweet_id': 967911702816735000}
# {'_id': ObjectId('5ac44ab0a313fc07c984edb3'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 58, 34),
#  'text': 'Can we start a petition that if @netflix includes one movie in a '
#          'series, they must include all movies? I don?t need?',
#  'tweet_id': 967911733137461000}
# {'_id': ObjectId('5ac44ab0a313fc07c984edb4'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 58, 45),
#  'text': 'wHAT THE FUCK IS THIS @netflix #TEOTFW',
#  'tweet_id': 967911778519667000}
# {'_id': ObjectId('5ac44ab0a313fc07c984edb5'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 58, 52),
#  'text': '@netflix please...more White Rabbit Project...my family is starving',
#  'tweet_id': 967911806030135000}
# {'_id': ObjectId('5ac44ab0a313fc07c984edb6'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 58, 53),
#  'text': 'Day 1: Defiance (2008) starring Daniel Craig. #MoviePerDayChallenge '
#          'on @netflix',
#  'tweet_id': 967911811415552000}
# {'_id': ObjectId('5ac44ab0a313fc07c984edb7'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 58, 57),
#  'text': 'RT @confluentinc: .@allenxwang discussed why @netflix moved to '
#          '@apachekafka, the architecture and improvements they added to make '
#          '#Kafka w?',
#  'tweet_id': 967911826431373000}
# {'_id': ObjectId('5ac44ab0a313fc07c984edb8'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 59),
#  'text': "It's one thing to watch a story, another thing to live it ?? "
#          '@netflix @AltCarb #TheResistance #Resistance?',
#  'tweet_id': 967911839215604000}
# {'_id': ObjectId('5ac44ab0a313fc07c984edb9'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 59, 9),
#  'text': '@ash71us @iamritu @JoaoLCavalcante @almasthela @onco_cardiology '
#          '@venkmurthy @DavidWienerMD @HeartOTXHeartMD?',
#  'tweet_id': 967911879896064000}
# {'_id': ObjectId('5ac44ab0a313fc07c984edba'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 59, 13),
#  'text': '.@hulu @netflix #BandT #NETFLIXforBandT #HULUforBandT',
#  'tweet_id': 967911897218523000}
# {'_id': ObjectId('5ac44ab0a313fc07c984edbb'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 59, 15),
#  'text': 'And if we see a series in @netflix ? (tone of "and if we make a '
#          'doll" frozen)??',
#  'tweet_id': 967911902625042000}
# {'_id': ObjectId('5ac44ab0a313fc07c984edbc'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 59, 19),
#  'text': 'My Netflix application on roku is showing video stats on the top '
#          'left corner of the screen @netflix',
#  'tweet_id': 967911919536374000}
# {'_id': ObjectId('5ac44ab0a313fc07c984edbd'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 59, 36),
#  'text': '@netflix, eu te desprezo por n?o ter feito uma estreia simult\x83nea '
#          'de Annihilation',
#  'tweet_id': 967911991351259000}
# {'_id': ObjectId('5ac44ab0a313fc07c984edbe'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 59, 38),
#  'text': "What do you do when you don't feel good? Watch Creep 2... "
#          '@MarkDuplass @patrick_brice @netflix #creep #creep2 #superiorsequel '
#          '#makemore',
#  'tweet_id': 967911999568048000}
# {'_id': ObjectId('5ac44ab0a313fc07c984edbf'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 59, 40),
#  'text': "RT @dyadsproperty: @netflix Don't you dare to cancel @OneDayAtATime. "
#          "It's an amazing show that brings up many important discussions to "
#          'soci?',
#  'tweet_id': 967912007478530000}
# {'_id': ObjectId('5ac44ab0a313fc07c984edc0'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 59, 56),
#  'text': 'RT @AnaMSL4ever: @robtapert @netflix @NBCUniversal @nbc '
#          '@NetflixLifee @RealLucyLawless #XenaRevival #XXisforXENA Give us the '
#          'ending that w?',
#  'tweet_id': 967912075417842000}
# {'_id': ObjectId('5ac44ab0a313fc07c984edc1'),
#  'created_at': datetime.datetime(2018, 2, 25, 23, 59, 58),
#  'text': 'Just watched Duncan Jones? (@ManMadeMoon?s) #Mute on @netflix. Final '
#          'few moments pulled the emotional rug out, then?',
#  'tweet_id': 967912085391905000}

# %% [markdown]
# Updated October 3, 2017
